# %% [markdown]
# # **2021ML FALL HW1: PM2.5 Prediction (Regression)**

# %% [markdown]
# # **Import Some Packages**

# %%
# For data preprocess
import numpy as np
import csv
import math
import pandas as pd
import math

# %%
data_train = pd.read_csv('../train.csv')
data_test = pd.read_csv('../test.csv')

# %% [markdown]
# # Data preprocessing

# %%
class DataPreprocessor():
    def __init__(self):
        self.keep_col = None
        self.top_corr_number = 15
        self.train_mean = None
        self.train_std = None
    
    def remove_outlier_y_with_IQR(self, data_train: pd.DataFrame):
        mean_y = data_train['PM2.5'].mean()
        q75, q25 = np.percentile(data_train['PM2.5'], [75 ,25])
        IQR = q75 - q25
        upper_bound = mean_y + 1.5 * IQR
        lower_bound = mean_y - 1.5 * IQR
        keep_cond = (data_train['PM2.5'] < upper_bound) & (data_train['PM2.5'] > lower_bound)
        data_train = data_train[keep_cond]
        return data_train

    def remove_larger_than_1000(self, data_train: pd.DataFrame):
        data_train = data_train[data_train['PM2.5'] < 1000]
        return data_train

    def slice_top_n_correlation_with_y(self, data: pd.DataFrame, isTraining = False):
        if isTraining:
            index_corr_descending = abs(data.corrwith(data['PM2.5'])).sort_values(ascending=False).index
            #first column will always be `PM2.5`
            self.keep_col = index_corr_descending[:self.top_corr_number]
        data = data[self.keep_col]
        return data

    def normalize_data(self, X_data: np.array, isTraining = False):
        if isTraining:
            self.train_mean = X_data.mean(axis = 0)
            self.train_std = X_data.std(axis = 0)
        normalized_data = (X_data - self.train_mean) / self.train_std
        return normalized_data

    def min_max_scaling(self, X_data: np.array, isTraining = False):
        if isTraining:
            self.train_max = X_data.max(axis = 0)
            self.train_min = X_data.min(axis = 0)
        normalized_data = (X_data - self.train_min) / (self.train_max - self.train_min)
        return normalized_data


    def parse2train(self, data):
        data = data.values
        x = []
        y = []
        # 用前面9筆資料預測下一筆PM2.5 所以需要-9
        total_length = data.shape[0] - 9
        for i in range(total_length):
            x_tmp = data[i:i+9, :]
            y_tmp = data[i+9, 0] #PM2.5 is the first column
            x.append(x_tmp.reshape(-1,))
            y.append(y_tmp)
        x = np.array(x) #shape = (# of observations, # of features * # of time lag)
        y = np.array(y)
        return x, y


    def parse2test(self, data):
        x = []
        y = []
        data = data.values
        # 用前面9筆資料預測下一筆PM2.5 所以需要-9
        total_length = data.shape[0] - 9
        for i in range(857):
            x_tmp = data[9 * i: 9 * i + 9, :]
            x.append(x_tmp.reshape(-1,))
        # x 會是一個(n, 18, 9)的陣列， y 則是(n, 1) 
        x = np.array(x)
        return x

    def preprocess_train_data(self, data_train: pd.DataFrame):
        data_train = self.remove_outlier_y_with_IQR(data_train)
        #data_train = self.remove_larger_than_1000(data_train)
        data_train = self.slice_top_n_correlation_with_y(data_train, isTraining=True)
        X_train, y_train = self.parse2train(data_train)
        #X_train = self.normalize_data(X_train, isTraining = True)
        X_train = self.min_max_scaling(X_train, isTraining = True)
        return X_train, y_train

    def preprocess_test_data(self, data_test: pd.DataFrame):
        data_test = self.slice_top_n_correlation_with_y(data_test, isTraining=False)
        X_test = self.parse2test(data_test)
        #X_test = self.normalize_data(X_test, isTraining = False)
        X_test = self.min_max_scaling(X_test, isTraining = False)
        return X_test

# %%
class LinearRegression():
    def __init__(self):
        self.train_valid_ratio = 0.70
        self.train_loss = list()
        self.valid_loss = list()
        #record best information
        self.best_w = None
        self.best_bias = None
        self.best_valid_RMSE = None
        self.best_epoch = None
        self.stop_epoch = None

    def initialize_params(self, x):
        #initalize as a ~ unif(1, n-1) / sqrt(n)
        w = np.random.rand(x.shape[1]).reshape(-1, 1)
        bias = np.random.rand()
        return w, bias

    def train(self, x, y,batch_size, epoch_size, learning_rate, lam_train, verbose = True):
        #Initialize parameter
        batch_size = batch_size 
        epoch_size = epoch_size 
        lr = learning_rate
        w, bias = self.initialize_params(x)
        best_valid_RMSE = 99999
        best_epoch = 0
        patience = 10 #for early stopping

        #Adam optimizer
        lam = lam_train #L2 regularization
        beta_1 = np.full(x[0].shape, 0.9).reshape(-1, 1) #exponential decay rates for the moment estimates
        beta_2 = np.full(x[0].shape, 0.999).reshape(-1,1) #exponential decay rates for the moment estimates
        #m_t: first momentum vector, for momentum
        m_t = np.full(x[0].shape, 0).reshape(-1, 1)
        #v_t: second momemtum vector, for RMSprop
        v_t = np.full(x[0].shape, 0).reshape(-1, 1)
        m_t_b = 0.0
        v_t_b = 0.0
        t = 0
        epsilon = 1e-8

        for num_epoch in range(1, epoch_size + 1):
            #Shuffle when each epoch begin
            index = np.arange(x.shape[0])
            np.random.shuffle(index)
            x = x[index]
            y = y[index]
            split_point_x = math.floor(x.shape[0] * self.train_valid_ratio)
            split_point_y = math.floor(y.shape[0] * self.train_valid_ratio)
            X_train = x[:split_point_x, :]
            y_train = y[:split_point_y] 
            X_valid = x[split_point_x:, :] 
            y_valid = y[split_point_y:]
            SSE = 0
            for num_batch in range(int(X_train.shape[0]/batch_size)):
                t+=1
                x_batch = X_train[num_batch * batch_size:(num_batch + 1) * batch_size]
                y_batch = y_train[num_batch * batch_size:(num_batch + 1) * batch_size].reshape(-1,1)
                
                y_hat = np.dot(x_batch, w) + bias
                train_loss = y_batch - y_hat
                # 計算gradient
                g_t = np.dot(x_batch.transpose(), train_loss) * (-2) +  2 * lam * np.sum(w)
                #助教原本寫的是*2
                g_t_b = train_loss.sum(axis=0) * (-2)
                m_t = beta_1*m_t + (1-beta_1)*g_t 
                v_t = beta_2*v_t + (1-beta_2)*np.multiply(g_t, g_t)
                m_cap = m_t/(1-(beta_1**t))
                v_cap = v_t/(1-(beta_2**t))
                m_t_b = 0.9*m_t_b + (1-0.9)*g_t_b
                v_t_b = 0.999*v_t_b + (1-0.999) * (g_t_b*g_t_b) 
                m_cap_b = m_t_b/(1-(0.9**t))
                v_cap_b = v_t_b/(1-(0.999**t))

                # 更新weight, bias
                w -= ((lr*m_cap)/(np.sqrt(v_cap)+epsilon)).reshape(-1, 1)
                bias -= (lr*m_cap_b)/(math.sqrt(v_cap_b)+epsilon)
                SSE += np.sum(np.square(train_loss))

            # print(SSE)
            train_RMSE = np.sqrt(SSE / X_train.shape[0])
            valid_RMSE = self.compute_valid_RMSE(X_valid, y_valid, w, bias)
            self.train_loss.append(train_RMSE)
            self.valid_loss.append(valid_RMSE)
            if verbose:
                print(f"Epoch {num_epoch}, training RMSE = {round(train_RMSE, 5)}, validation RMSE = {round(valid_RMSE, 5)}")
            
            #save best result
            if valid_RMSE < best_valid_RMSE:
                self.best_w = w
                self.best_bias = bias
                self.best_epoch = num_epoch
                best_valid_RMSE = valid_RMSE
                self.best_valid_RMSE = best_valid_RMSE

            #early stopping
            if valid_RMSE > best_valid_RMSE and num_epoch >= self.best_epoch + patience:
                self.stop_epoch = self.best_epoch + patience
                if verbose:
                    print("Early Stopping!")
                    print("="*10 + "validation result" + "="*10)
                    print(f"Best epoch is {self.best_epoch} with minimum validation error = {round(best_valid_RMSE, 5)}")
                return

        self.stop_epoch = num_epoch
        if verbose:
            print("="*10 + "Model result" + "="*10)
            print(f"Best epoch is {self.best_epoch} with minimum validation error = {round(best_valid_RMSE, 5)}")
                      
    def compute_valid_RMSE(self, X_valid, y_valid, w, bias):
        valid_loss = 0
        y_hat = np.dot(X_valid, w) + bias
        valid_loss = y_valid.reshape(-1, 1) - y_hat.reshape(-1, 1)
        valid_SSE = np.sum(np.square(valid_loss))
        valid_RMSE = np.sqrt(valid_SSE / X_valid.shape[0])
        return valid_RMSE

    def train_with_full_data(self, x, y, batch_size, epoch_size, learning_rate, lam_train, verbose = True):
        #Initialize parameter
        batch_size = batch_size 
        epoch_size = epoch_size 
        lr = learning_rate
        w, bias = self.initialize_params(x)

        #Adam optimizer
        lam = lam_train #L2 regularization
        beta_1 = np.full(x[0].shape, 0.9).reshape(-1, 1) #exponential decay rates for the moment estimates
        beta_2 = np.full(x[0].shape, 0.999).reshape(-1,1) #exponential decay rates for the moment estimates
        #m_t: first momentum vector, for momentum
        m_t = np.full(x[0].shape, 0).reshape(-1, 1)
        #v_t: second momemtum vector, for RMSprop
        v_t = np.full(x[0].shape, 0).reshape(-1, 1)
        m_t_b = 0.0
        v_t_b = 0.0
        t = 0
        epsilon = 1e-8

        for num_epoch in range(1, epoch_size + 1):
            #Shuffle when each epoch begin
            index = np.arange(x.shape[0])
            np.random.shuffle(index)
            x = x[index]
            y = y[index]

            SSE = 0
            for num_batch in range(int(x.shape[0]/batch_size)):
                t+=1
                x_batch = x[num_batch * batch_size:(num_batch + 1) * batch_size]
                y_batch = y[num_batch * batch_size:(num_batch + 1) * batch_size].reshape(-1,1)
                
                y_hat = np.dot(x_batch, w) + bias
                train_loss = y_batch - y_hat
                # 計算gradient
                g_t = np.dot(x_batch.transpose(), train_loss) * (-2) +  2 * lam * np.sum(w)
                g_t_b = train_loss.sum(axis=0) * (-2)
                m_t = beta_1*m_t + (1-beta_1)*g_t 
                v_t = beta_2*v_t + (1-beta_2)*np.multiply(g_t, g_t)
                m_cap = m_t/(1-(beta_1**t))
                v_cap = v_t/(1-(beta_2**t))
                m_t_b = 0.9*m_t_b + (1-0.9)*g_t_b
                v_t_b = 0.999*v_t_b + (1-0.999) * (g_t_b*g_t_b) 
                m_cap_b = m_t_b/(1-(0.9**t))
                v_cap_b = v_t_b/(1-(0.999**t))

                # 更新weight, bias
                w -= ((lr*m_cap)/(np.sqrt(v_cap)+epsilon)).reshape(-1, 1)
                bias -= (lr*m_cap_b)/(math.sqrt(v_cap_b)+epsilon)
                SSE += np.sum(np.square(train_loss))

            # print(SSE)
            train_RMSE = np.sqrt(SSE / x.shape[0])
            self.train_loss.append(train_RMSE)
            if verbose:
                print(f"Epoch {num_epoch}, training RMSE = {round(train_RMSE, 5)}")

        self.best_w = w
        self.best_bias = bias

    def predict(self, X_test, w, bias):
        predict_value = np.dot(X_test, w) + bias
        return predict_value

# %%
def write_to_csv(y_pred, file_name):
    with open(file_name, 'w', newline='') as csvf:
        # 建立 CSV 檔寫入器
        writer = csv.writer(csvf)
        writer.writerow(['Id','Predicted'])
        for i in range(int(y_pred.shape[0])):
            writer.writerow([i + 1, y_pred[i][0]])

# %% [markdown]
# # Preprocessing and model tuning

# %%
DP = DataPreprocessor()
X_train, y_train = DP.preprocess_train_data(data_train)
X_test = DP.preprocess_test_data(data_test)

# %%
#train_valid_ratio_list = [0.6, 0.7, 0.8, 0.9]
batch_size_list = [64, 128, 256, 512, 1024]
epoch_size_list = [20, 30, 50, 100]
learning_rate_list = [0.002, 0.005, 0.01, 0.025, 0.05]
lambda_list = [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5]
np.random.seed(2021)

#Model saving
global_best_w = 0
global_best_bias = 0
global_best_RMSE = 1000000

#Hyperparameter saving
best_train_valid_ratio = 0
best_batch_size = 0
best_epoch_size = 0
best_learning_rate = 0
best_lambda = 0

# for train_valid_ratio in train_valid_ratio_list:
for batch_size in batch_size_list:
    for epoch_size in epoch_size_list:
        for learning_rate in learning_rate_list:
            for lam in lambda_list:
                print("=" * 10,"Start training model", "="*10)
                print(f"batch size = {batch_size}, epoch_size = {epoch_size}, learning rate = {learning_rate}, lambda = {lam}")
                model = LinearRegression()
                model.train(X_train, y_train, batch_size, epoch_size, learning_rate, lam, verbose = True)
                if model.best_valid_RMSE < global_best_RMSE:
                    global_best_RMSE = model.best_valid_RMSE
                    global_best_w = model.best_w
                    global_best_bias = model.best_bias
                    best_batch_size = batch_size
                    best_epoch_size = epoch_size
                    best_stop_epoch_size = model.best_epoch
                    best_learning_rate = learning_rate
                    best_lambda = lam
# Out:
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.001
# Epoch 1, training RMSE = 12.9916, validation RMSE = 12.5919
# Epoch 2, training RMSE = 12.05476, validation RMSE = 11.8206
# Epoch 3, training RMSE = 11.33632, validation RMSE = 11.13761
# Epoch 4, training RMSE = 10.76047, validation RMSE = 10.51097
# Epoch 5, training RMSE = 10.26354, validation RMSE = 10.03316
# Epoch 6, training RMSE = 9.81233, validation RMSE = 9.67338
# Epoch 7, training RMSE = 9.51167, validation RMSE = 9.16111
# Epoch 8, training RMSE = 9.13095, validation RMSE = 8.99694
# Epoch 9, training RMSE = 8.91152, validation RMSE = 8.59425
# Epoch 10, training RMSE = 8.62792, validation RMSE = 8.44072
# Epoch 11, training RMSE = 8.3434, validation RMSE = 8.42345
# Epoch 12, training RMSE = 8.24002, validation RMSE = 8.08416
# Epoch 13, training RMSE = 8.04595, validation RMSE = 8.01728
# Epoch 14, training RMSE = 7.89486, validation RMSE = 7.93728
# Epoch 15, training RMSE = 7.80636, validation RMSE = 7.78018
# Epoch 16, training RMSE = 7.75547, validation RMSE = 7.57583
# Epoch 17, training RMSE = 7.64954, validation RMSE = 7.54766
# Epoch 18, training RMSE = 7.56479, validation RMSE = 7.5159
# Epoch 19, training RMSE = 7.46491, validation RMSE = 7.5275
# Epoch 20, training RMSE = 7.41265, validation RMSE = 7.44805
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.44805
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.005
# Epoch 1, training RMSE = 13.66096, validation RMSE = 12.92074
# Epoch 2, training RMSE = 12.56524, validation RMSE = 12.21589
# Epoch 3, training RMSE = 11.85129, validation RMSE = 11.58484
# Epoch 4, training RMSE = 11.19508, validation RMSE = 11.12144
# Epoch 5, training RMSE = 10.67029, validation RMSE = 10.61596
# Epoch 6, training RMSE = 10.23563, validation RMSE = 10.14165
# Epoch 7, training RMSE = 9.84075, validation RMSE = 9.76619
# Epoch 8, training RMSE = 9.54204, validation RMSE = 9.31462
# Epoch 9, training RMSE = 9.18493, validation RMSE = 9.1182
# Epoch 10, training RMSE = 8.90999, validation RMSE = 8.88029
# Epoch 11, training RMSE = 8.67885, validation RMSE = 8.62771
# Epoch 12, training RMSE = 8.54952, validation RMSE = 8.23827
# Epoch 13, training RMSE = 8.31757, validation RMSE = 8.16492
# Epoch 14, training RMSE = 8.11865, validation RMSE = 8.09883
# Epoch 15, training RMSE = 7.9284, validation RMSE = 8.07746
# Epoch 16, training RMSE = 7.81927, validation RMSE = 7.93769
# Epoch 17, training RMSE = 7.71006, validation RMSE = 7.84185
# Epoch 18, training RMSE = 7.6599, validation RMSE = 7.66348
# Epoch 19, training RMSE = 7.58415, validation RMSE = 7.56796
# Epoch 20, training RMSE = 7.54501, validation RMSE = 7.4242
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.4242
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.01
# Epoch 1, training RMSE = 13.27325, validation RMSE = 12.61318
# Epoch 2, training RMSE = 12.25223, validation RMSE = 11.95974
# Epoch 3, training RMSE = 11.64238, validation RMSE = 11.04563
# Epoch 4, training RMSE = 10.92652, validation RMSE = 10.77437
# Epoch 5, training RMSE = 10.44262, validation RMSE = 10.24799
# Epoch 6, training RMSE = 10.05353, validation RMSE = 9.73854
# Epoch 7, training RMSE = 9.59974, validation RMSE = 9.5646
# Epoch 8, training RMSE = 9.30756, validation RMSE = 9.19348
# Epoch 9, training RMSE = 9.00589, validation RMSE = 8.94524
# Epoch 10, training RMSE = 8.7544, validation RMSE = 8.7277
# Epoch 11, training RMSE = 8.57785, validation RMSE = 8.42227
# Epoch 12, training RMSE = 8.37281, validation RMSE = 8.26245
# Epoch 13, training RMSE = 8.23744, validation RMSE = 8.04457
# Epoch 14, training RMSE = 8.05791, validation RMSE = 7.97066
# Epoch 15, training RMSE = 7.96446, validation RMSE = 7.78175
# Epoch 16, training RMSE = 7.76023, validation RMSE = 7.89573
# Epoch 17, training RMSE = 7.70995, validation RMSE = 7.70477
# Epoch 18, training RMSE = 7.62062, validation RMSE = 7.6435
# Epoch 19, training RMSE = 7.59334, validation RMSE = 7.46696
# Epoch 20, training RMSE = 7.49192, validation RMSE = 7.49253
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 7.46696
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.05
# Epoch 1, training RMSE = 13.01423, validation RMSE = 12.07707
# Epoch 2, training RMSE = 11.97657, validation RMSE = 11.5815
# Epoch 3, training RMSE = 11.25577, validation RMSE = 11.19511
# Epoch 4, training RMSE = 10.78699, validation RMSE = 10.52668
# Epoch 5, training RMSE = 10.32715, validation RMSE = 10.08052
# Epoch 6, training RMSE = 9.98071, validation RMSE = 9.58051
# Epoch 7, training RMSE = 9.59812, validation RMSE = 9.32955
# Epoch 8, training RMSE = 9.26055, validation RMSE = 9.10202
# Epoch 9, training RMSE = 8.95198, validation RMSE = 8.92612
# Epoch 10, training RMSE = 8.72211, validation RMSE = 8.6583
# Epoch 11, training RMSE = 8.51113, validation RMSE = 8.42904
# Epoch 12, training RMSE = 8.31202, validation RMSE = 8.25927
# Epoch 13, training RMSE = 8.11815, validation RMSE = 8.15819
# Epoch 14, training RMSE = 7.97932, validation RMSE = 7.99535
# Epoch 15, training RMSE = 7.88138, validation RMSE = 7.80394
# Epoch 16, training RMSE = 7.77409, validation RMSE = 7.69825
# Epoch 17, training RMSE = 7.67668, validation RMSE = 7.61284
# Epoch 18, training RMSE = 7.58181, validation RMSE = 7.56342
# Epoch 19, training RMSE = 7.50882, validation RMSE = 7.47108
# Epoch 20, training RMSE = 7.46568, validation RMSE = 7.37346
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.37346
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.1
# Epoch 1, training RMSE = 13.06882, validation RMSE = 12.47686
# Epoch 2, training RMSE = 12.25973, validation RMSE = 11.7868
# Epoch 3, training RMSE = 11.58423, validation RMSE = 11.2883
# Epoch 4, training RMSE = 10.9774, validation RMSE = 10.92611
# Epoch 5, training RMSE = 10.55232, validation RMSE = 10.34909
# Epoch 6, training RMSE = 10.17022, validation RMSE = 9.87628
# Epoch 7, training RMSE = 9.76456, validation RMSE = 9.59196
# Epoch 8, training RMSE = 9.41816, validation RMSE = 9.29636
# Epoch 9, training RMSE = 9.13342, validation RMSE = 8.99331
# Epoch 10, training RMSE = 8.86771, validation RMSE = 8.71662
# Epoch 11, training RMSE = 8.55656, validation RMSE = 8.67876
# Epoch 12, training RMSE = 8.39879, validation RMSE = 8.3726
# Epoch 13, training RMSE = 8.26183, validation RMSE = 8.0793
# Epoch 14, training RMSE = 8.03112, validation RMSE = 8.07486
# Epoch 15, training RMSE = 7.86831, validation RMSE = 7.97917
# Epoch 16, training RMSE = 7.80144, validation RMSE = 7.75458
# Epoch 17, training RMSE = 7.65129, validation RMSE = 7.7558
# Epoch 18, training RMSE = 7.60532, validation RMSE = 7.55856
# Epoch 19, training RMSE = 7.50459, validation RMSE = 7.54383
# Epoch 20, training RMSE = 7.41945, validation RMSE = 7.49975
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.49975
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.5
# Epoch 1, training RMSE = 13.41126, validation RMSE = 12.88628
# Epoch 2, training RMSE = 12.57453, validation RMSE = 12.20316
# Epoch 3, training RMSE = 11.92812, validation RMSE = 11.73249
# Epoch 4, training RMSE = 11.42818, validation RMSE = 11.11189
# Epoch 5, training RMSE = 10.94709, validation RMSE = 10.56648
# Epoch 6, training RMSE = 10.44449, validation RMSE = 10.31482
# Epoch 7, training RMSE = 10.07639, validation RMSE = 9.85167
# Epoch 8, training RMSE = 9.72691, validation RMSE = 9.48659
# Epoch 9, training RMSE = 9.34496, validation RMSE = 9.31053
# Epoch 10, training RMSE = 9.10748, validation RMSE = 8.90819
# Epoch 11, training RMSE = 8.79543, validation RMSE = 8.773
# Epoch 12, training RMSE = 8.59915, validation RMSE = 8.48166
# Epoch 13, training RMSE = 8.43555, validation RMSE = 8.17568
# Epoch 14, training RMSE = 8.23424, validation RMSE = 8.04008
# Epoch 15, training RMSE = 8.09234, validation RMSE = 7.8494
# Epoch 16, training RMSE = 7.84917, validation RMSE = 7.94575
# Epoch 17, training RMSE = 7.80532, validation RMSE = 7.65786
# Epoch 18, training RMSE = 7.67228, validation RMSE = 7.60682
# Epoch 19, training RMSE = 7.53666, validation RMSE = 7.64753
# Epoch 20, training RMSE = 7.53765, validation RMSE = 7.39162
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.39162
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 1
# Epoch 1, training RMSE = 13.14705, validation RMSE = 12.94438
# Epoch 2, training RMSE = 12.39606, validation RMSE = 12.08833
# Epoch 3, training RMSE = 11.80725, validation RMSE = 11.4068
# Epoch 4, training RMSE = 11.2413, validation RMSE = 10.99659
# Epoch 5, training RMSE = 10.73338, validation RMSE = 10.67824
# Epoch 6, training RMSE = 10.36175, validation RMSE = 10.16496
# Epoch 7, training RMSE = 9.96732, validation RMSE = 9.82609
# Epoch 8, training RMSE = 9.66434, validation RMSE = 9.40568
# Epoch 9, training RMSE = 9.30917, validation RMSE = 9.21983
# Epoch 10, training RMSE = 9.07982, validation RMSE = 8.85384
# Epoch 11, training RMSE = 8.78487, validation RMSE = 8.75074
# Epoch 12, training RMSE = 8.56325, validation RMSE = 8.5345
# Epoch 13, training RMSE = 8.38555, validation RMSE = 8.30114
# Epoch 14, training RMSE = 8.21821, validation RMSE = 8.11462
# Epoch 15, training RMSE = 8.06678, validation RMSE = 7.96141
# Epoch 16, training RMSE = 7.91185, validation RMSE = 7.88322
# Epoch 17, training RMSE = 7.81598, validation RMSE = 7.73437
# Epoch 18, training RMSE = 7.66332, validation RMSE = 7.77502
# Epoch 19, training RMSE = 7.59442, validation RMSE = 7.65149
# Epoch 20, training RMSE = 7.56993, validation RMSE = 7.44224
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 7.44224
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 5
# Epoch 1, training RMSE = 14.54719, validation RMSE = 14.00519
# Epoch 2, training RMSE = 13.26784, validation RMSE = 12.71742
# Epoch 3, training RMSE = 12.20535, validation RMSE = 11.83771
# Epoch 4, training RMSE = 11.47713, validation RMSE = 11.22666
# Epoch 5, training RMSE = 10.94605, validation RMSE = 10.70146
# Epoch 6, training RMSE = 10.48355, validation RMSE = 10.28323
# Epoch 7, training RMSE = 10.13735, validation RMSE = 9.77383
# Epoch 8, training RMSE = 9.7259, validation RMSE = 9.57075
# Epoch 9, training RMSE = 9.39606, validation RMSE = 9.31174
# Epoch 10, training RMSE = 9.1441, validation RMSE = 8.98588
# Epoch 11, training RMSE = 8.93465, validation RMSE = 8.65633
# Epoch 12, training RMSE = 8.64471, validation RMSE = 8.61075
# Epoch 13, training RMSE = 8.47599, validation RMSE = 8.3451
# Epoch 14, training RMSE = 8.29705, validation RMSE = 8.20963
# Epoch 15, training RMSE = 8.12046, validation RMSE = 8.12069
# Epoch 16, training RMSE = 8.0572, validation RMSE = 7.82155
# Epoch 17, training RMSE = 7.87662, validation RMSE = 7.87019
# Epoch 18, training RMSE = 7.75988, validation RMSE = 7.82788
# Epoch 19, training RMSE = 7.71127, validation RMSE = 7.64311
# Epoch 20, training RMSE = 7.5951, validation RMSE = 7.6601
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 7.64311
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.001
# Epoch 1, training RMSE = 12.48147, validation RMSE = 11.28605
# Epoch 2, training RMSE = 10.68849, validation RMSE = 10.24145
# Epoch 3, training RMSE = 9.63867, validation RMSE = 9.2862
# Epoch 4, training RMSE = 8.82809, validation RMSE = 8.75076
# Epoch 5, training RMSE = 8.35298, validation RMSE = 8.1389
# Epoch 6, training RMSE = 7.97357, validation RMSE = 7.85197
# Epoch 7, training RMSE = 7.70041, validation RMSE = 7.67842
# Epoch 8, training RMSE = 7.52558, validation RMSE = 7.49938
# Epoch 9, training RMSE = 7.35974, validation RMSE = 7.42467
# Epoch 10, training RMSE = 7.26809, validation RMSE = 7.28509
# Epoch 11, training RMSE = 7.26988, validation RMSE = 6.94042
# Epoch 12, training RMSE = 7.13791, validation RMSE = 6.93988
# Epoch 13, training RMSE = 6.95594, validation RMSE = 7.09413
# Epoch 14, training RMSE = 6.89149, validation RMSE = 6.9626
# Epoch 15, training RMSE = 6.80201, validation RMSE = 6.89375
# Epoch 16, training RMSE = 6.73154, validation RMSE = 6.80277
# Epoch 17, training RMSE = 6.69656, validation RMSE = 6.63314
# Epoch 18, training RMSE = 6.5856, validation RMSE = 6.65421
# Epoch 19, training RMSE = 6.55276, validation RMSE = 6.48264
# Epoch 20, training RMSE = 6.47516, validation RMSE = 6.4432
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.4432
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.005
# Epoch 1, training RMSE = 12.26921, validation RMSE = 11.45098
# Epoch 2, training RMSE = 10.62902, validation RMSE = 10.15508
# Epoch 3, training RMSE = 9.56095, validation RMSE = 9.29762
# Epoch 4, training RMSE = 8.88881, validation RMSE = 8.50321
# Epoch 5, training RMSE = 8.35997, validation RMSE = 8.06479
# Epoch 6, training RMSE = 7.98204, validation RMSE = 7.78968
# Epoch 7, training RMSE = 7.69293, validation RMSE = 7.63851
# Epoch 8, training RMSE = 7.47988, validation RMSE = 7.55054
# Epoch 9, training RMSE = 7.38334, validation RMSE = 7.33863
# Epoch 10, training RMSE = 7.22265, validation RMSE = 7.37213
# Epoch 11, training RMSE = 7.21157, validation RMSE = 7.05781
# Epoch 12, training RMSE = 7.09747, validation RMSE = 7.01016
# Epoch 13, training RMSE = 7.01937, validation RMSE = 6.93252
# Epoch 14, training RMSE = 6.96409, validation RMSE = 6.77934
# Epoch 15, training RMSE = 6.83936, validation RMSE = 6.8057
# Epoch 16, training RMSE = 6.72581, validation RMSE = 6.80974
# Epoch 17, training RMSE = 6.67354, validation RMSE = 6.67303
# Epoch 18, training RMSE = 6.63525, validation RMSE = 6.53463
# Epoch 19, training RMSE = 6.58292, validation RMSE = 6.41283
# Epoch 20, training RMSE = 6.48963, validation RMSE = 6.39789
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.39789
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.01
# Epoch 1, training RMSE = 12.73963, validation RMSE = 11.7671
# Epoch 2, training RMSE = 10.96455, validation RMSE = 10.50218
# Epoch 3, training RMSE = 9.86228, validation RMSE = 9.52624
# Epoch 4, training RMSE = 9.10798, validation RMSE = 8.79753
# Epoch 5, training RMSE = 8.55955, validation RMSE = 8.25091
# Epoch 6, training RMSE = 8.14853, validation RMSE = 7.92203
# Epoch 7, training RMSE = 7.83175, validation RMSE = 7.73835
# Epoch 8, training RMSE = 7.61899, validation RMSE = 7.57519
# Epoch 9, training RMSE = 7.46286, validation RMSE = 7.44726
# Epoch 10, training RMSE = 7.3623, validation RMSE = 7.30037
# Epoch 11, training RMSE = 7.25547, validation RMSE = 7.21969
# Epoch 12, training RMSE = 7.13355, validation RMSE = 7.21328
# Epoch 13, training RMSE = 7.11582, validation RMSE = 6.95901
# Epoch 14, training RMSE = 6.98798, validation RMSE = 6.98059
# Epoch 15, training RMSE = 6.88497, validation RMSE = 6.95714
# Epoch 16, training RMSE = 6.836, validation RMSE = 6.81768
# Epoch 17, training RMSE = 6.7702, validation RMSE = 6.72626
# Epoch 18, training RMSE = 6.67893, validation RMSE = 6.7032
# Epoch 19, training RMSE = 6.58583, validation RMSE = 6.66835
# Epoch 20, training RMSE = 6.50788, validation RMSE = 6.62646
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.62646
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.05
# Epoch 1, training RMSE = 12.72254, validation RMSE = 11.64402
# Epoch 2, training RMSE = 11.03749, validation RMSE = 10.28836
# Epoch 3, training RMSE = 9.92797, validation RMSE = 9.488
# Epoch 4, training RMSE = 9.22965, validation RMSE = 8.67889
# Epoch 5, training RMSE = 8.65847, validation RMSE = 8.20681
# Epoch 6, training RMSE = 8.18991, validation RMSE = 7.98754
# Epoch 7, training RMSE = 7.89098, validation RMSE = 7.71572
# Epoch 8, training RMSE = 7.63566, validation RMSE = 7.61924
# Epoch 9, training RMSE = 7.51247, validation RMSE = 7.38283
# Epoch 10, training RMSE = 7.37497, validation RMSE = 7.28698
# Epoch 11, training RMSE = 7.18642, validation RMSE = 7.35655
# Epoch 12, training RMSE = 7.1834, validation RMSE = 7.08593
# Epoch 13, training RMSE = 7.05547, validation RMSE = 7.09342
# Epoch 14, training RMSE = 7.0074, validation RMSE = 6.94114
# Epoch 15, training RMSE = 6.94113, validation RMSE = 6.82708
# Epoch 16, training RMSE = 6.82628, validation RMSE = 6.81554
# Epoch 17, training RMSE = 6.76384, validation RMSE = 6.71896
# Epoch 18, training RMSE = 6.67741, validation RMSE = 6.66228
# Epoch 19, training RMSE = 6.62264, validation RMSE = 6.55722
# Epoch 20, training RMSE = 6.5384, validation RMSE = 6.52985
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.52985
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.1
# Epoch 1, training RMSE = 12.52333, validation RMSE = 11.6933
# Epoch 2, training RMSE = 10.90684, validation RMSE = 10.50255
# Epoch 3, training RMSE = 9.92492, validation RMSE = 9.46399
# Epoch 4, training RMSE = 9.20996, validation RMSE = 8.66912
# Epoch 5, training RMSE = 8.59128, validation RMSE = 8.31826
# Epoch 6, training RMSE = 8.20285, validation RMSE = 7.88437
# Epoch 7, training RMSE = 7.89562, validation RMSE = 7.62738
# Epoch 8, training RMSE = 7.64929, validation RMSE = 7.5207
# Epoch 9, training RMSE = 7.4989, validation RMSE = 7.37889
# Epoch 10, training RMSE = 7.29668, validation RMSE = 7.4452
# Epoch 11, training RMSE = 7.22246, validation RMSE = 7.31298
# Epoch 12, training RMSE = 7.16024, validation RMSE = 7.15132
# Epoch 13, training RMSE = 7.09758, validation RMSE = 7.00323
# Epoch 14, training RMSE = 6.97808, validation RMSE = 6.99512
# Epoch 15, training RMSE = 6.85039, validation RMSE = 7.03918
# Epoch 16, training RMSE = 6.83035, validation RMSE = 6.81434
# Epoch 17, training RMSE = 6.81624, validation RMSE = 6.60467
# Epoch 18, training RMSE = 6.63916, validation RMSE = 6.75657
# Epoch 19, training RMSE = 6.64704, validation RMSE = 6.52638
# Epoch 20, training RMSE = 6.5822, validation RMSE = 6.43253
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.43253
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.5
# Epoch 1, training RMSE = 12.75824, validation RMSE = 11.89824
# Epoch 2, training RMSE = 11.24802, validation RMSE = 10.71763
# Epoch 3, training RMSE = 10.1715, validation RMSE = 9.73242
# Epoch 4, training RMSE = 9.41168, validation RMSE = 8.87176
# Epoch 5, training RMSE = 8.72571, validation RMSE = 8.50609
# Epoch 6, training RMSE = 8.25434, validation RMSE = 8.14905
# Epoch 7, training RMSE = 7.87414, validation RMSE = 7.95513
# Epoch 8, training RMSE = 7.72193, validation RMSE = 7.53265
# Epoch 9, training RMSE = 7.5271, validation RMSE = 7.39967
# Epoch 10, training RMSE = 7.3973, validation RMSE = 7.28841
# Epoch 11, training RMSE = 7.22492, validation RMSE = 7.33525
# Epoch 12, training RMSE = 7.20438, validation RMSE = 7.05714
# Epoch 13, training RMSE = 7.1199, validation RMSE = 6.95037
# Epoch 14, training RMSE = 7.0057, validation RMSE = 6.95035
# Epoch 15, training RMSE = 6.95959, validation RMSE = 6.77784
# Epoch 16, training RMSE = 6.85207, validation RMSE = 6.76258
# Epoch 17, training RMSE = 6.76976, validation RMSE = 6.69368
# Epoch 18, training RMSE = 6.68577, validation RMSE = 6.6263
# Epoch 19, training RMSE = 6.63111, validation RMSE = 6.50957
# Epoch 20, training RMSE = 6.50472, validation RMSE = 6.59586
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 6.50957
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 1
# Epoch 1, training RMSE = 12.9232, validation RMSE = 11.9768
# Epoch 2, training RMSE = 11.43079, validation RMSE = 10.58691
# Epoch 3, training RMSE = 10.2542, validation RMSE = 9.8998
# Epoch 4, training RMSE = 9.49195, validation RMSE = 9.09425
# Epoch 5, training RMSE = 8.83592, validation RMSE = 8.67069
# Epoch 6, training RMSE = 8.39952, validation RMSE = 8.23305
# Epoch 7, training RMSE = 8.05518, validation RMSE = 7.94063
# Epoch 8, training RMSE = 7.79292, validation RMSE = 7.76435
# Epoch 9, training RMSE = 7.59111, validation RMSE = 7.62369
# Epoch 10, training RMSE = 7.47359, validation RMSE = 7.43734
# Epoch 11, training RMSE = 7.41631, validation RMSE = 7.2015
# Epoch 12, training RMSE = 7.24281, validation RMSE = 7.27063
# Epoch 13, training RMSE = 7.15737, validation RMSE = 7.17267
# Epoch 14, training RMSE = 7.07392, validation RMSE = 7.05838
# Epoch 15, training RMSE = 6.99518, validation RMSE = 6.9482
# Epoch 16, training RMSE = 6.89306, validation RMSE = 6.90059
# Epoch 17, training RMSE = 6.8331, validation RMSE = 6.77393
# Epoch 18, training RMSE = 6.74665, validation RMSE = 6.71724
# Epoch 19, training RMSE = 6.70311, validation RMSE = 6.5695
# Epoch 20, training RMSE = 6.60223, validation RMSE = 6.53017
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.53017
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 5
# Epoch 1, training RMSE = 13.67682, validation RMSE = 12.40379
# Epoch 2, training RMSE = 11.43152, validation RMSE = 10.69013
# Epoch 3, training RMSE = 10.20333, validation RMSE = 9.73558
# Epoch 4, training RMSE = 9.33759, validation RMSE = 9.09264
# Epoch 5, training RMSE = 8.75684, validation RMSE = 8.55483
# Epoch 6, training RMSE = 8.36322, validation RMSE = 8.09591
# Epoch 7, training RMSE = 7.96397, validation RMSE = 8.03187
# Epoch 8, training RMSE = 7.87724, validation RMSE = 7.51773
# Epoch 9, training RMSE = 7.65605, validation RMSE = 7.50013
# Epoch 10, training RMSE = 7.47908, validation RMSE = 7.49519
# Epoch 11, training RMSE = 7.39857, validation RMSE = 7.32313
# Epoch 12, training RMSE = 7.32163, validation RMSE = 7.19193
# Epoch 13, training RMSE = 7.21799, validation RMSE = 7.13129
# Epoch 14, training RMSE = 7.10998, validation RMSE = 7.06402
# Epoch 15, training RMSE = 7.01691, validation RMSE = 6.9905
# Epoch 16, training RMSE = 6.89236, validation RMSE = 7.01887
# Epoch 17, training RMSE = 6.84956, validation RMSE = 6.8513
# Epoch 18, training RMSE = 6.85383, validation RMSE = 6.57238
# Epoch 19, training RMSE = 6.71956, validation RMSE = 6.6279
# Epoch 20, training RMSE = 6.64514, validation RMSE = 6.56113
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 6.56113
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.001
# Epoch 1, training RMSE = 11.63166, validation RMSE = 10.27546
# Epoch 2, training RMSE = 9.2697, validation RMSE = 8.69167
# Epoch 3, training RMSE = 8.21134, validation RMSE = 7.83581
# Epoch 4, training RMSE = 7.64877, validation RMSE = 7.5069
# Epoch 5, training RMSE = 7.32703, validation RMSE = 7.38493
# Epoch 6, training RMSE = 7.13809, validation RMSE = 7.19628
# Epoch 7, training RMSE = 6.98267, validation RMSE = 7.06489
# Epoch 8, training RMSE = 6.91118, validation RMSE = 6.76106
# Epoch 9, training RMSE = 6.74486, validation RMSE = 6.6614
# Epoch 10, training RMSE = 6.59407, validation RMSE = 6.59026
# Epoch 11, training RMSE = 6.56055, validation RMSE = 6.27083
# Epoch 12, training RMSE = 6.33966, validation RMSE = 6.41926
# Epoch 13, training RMSE = 6.26035, validation RMSE = 6.2886
# Epoch 14, training RMSE = 6.19353, validation RMSE = 6.11729
# Epoch 15, training RMSE = 6.08774, validation RMSE = 6.07897
# Epoch 16, training RMSE = 5.97776, validation RMSE = 6.05467
# Epoch 17, training RMSE = 5.92673, validation RMSE = 5.94394
# Epoch 18, training RMSE = 5.86558, validation RMSE = 5.84749
# Epoch 19, training RMSE = 5.8292, validation RMSE = 5.72783
# Epoch 20, training RMSE = 5.69311, validation RMSE = 5.8486
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 5.72783
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.005
# Epoch 1, training RMSE = 11.70467, validation RMSE = 10.05631
# Epoch 2, training RMSE = 9.26452, validation RMSE = 8.63565
# Epoch 3, training RMSE = 8.20119, validation RMSE = 7.83929
# Epoch 4, training RMSE = 7.6605, validation RMSE = 7.4433
# Epoch 5, training RMSE = 7.3458, validation RMSE = 7.26828
# Epoch 6, training RMSE = 7.13728, validation RMSE = 7.16931
# Epoch 7, training RMSE = 6.98775, validation RMSE = 7.03305
# Epoch 8, training RMSE = 6.82294, validation RMSE = 6.94619
# Epoch 9, training RMSE = 6.71643, validation RMSE = 6.76032
# Epoch 10, training RMSE = 6.64062, validation RMSE = 6.52647
# Epoch 11, training RMSE = 6.50515, validation RMSE = 6.43471
# Epoch 12, training RMSE = 6.38795, validation RMSE = 6.34698
# Epoch 13, training RMSE = 6.27611, validation RMSE = 6.28697
# Epoch 14, training RMSE = 6.22109, validation RMSE = 6.08478
# Epoch 15, training RMSE = 6.10912, validation RMSE = 6.07649
# Epoch 16, training RMSE = 5.99775, validation RMSE = 6.08453
# Epoch 17, training RMSE = 5.99665, validation RMSE = 5.8277
# Epoch 18, training RMSE = 5.89333, validation RMSE = 5.85083
# Epoch 19, training RMSE = 5.86863, validation RMSE = 5.69647
# Epoch 20, training RMSE = 5.7664, validation RMSE = 5.74759
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 5.69647
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.01
# Epoch 1, training RMSE = 11.50058, validation RMSE = 10.06736
# Epoch 2, training RMSE = 9.18974, validation RMSE = 8.51263
# Epoch 3, training RMSE = 8.17061, validation RMSE = 7.664
# Epoch 4, training RMSE = 7.55317, validation RMSE = 7.51871
# Epoch 5, training RMSE = 7.33467, validation RMSE = 7.19037
# Epoch 6, training RMSE = 7.15511, validation RMSE = 7.00157
# Epoch 7, training RMSE = 6.99585, validation RMSE = 6.85827
# Epoch 8, training RMSE = 6.8125, validation RMSE = 6.83449
# Epoch 9, training RMSE = 6.6794, validation RMSE = 6.70002
# Epoch 10, training RMSE = 6.57319, validation RMSE = 6.52791
# Epoch 11, training RMSE = 6.45935, validation RMSE = 6.41039
# Epoch 12, training RMSE = 6.33581, validation RMSE = 6.34145
# Epoch 13, training RMSE = 6.21822, validation RMSE = 6.31078
# Epoch 14, training RMSE = 6.19645, validation RMSE = 6.05986
# Epoch 15, training RMSE = 6.02882, validation RMSE = 6.16689
# Epoch 16, training RMSE = 5.98359, validation RMSE = 6.00942
# Epoch 17, training RMSE = 5.92316, validation RMSE = 5.92196
# Epoch 18, training RMSE = 5.89087, validation RMSE = 5.78586
# Epoch 19, training RMSE = 5.77526, validation RMSE = 5.85022
# Epoch 20, training RMSE = 5.7492, validation RMSE = 5.73532
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.73532
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.05
# Epoch 1, training RMSE = 11.70286, validation RMSE = 10.28113
# Epoch 2, training RMSE = 9.51464, validation RMSE = 8.61309
# Epoch 3, training RMSE = 8.37913, validation RMSE = 7.85454
# Epoch 4, training RMSE = 7.71508, validation RMSE = 7.57705
# Epoch 5, training RMSE = 7.42193, validation RMSE = 7.27274
# Epoch 6, training RMSE = 7.1997, validation RMSE = 7.17743
# Epoch 7, training RMSE = 7.07532, validation RMSE = 6.94213
# Epoch 8, training RMSE = 7.00636, validation RMSE = 6.62523
# Epoch 9, training RMSE = 6.74708, validation RMSE = 6.77017
# Epoch 10, training RMSE = 6.64661, validation RMSE = 6.57792
# Epoch 11, training RMSE = 6.49605, validation RMSE = 6.55087
# Epoch 12, training RMSE = 6.46992, validation RMSE = 6.24453
# Epoch 13, training RMSE = 6.30659, validation RMSE = 6.29747
# Epoch 14, training RMSE = 6.24261, validation RMSE = 6.14303
# Epoch 15, training RMSE = 6.14509, validation RMSE = 6.0889
# Epoch 16, training RMSE = 5.9937, validation RMSE = 6.16137
# Epoch 17, training RMSE = 5.99821, validation RMSE = 5.90496
# Epoch 18, training RMSE = 5.87547, validation RMSE = 5.97157
# Epoch 19, training RMSE = 5.82495, validation RMSE = 5.87948
# Epoch 20, training RMSE = 5.76309, validation RMSE = 5.81215
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.81215
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.1
# Epoch 1, training RMSE = 11.89712, validation RMSE = 10.44918
# Epoch 2, training RMSE = 9.58423, validation RMSE = 8.93109
# Epoch 3, training RMSE = 8.40185, validation RMSE = 8.03502
# Epoch 4, training RMSE = 7.76391, validation RMSE = 7.56907
# Epoch 5, training RMSE = 7.42505, validation RMSE = 7.30831
# Epoch 6, training RMSE = 7.26203, validation RMSE = 7.01613
# Epoch 7, training RMSE = 7.02577, validation RMSE = 7.05917
# Epoch 8, training RMSE = 6.8829, validation RMSE = 6.96425
# Epoch 9, training RMSE = 6.83521, validation RMSE = 6.62221
# Epoch 10, training RMSE = 6.67733, validation RMSE = 6.55429
# Epoch 11, training RMSE = 6.55114, validation RMSE = 6.47237
# Epoch 12, training RMSE = 6.37583, validation RMSE = 6.52595
# Epoch 13, training RMSE = 6.32647, validation RMSE = 6.31638
# Epoch 14, training RMSE = 6.23128, validation RMSE = 6.23386
# Epoch 15, training RMSE = 6.1354, validation RMSE = 6.16374
# Epoch 16, training RMSE = 6.07514, validation RMSE = 6.03418
# Epoch 17, training RMSE = 5.97472, validation RMSE = 6.02829
# Epoch 18, training RMSE = 5.9317, validation RMSE = 5.90645
# Epoch 19, training RMSE = 5.83534, validation RMSE = 5.90138
# Epoch 20, training RMSE = 5.7697, validation RMSE = 5.87289
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.87289
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.5
# Epoch 1, training RMSE = 12.30405, validation RMSE = 10.87863
# Epoch 2, training RMSE = 9.99731, validation RMSE = 9.18974
# Epoch 3, training RMSE = 8.64328, validation RMSE = 8.34909
# Epoch 4, training RMSE = 7.95066, validation RMSE = 7.79941
# Epoch 5, training RMSE = 7.57117, validation RMSE = 7.47881
# Epoch 6, training RMSE = 7.32762, validation RMSE = 7.2917
# Epoch 7, training RMSE = 7.20878, validation RMSE = 7.00969
# Epoch 8, training RMSE = 6.95723, validation RMSE = 7.11607
# Epoch 9, training RMSE = 6.87187, validation RMSE = 6.85825
# Epoch 10, training RMSE = 6.73408, validation RMSE = 6.72513
# Epoch 11, training RMSE = 6.64627, validation RMSE = 6.53419
# Epoch 12, training RMSE = 6.58947, validation RMSE = 6.2686
# Epoch 13, training RMSE = 6.36569, validation RMSE = 6.45401
# Epoch 14, training RMSE = 6.34945, validation RMSE = 6.17215
# Epoch 15, training RMSE = 6.20238, validation RMSE = 6.19895
# Epoch 16, training RMSE = 6.12332, validation RMSE = 6.11558
# Epoch 17, training RMSE = 6.05991, validation RMSE = 5.98081
# Epoch 18, training RMSE = 5.94389, validation RMSE = 5.99742
# Epoch 19, training RMSE = 5.90141, validation RMSE = 5.87852
# Epoch 20, training RMSE = 5.81454, validation RMSE = 5.86757
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.86757
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 1
# Epoch 1, training RMSE = 12.08985, validation RMSE = 10.70255
# Epoch 2, training RMSE = 9.87884, validation RMSE = 9.00544
# Epoch 3, training RMSE = 8.56421, validation RMSE = 8.22476
# Epoch 4, training RMSE = 7.8445, validation RMSE = 7.80195
# Epoch 5, training RMSE = 7.5612, validation RMSE = 7.31375
# Epoch 6, training RMSE = 7.33714, validation RMSE = 7.12124
# Epoch 7, training RMSE = 7.10224, validation RMSE = 7.12407
# Epoch 8, training RMSE = 6.996, validation RMSE = 6.90317
# Epoch 9, training RMSE = 6.86375, validation RMSE = 6.73277
# Epoch 10, training RMSE = 6.72836, validation RMSE = 6.62167
# Epoch 11, training RMSE = 6.5811, validation RMSE = 6.54441
# Epoch 12, training RMSE = 6.45319, validation RMSE = 6.44703
# Epoch 13, training RMSE = 6.33138, validation RMSE = 6.36461
# Epoch 14, training RMSE = 6.22563, validation RMSE = 6.29994
# Epoch 15, training RMSE = 6.16909, validation RMSE = 6.14831
# Epoch 16, training RMSE = 6.10727, validation RMSE = 5.99322
# Epoch 17, training RMSE = 6.04471, validation RMSE = 5.87724
# Epoch 18, training RMSE = 5.9264, validation RMSE = 5.91151
# Epoch 19, training RMSE = 5.87349, validation RMSE = 5.8206
# Epoch 20, training RMSE = 5.80908, validation RMSE = 5.76489
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.76489
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 5
# Epoch 1, training RMSE = 12.78508, validation RMSE = 10.85513
# Epoch 2, training RMSE = 9.92772, validation RMSE = 9.12429
# Epoch 3, training RMSE = 8.60678, validation RMSE = 8.34762
# Epoch 4, training RMSE = 7.93813, validation RMSE = 7.82794
# Epoch 5, training RMSE = 7.64351, validation RMSE = 7.39102
# Epoch 6, training RMSE = 7.33807, validation RMSE = 7.42509
# Epoch 7, training RMSE = 7.25254, validation RMSE = 7.02613
# Epoch 8, training RMSE = 7.01422, validation RMSE = 7.07956
# Epoch 9, training RMSE = 6.87614, validation RMSE = 6.932
# Epoch 10, training RMSE = 6.78222, validation RMSE = 6.71313
# Epoch 11, training RMSE = 6.65187, validation RMSE = 6.5894
# Epoch 12, training RMSE = 6.51321, validation RMSE = 6.50974
# Epoch 13, training RMSE = 6.42564, validation RMSE = 6.34248
# Epoch 14, training RMSE = 6.31378, validation RMSE = 6.26579
# Epoch 15, training RMSE = 6.22011, validation RMSE = 6.14776
# Epoch 16, training RMSE = 6.14473, validation RMSE = 6.05932
# Epoch 17, training RMSE = 6.02351, validation RMSE = 6.07335
# Epoch 18, training RMSE = 5.96079, validation RMSE = 5.97086
# Epoch 19, training RMSE = 5.84101, validation RMSE = 6.00949
# Epoch 20, training RMSE = 5.80672, validation RMSE = 5.87902
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.87902
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.001
# Epoch 1, training RMSE = 10.16369, validation RMSE = 8.14744
# Epoch 2, training RMSE = 7.63631, validation RMSE = 7.34461
# Epoch 3, training RMSE = 7.16268, validation RMSE = 6.88529
# Epoch 4, training RMSE = 6.80262, validation RMSE = 6.61621
# Epoch 5, training RMSE = 6.51013, validation RMSE = 6.37331
# Epoch 6, training RMSE = 6.29895, validation RMSE = 6.13699
# Epoch 7, training RMSE = 6.06713, validation RMSE = 6.06019
# Epoch 8, training RMSE = 5.86712, validation RMSE = 5.99797
# Epoch 9, training RMSE = 5.81423, validation RMSE = 5.69397
# Epoch 10, training RMSE = 5.68989, validation RMSE = 5.6375
# Epoch 11, training RMSE = 5.61823, validation RMSE = 5.58537
# Epoch 12, training RMSE = 5.47452, validation RMSE = 5.52575
# Epoch 13, training RMSE = 5.43639, validation RMSE = 5.447
# Epoch 14, training RMSE = 5.37868, validation RMSE = 5.35743
# Epoch 15, training RMSE = 5.30111, validation RMSE = 5.30795
# Epoch 16, training RMSE = 5.26027, validation RMSE = 5.26117
# Epoch 17, training RMSE = 5.22929, validation RMSE = 5.15403
# Epoch 18, training RMSE = 5.11961, validation RMSE = 5.30854
# Epoch 19, training RMSE = 5.12986, validation RMSE = 5.1298
# Epoch 20, training RMSE = 5.10609, validation RMSE = 5.07507
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.07507
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.005
# Epoch 1, training RMSE = 10.1332, validation RMSE = 8.29421
# Epoch 2, training RMSE = 7.62578, validation RMSE = 7.2844
# Epoch 3, training RMSE = 7.11329, validation RMSE = 6.8974
# Epoch 4, training RMSE = 6.76487, validation RMSE = 6.66349
# Epoch 5, training RMSE = 6.55746, validation RMSE = 6.26852
# Epoch 6, training RMSE = 6.31059, validation RMSE = 6.11268
# Epoch 7, training RMSE = 6.11403, validation RMSE = 5.92044
# Epoch 8, training RMSE = 5.9371, validation RMSE = 5.84169
# Epoch 9, training RMSE = 5.81156, validation RMSE = 5.73023
# Epoch 10, training RMSE = 5.65209, validation RMSE = 5.74729
# Epoch 11, training RMSE = 5.60339, validation RMSE = 5.65222
# Epoch 12, training RMSE = 5.50328, validation RMSE = 5.51965
# Epoch 13, training RMSE = 5.41892, validation RMSE = 5.44941
# Epoch 14, training RMSE = 5.39263, validation RMSE = 5.2962
# Epoch 15, training RMSE = 5.31346, validation RMSE = 5.32783
# Epoch 16, training RMSE = 5.25128, validation RMSE = 5.36814
# Epoch 17, training RMSE = 5.23508, validation RMSE = 5.15002
# Epoch 18, training RMSE = 5.16464, validation RMSE = 5.1856
# Epoch 19, training RMSE = 5.11489, validation RMSE = 5.18992
# Epoch 20, training RMSE = 5.10432, validation RMSE = 5.10157
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.10157
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.01
# Epoch 1, training RMSE = 9.99614, validation RMSE = 8.24541
# Epoch 2, training RMSE = 7.67129, validation RMSE = 7.09838
# Epoch 3, training RMSE = 7.06377, validation RMSE = 6.94512
# Epoch 4, training RMSE = 6.82162, validation RMSE = 6.44591
# Epoch 5, training RMSE = 6.47973, validation RMSE = 6.36103
# Epoch 6, training RMSE = 6.2504, validation RMSE = 6.16521
# Epoch 7, training RMSE = 6.0737, validation RMSE = 6.03742
# Epoch 8, training RMSE = 5.91232, validation RMSE = 5.86157
# Epoch 9, training RMSE = 5.77512, validation RMSE = 5.77655
# Epoch 10, training RMSE = 5.72528, validation RMSE = 5.51659
# Epoch 11, training RMSE = 5.57251, validation RMSE = 5.58959
# Epoch 12, training RMSE = 5.45304, validation RMSE = 5.5652
# Epoch 13, training RMSE = 5.40504, validation RMSE = 5.53375
# Epoch 14, training RMSE = 5.39635, validation RMSE = 5.24924
# Epoch 15, training RMSE = 5.25832, validation RMSE = 5.44874
# Epoch 16, training RMSE = 5.24207, validation RMSE = 5.28181
# Epoch 17, training RMSE = 5.25607, validation RMSE = 5.09241
# Epoch 18, training RMSE = 5.18038, validation RMSE = 5.15049
# Epoch 19, training RMSE = 5.12911, validation RMSE = 5.14292
# Epoch 20, training RMSE = 5.14821, validation RMSE = 5.00604
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.00604
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.05
# Epoch 1, training RMSE = 10.02625, validation RMSE = 8.2037
# Epoch 2, training RMSE = 7.63694, validation RMSE = 7.30073
# Epoch 3, training RMSE = 7.13614, validation RMSE = 6.82292
# Epoch 4, training RMSE = 6.72745, validation RMSE = 6.71429
# Epoch 5, training RMSE = 6.49727, validation RMSE = 6.33744
# Epoch 6, training RMSE = 6.29262, validation RMSE = 6.09761
# Epoch 7, training RMSE = 6.10647, validation RMSE = 5.96407
# Epoch 8, training RMSE = 5.98813, validation RMSE = 5.70372
# Epoch 9, training RMSE = 5.76227, validation RMSE = 5.81682
# Epoch 10, training RMSE = 5.67186, validation RMSE = 5.69173
# Epoch 11, training RMSE = 5.57745, validation RMSE = 5.60445
# Epoch 12, training RMSE = 5.51817, validation RMSE = 5.47112
# Epoch 13, training RMSE = 5.42907, validation RMSE = 5.43096
# Epoch 14, training RMSE = 5.41297, validation RMSE = 5.27831
# Epoch 15, training RMSE = 5.34005, validation RMSE = 5.25359
# Epoch 16, training RMSE = 5.24017, validation RMSE = 5.29989
# Epoch 17, training RMSE = 5.27367, validation RMSE = 5.11721
# Epoch 18, training RMSE = 5.15164, validation RMSE = 5.25546
# Epoch 19, training RMSE = 5.15197, validation RMSE = 5.16236
# Epoch 20, training RMSE = 5.08251, validation RMSE = 5.16107
# ==========Model result==========
# Best epoch is 17 with minimum validation error = 5.11721
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.1
# Epoch 1, training RMSE = 10.70556, validation RMSE = 8.61079
# Epoch 2, training RMSE = 7.8688, validation RMSE = 7.55194
# Epoch 3, training RMSE = 7.19145, validation RMSE = 7.23041
# Epoch 4, training RMSE = 6.90098, validation RMSE = 6.71287
# Epoch 5, training RMSE = 6.60769, validation RMSE = 6.50227
# Epoch 6, training RMSE = 6.38966, validation RMSE = 6.23255
# Epoch 7, training RMSE = 6.1882, validation RMSE = 6.06065
# Epoch 8, training RMSE = 6.02207, validation RMSE = 5.90282
# Epoch 9, training RMSE = 5.8826, validation RMSE = 5.80664
# Epoch 10, training RMSE = 5.76159, validation RMSE = 5.66902
# Epoch 11, training RMSE = 5.68754, validation RMSE = 5.57219
# Epoch 12, training RMSE = 5.59398, validation RMSE = 5.5045
# Epoch 13, training RMSE = 5.51777, validation RMSE = 5.39435
# Epoch 14, training RMSE = 5.43149, validation RMSE = 5.35372
# Epoch 15, training RMSE = 5.37321, validation RMSE = 5.27063
# Epoch 16, training RMSE = 5.26422, validation RMSE = 5.35905
# Epoch 17, training RMSE = 5.26252, validation RMSE = 5.21513
# Epoch 18, training RMSE = 5.20087, validation RMSE = 5.22372
# Epoch 19, training RMSE = 5.11471, validation RMSE = 5.28085
# Epoch 20, training RMSE = 5.14165, validation RMSE = 5.11752
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.11752
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.5
# Epoch 1, training RMSE = 10.33021, validation RMSE = 8.36503
# Epoch 2, training RMSE = 7.70664, validation RMSE = 7.36654
# Epoch 3, training RMSE = 7.09445, validation RMSE = 7.01383
# Epoch 4, training RMSE = 6.78897, validation RMSE = 6.66716
# Epoch 5, training RMSE = 6.48634, validation RMSE = 6.4683
# Epoch 6, training RMSE = 6.298, validation RMSE = 6.13724
# Epoch 7, training RMSE = 6.10442, validation RMSE = 6.01647
# Epoch 8, training RMSE = 5.93913, validation RMSE = 5.87177
# Epoch 9, training RMSE = 5.80207, validation RMSE = 5.74982
# Epoch 10, training RMSE = 5.7048, validation RMSE = 5.66756
# Epoch 11, training RMSE = 5.59826, validation RMSE = 5.57929
# Epoch 12, training RMSE = 5.48931, validation RMSE = 5.54332
# Epoch 13, training RMSE = 5.47371, validation RMSE = 5.33535
# Epoch 14, training RMSE = 5.39397, validation RMSE = 5.32362
# Epoch 15, training RMSE = 5.2975, validation RMSE = 5.35244
# Epoch 16, training RMSE = 5.22458, validation RMSE = 5.36383
# Epoch 17, training RMSE = 5.21248, validation RMSE = 5.32185
# Epoch 18, training RMSE = 5.21742, validation RMSE = 5.09691
# Epoch 19, training RMSE = 5.16531, validation RMSE = 5.08606
# Epoch 20, training RMSE = 5.09063, validation RMSE = 5.16517
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 5.08606
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 1
# Epoch 1, training RMSE = 10.78232, validation RMSE = 8.43688
# Epoch 2, training RMSE = 7.90055, validation RMSE = 7.52591
# Epoch 3, training RMSE = 7.28484, validation RMSE = 7.05161
# Epoch 4, training RMSE = 6.93738, validation RMSE = 6.75284
# Epoch 5, training RMSE = 6.69438, validation RMSE = 6.37373
# Epoch 6, training RMSE = 6.41297, validation RMSE = 6.25466
# Epoch 7, training RMSE = 6.1971, validation RMSE = 6.07392
# Epoch 8, training RMSE = 6.04711, validation RMSE = 5.84908
# Epoch 9, training RMSE = 5.87033, validation RMSE = 5.82347
# Epoch 10, training RMSE = 5.77655, validation RMSE = 5.63313
# Epoch 11, training RMSE = 5.65811, validation RMSE = 5.57341
# Epoch 12, training RMSE = 5.58811, validation RMSE = 5.44409
# Epoch 13, training RMSE = 5.52522, validation RMSE = 5.3337
# Epoch 14, training RMSE = 5.40849, validation RMSE = 5.42009
# Epoch 15, training RMSE = 5.35856, validation RMSE = 5.31404
# Epoch 16, training RMSE = 5.2814, validation RMSE = 5.28913
# Epoch 17, training RMSE = 5.2511, validation RMSE = 5.22352
# Epoch 18, training RMSE = 5.20257, validation RMSE = 5.17214
# Epoch 19, training RMSE = 5.13872, validation RMSE = 5.27658
# Epoch 20, training RMSE = 5.10116, validation RMSE = 5.18251
# ==========Model result==========
# Best epoch is 18 with minimum validation error = 5.17214
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 5
# Epoch 1, training RMSE = 11.26299, validation RMSE = 8.8463
# Epoch 2, training RMSE = 8.03308, validation RMSE = 7.5711
# Epoch 3, training RMSE = 7.33108, validation RMSE = 7.1967
# Epoch 4, training RMSE = 7.02201, validation RMSE = 6.78176
# Epoch 5, training RMSE = 6.70436, validation RMSE = 6.60213
# Epoch 6, training RMSE = 6.47159, validation RMSE = 6.36972
# Epoch 7, training RMSE = 6.26427, validation RMSE = 6.14637
# Epoch 8, training RMSE = 6.06379, validation RMSE = 6.05191
# Epoch 9, training RMSE = 5.89983, validation RMSE = 5.96442
# Epoch 10, training RMSE = 5.79921, validation RMSE = 5.79736
# Epoch 11, training RMSE = 5.67864, validation RMSE = 5.70961
# Epoch 12, training RMSE = 5.6422, validation RMSE = 5.4811
# Epoch 13, training RMSE = 5.51551, validation RMSE = 5.52726
# Epoch 14, training RMSE = 5.44497, validation RMSE = 5.45952
# Epoch 15, training RMSE = 5.39116, validation RMSE = 5.36768
# Epoch 16, training RMSE = 5.27306, validation RMSE = 5.43387
# Epoch 17, training RMSE = 5.27962, validation RMSE = 5.28842
# Epoch 18, training RMSE = 5.22469, validation RMSE = 5.25447
# Epoch 19, training RMSE = 5.1564, validation RMSE = 5.29058
# Epoch 20, training RMSE = 5.1718, validation RMSE = 5.12154
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 5.12154
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.05, lambda = 0.001
# Epoch 1, training RMSE = 8.8729, validation RMSE = 7.28885
# Epoch 2, training RMSE = 6.979, validation RMSE = 6.52673
# Epoch 3, training RMSE = 6.40678, validation RMSE = 6.10406
# Epoch 4, training RMSE = 6.00134, validation RMSE = 5.94553
# Epoch 5, training RMSE = 5.76732, validation RMSE = 5.74276
# Epoch 6, training RMSE = 5.61784, validation RMSE = 5.47157
# Epoch 7, training RMSE = 5.398, validation RMSE = 5.65793
# Epoch 8, training RMSE = 5.37192, validation RMSE = 5.44659
# Epoch 9, training RMSE = 5.28427, validation RMSE = 5.2275
# Epoch 10, training RMSE = 5.17487, validation RMSE = 5.16586
# Epoch 11, training RMSE = 5.17265, validation RMSE = 5.0772
# Epoch 12, training RMSE = 5.05633, validation RMSE = 5.05944
# Epoch 13, training RMSE = 5.0384, validation RMSE = 4.99751
# Epoch 14, training RMSE = 4.98488, validation RMSE = 5.02328
# Epoch 15, training RMSE = 4.97336, validation RMSE = 5.18609
# Epoch 16, training RMSE = 4.94275, validation RMSE = 4.93766
# Epoch 17, training RMSE = 4.96117, validation RMSE = 4.90188
# Epoch 18, training RMSE = 4.86677, validation RMSE = 5.02336
# Epoch 19, training RMSE = 4.92771, validation RMSE = 4.84467
# Epoch 20, training RMSE = 4.91851, validation RMSE = 4.88522
# ==========Model result==========
# Best epoch is 19 with minimum validation error = 4.84467
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.05, lambda = 0.005
# Epoch 1, training RMSE = 8.9966, validation RMSE = 7.41644
# Epoch 2, training RMSE = 7.03866, validation RMSE = 6.55858
# Epoch 3, training RMSE = 6.41245, validation RMSE = 6.26575
# Epoch 4, training RMSE = 6.04492, validation RMSE = 5.9702
# Epoch 5, training RMSE = 5.835, validation RMSE = 5.68148
# Epoch 6, training RMSE = 5.61769, validation RMSE = 5.527
# Epoch 7, training RMSE = 5.47771, validation RMSE = 5.4207
# Epoch 8, training RMSE = 5.36024, validation RMSE = 5.37993
# Epoch 9, training RMSE = 5.34241, validation RMSE = 5.12261
# Epoch 10, training RMSE = 5.18984, validation RMSE = 5.18497
# Epoch 11, training RMSE = 5.1169, validation RMSE = 5.20623
# Epoch 12, training RMSE = 5.08979, validation RMSE = 5.17006
# Epoch 13, training RMSE = 5.07694, validation RMSE = 4.95685
# Epoch 14, training RMSE = 5.03276, validation RMSE = 4.94441
# Epoch 15, training RMSE = 4.98059, validation RMSE = 4.99221
# Epoch 16, training RMSE = 4.9799, validation RMSE = 4.92115
# Epoch 17, training RMSE = 4.93478, validation RMSE = 4.9801
# Epoch 18, training RMSE = 4.89037, validation RMSE = 4.9921
# Epoch 19, training RMSE = 4.92994, validation RMSE = 4.95352
# Epoch 20, training RMSE = 4.9131, validation RMSE = 4.92667
# ...
# Epoch 46, training RMSE = 6.01703, validation RMSE = 6.25828
# Epoch 47, training RMSE = 6.02739, validation RMSE = 6.08757
# Epoch 48, training RMSE = 5.97999, validation RMSE = 6.15177
# Epoch 49, training RMSE = 5.98145, validation RMSE = 6.13588
# Epoch 50, training RMSE = 5.93084, validation RMSE = 6.12467
# Epoch 51, training RMSE = 5.9234, validation RMSE = 6.12984
# Epoch 52, training RMSE = 5.91823, validation RMSE = 6.03611
# Epoch 53, training RMSE = 5.92943, validation RMSE = 5.98543
# Epoch 54, training RMSE = 5.89064, validation RMSE = 6.00254
# Epoch 55, training RMSE = 5.82297, validation RMSE = 5.98989
# Epoch 56, training RMSE = 5.81648, validation RMSE = 5.97248
# Epoch 57, training RMSE = 5.81967, validation RMSE = 5.98275
# Epoch 58, training RMSE = 5.83408, validation RMSE = 5.8454
# Epoch 59, training RMSE = 5.75074, validation RMSE = 5.93952
# Epoch 60, training RMSE = 5.68431, validation RMSE = 6.08884
# Epoch 61, training RMSE = 5.74437, validation RMSE = 5.8919
# Epoch 62, training RMSE = 5.71396, validation RMSE = 5.91706
# Epoch 63, training RMSE = 5.72158, validation RMSE = 5.82963
# Epoch 64, training RMSE = 5.69268, validation RMSE = 5.86664
# Epoch 65, training RMSE = 5.69472, validation RMSE = 5.8315
# Epoch 66, training RMSE = 5.67657, validation RMSE = 5.80731
# Epoch 67, training RMSE = 5.6627, validation RMSE = 5.76866
# Epoch 68, training RMSE = 5.59192, validation RMSE = 5.83114
# Epoch 69, training RMSE = 5.6104, validation RMSE = 5.76675
# Epoch 70, training RMSE = 5.66601, validation RMSE = 5.683
# Epoch 71, training RMSE = 5.61291, validation RMSE = 5.66833
# Epoch 72, training RMSE = 5.52736, validation RMSE = 5.79261
# Epoch 73, training RMSE = 5.56398, validation RMSE = 5.68716
# Epoch 74, training RMSE = 5.54239, validation RMSE = 5.72047
# Epoch 75, training RMSE = 5.50325, validation RMSE = 5.70387
# Epoch 76, training RMSE = 5.51887, validation RMSE = 5.71559
# Epoch 77, training RMSE = 5.57127, validation RMSE = 5.53516
# Epoch 78, training RMSE = 5.46348, validation RMSE = 5.67448
# Epoch 79, training RMSE = 5.49541, validation RMSE = 5.57775
# Epoch 80, training RMSE = 5.45503, validation RMSE = 5.63165
# Epoch 81, training RMSE = 5.50454, validation RMSE = 5.51928
# Epoch 82, training RMSE = 5.44618, validation RMSE = 5.54334
# Epoch 83, training RMSE = 5.48196, validation RMSE = 5.45739
# Epoch 84, training RMSE = 5.38734, validation RMSE = 5.63247
# Epoch 85, training RMSE = 5.39823, validation RMSE = 5.59443
# Epoch 86, training RMSE = 5.39062, validation RMSE = 5.52243
# Epoch 87, training RMSE = 5.39842, validation RMSE = 5.53434
# Epoch 88, training RMSE = 5.34167, validation RMSE = 5.62447
# Epoch 89, training RMSE = 5.31593, validation RMSE = 5.63669
# Epoch 90, training RMSE = 5.36151, validation RMSE = 5.5797
# Epoch 91, training RMSE = 5.39854, validation RMSE = 5.47273
# Epoch 92, training RMSE = 5.40961, validation RMSE = 5.44408
# Epoch 93, training RMSE = 5.29182, validation RMSE = 5.58428
# Epoch 94, training RMSE = 5.31605, validation RMSE = 5.5055
# Epoch 95, training RMSE = 5.34155, validation RMSE = 5.44312
# Epoch 96, training RMSE = 5.3003, validation RMSE = 5.42716
# Epoch 97, training RMSE = 5.31795, validation RMSE = 5.42285
# Epoch 98, training RMSE = 5.30614, validation RMSE = 5.37789
# Epoch 99, training RMSE = 5.27583, validation RMSE = 5.40916
# Epoch 100, training RMSE = 5.25015, validation RMSE = 5.45547
# ==========Model result==========
# Best epoch is 98 with minimum validation error = 5.37789
# ========== Start training model ==========
# batch size = 1024, epoch_size = 100, learning rate = 0.05, lambda = 1
# Epoch 1, training RMSE = 13.31792, validation RMSE = 12.69822
# Epoch 2, training RMSE = 11.90421, validation RMSE = 11.51011
# Epoch 3, training RMSE = 10.7861, validation RMSE = 10.51541
# Epoch 4, training RMSE = 9.96244, validation RMSE = 9.8039
# Epoch 5, training RMSE = 9.29929, validation RMSE = 9.3112
# Epoch 6, training RMSE = 8.89321, validation RMSE = 8.79796
# Epoch 7, training RMSE = 8.50451, validation RMSE = 8.45362
# Epoch 8, training RMSE = 8.20436, validation RMSE = 8.17958
# Epoch 9, training RMSE = 7.88937, validation RMSE = 8.10973
# Epoch 10, training RMSE = 7.78688, validation RMSE = 7.65998
# Epoch 11, training RMSE = 7.56108, validation RMSE = 7.6848
# Epoch 12, training RMSE = 7.44768, validation RMSE = 7.55039
# Epoch 13, training RMSE = 7.38711, validation RMSE = 7.38031
# Epoch 14, training RMSE = 7.27559, validation RMSE = 7.34598
# Epoch 15, training RMSE = 7.20354, validation RMSE = 7.32329
# Epoch 16, training RMSE = 7.18158, validation RMSE = 7.20744
# Epoch 17, training RMSE = 7.07806, validation RMSE = 7.24844
# Epoch 18, training RMSE = 7.02048, validation RMSE = 7.214
# Epoch 19, training RMSE = 6.95735, validation RMSE = 7.22634
# Epoch 20, training RMSE = 6.88753, validation RMSE = 7.18614
# Epoch 21, training RMSE = 6.89303, validation RMSE = 7.04972
# Epoch 22, training RMSE = 6.84343, validation RMSE = 6.95455
# Epoch 23, training RMSE = 6.79931, validation RMSE = 6.9631
# Epoch 24, training RMSE = 6.74896, validation RMSE = 6.94178
# Epoch 25, training RMSE = 6.75036, validation RMSE = 6.81253
# Epoch 26, training RMSE = 6.6235, validation RMSE = 6.95666
# Epoch 27, training RMSE = 6.66236, validation RMSE = 6.72704
# Epoch 28, training RMSE = 6.64062, validation RMSE = 6.6845
# Epoch 29, training RMSE = 6.65225, validation RMSE = 6.53622
# Epoch 30, training RMSE = 6.49651, validation RMSE = 6.75941
# Epoch 31, training RMSE = 6.48756, validation RMSE = 6.66684
# Epoch 32, training RMSE = 6.46783, validation RMSE = 6.57573
# Epoch 33, training RMSE = 6.40919, validation RMSE = 6.6299
# Epoch 34, training RMSE = 6.36708, validation RMSE = 6.5963
# Epoch 35, training RMSE = 6.3468, validation RMSE = 6.55967
# Epoch 36, training RMSE = 6.3804, validation RMSE = 6.39731
# Epoch 37, training RMSE = 6.30276, validation RMSE = 6.4104
# Epoch 38, training RMSE = 6.28094, validation RMSE = 6.46325
# Epoch 39, training RMSE = 6.25377, validation RMSE = 6.37965
# Epoch 40, training RMSE = 6.23188, validation RMSE = 6.29701
# Epoch 41, training RMSE = 6.15297, validation RMSE = 6.39846
# Epoch 42, training RMSE = 6.07283, validation RMSE = 6.41193
# Epoch 43, training RMSE = 6.11941, validation RMSE = 6.3187
# Epoch 44, training RMSE = 6.11283, validation RMSE = 6.23437
# Epoch 45, training RMSE = 6.10018, validation RMSE = 6.18428
# Epoch 46, training RMSE = 6.02574, validation RMSE = 6.27575
# Epoch 47, training RMSE = 5.99566, validation RMSE = 6.23652
# Epoch 48, training RMSE = 6.0101, validation RMSE = 6.17414
# Epoch 49, training RMSE = 6.00383, validation RMSE = 6.1335
# Epoch 50, training RMSE = 6.00601, validation RMSE = 6.01547
# Epoch 51, training RMSE = 5.90745, validation RMSE = 6.22062
# Epoch 52, training RMSE = 6.00054, validation RMSE = 5.88805
# Epoch 53, training RMSE = 5.87865, validation RMSE = 6.08416
# Epoch 54, training RMSE = 5.93097, validation RMSE = 5.88743
# Epoch 55, training RMSE = 5.84019, validation RMSE = 6.01682
# Epoch 56, training RMSE = 5.85695, validation RMSE = 5.98091
# Epoch 57, training RMSE = 5.80316, validation RMSE = 6.04428
# Epoch 58, training RMSE = 5.81356, validation RMSE = 5.92581
# Epoch 59, training RMSE = 5.75336, validation RMSE = 6.00551
# Epoch 60, training RMSE = 5.74782, validation RMSE = 6.00813
# Epoch 61, training RMSE = 5.75429, validation RMSE = 5.89678
# Epoch 62, training RMSE = 5.72423, validation RMSE = 5.87252
# Epoch 63, training RMSE = 5.75749, validation RMSE = 5.79388
# Epoch 64, training RMSE = 5.73745, validation RMSE = 5.80413
# Epoch 65, training RMSE = 5.68785, validation RMSE = 5.83445
# Epoch 66, training RMSE = 5.6945, validation RMSE = 5.77075
# Epoch 67, training RMSE = 5.68579, validation RMSE = 5.74048
# Epoch 68, training RMSE = 5.65019, validation RMSE = 5.78323
# Epoch 69, training RMSE = 5.62811, validation RMSE = 5.80501
# Epoch 70, training RMSE = 5.59096, validation RMSE = 5.75961
# Epoch 71, training RMSE = 5.60801, validation RMSE = 5.68687
# Epoch 72, training RMSE = 5.57161, validation RMSE = 5.80367
# Epoch 73, training RMSE = 5.60124, validation RMSE = 5.74656
# Epoch 74, training RMSE = 5.58088, validation RMSE = 5.6736
# Epoch 75, training RMSE = 5.54866, validation RMSE = 5.67657
# Epoch 76, training RMSE = 5.52479, validation RMSE = 5.67164
# Epoch 77, training RMSE = 5.57116, validation RMSE = 5.5939
# Epoch 78, training RMSE = 5.52188, validation RMSE = 5.65088
# Epoch 79, training RMSE = 5.50383, validation RMSE = 5.6157
# Epoch 80, training RMSE = 5.50988, validation RMSE = 5.62116
# Epoch 81, training RMSE = 5.43831, validation RMSE = 5.7227
# Epoch 82, training RMSE = 5.48899, validation RMSE = 5.58766
# Epoch 83, training RMSE = 5.50819, validation RMSE = 5.48975
# Epoch 84, training RMSE = 5.39629, validation RMSE = 5.67456
# Epoch 85, training RMSE = 5.41605, validation RMSE = 5.60102
# Epoch 86, training RMSE = 5.404, validation RMSE = 5.54159
# Epoch 87, training RMSE = 5.38038, validation RMSE = 5.61483
# Epoch 88, training RMSE = 5.40182, validation RMSE = 5.57072
# Epoch 89, training RMSE = 5.43416, validation RMSE = 5.43123
# Epoch 90, training RMSE = 5.372, validation RMSE = 5.51124
# Epoch 91, training RMSE = 5.3317, validation RMSE = 5.561
# Epoch 92, training RMSE = 5.33139, validation RMSE = 5.55215
# Epoch 93, training RMSE = 5.33673, validation RMSE = 5.48646
# Epoch 94, training RMSE = 5.29022, validation RMSE = 5.56129
# Epoch 95, training RMSE = 5.34684, validation RMSE = 5.40558
# Epoch 96, training RMSE = 5.3194, validation RMSE = 5.4409
# Epoch 97, training RMSE = 5.32561, validation RMSE = 5.45776
# Epoch 98, training RMSE = 5.33243, validation RMSE = 5.37905
# Epoch 99, training RMSE = 5.25865, validation RMSE = 5.50411
# Epoch 100, training RMSE = 5.27542, validation RMSE = 5.43758
# ==========Model result==========
# Best epoch is 98 with minimum validation error = 5.37905
# ========== Start training model ==========
# batch size = 1024, epoch_size = 100, learning rate = 0.05, lambda = 5
# Epoch 1, training RMSE = 12.94656, validation RMSE = 12.6713
# Epoch 2, training RMSE = 11.92297, validation RMSE = 11.39245
# Epoch 3, training RMSE = 10.88537, validation RMSE = 10.83208
# Epoch 4, training RMSE = 10.13589, validation RMSE = 9.96724
# Epoch 5, training RMSE = 9.53615, validation RMSE = 9.3851
# Epoch 6, training RMSE = 8.9695, validation RMSE = 8.98808
# Epoch 7, training RMSE = 8.54137, validation RMSE = 8.54989
# Epoch 8, training RMSE = 8.21315, validation RMSE = 8.24645
# Epoch 9, training RMSE = 7.91009, validation RMSE = 8.06359
# Epoch 10, training RMSE = 7.72697, validation RMSE = 7.78703
# Epoch 11, training RMSE = 7.58975, validation RMSE = 7.58824
# Epoch 12, training RMSE = 7.41318, validation RMSE = 7.58634
# Epoch 13, training RMSE = 7.28467, validation RMSE = 7.58915
# Epoch 14, training RMSE = 7.27234, validation RMSE = 7.34337
# Epoch 15, training RMSE = 7.19433, validation RMSE = 7.29084
# Epoch 16, training RMSE = 7.13344, validation RMSE = 7.24965
# Epoch 17, training RMSE = 7.04905, validation RMSE = 7.24498
# Epoch 18, training RMSE = 6.99081, validation RMSE = 7.22959
# Epoch 19, training RMSE = 7.0102, validation RMSE = 7.04711
# Epoch 20, training RMSE = 6.94445, validation RMSE = 7.02539
# Epoch 21, training RMSE = 6.85237, validation RMSE = 7.12626
# Epoch 22, training RMSE = 6.79518, validation RMSE = 7.0745
# Epoch 23, training RMSE = 6.76816, validation RMSE = 6.97337
# Epoch 24, training RMSE = 6.7404, validation RMSE = 6.89217
# Epoch 25, training RMSE = 6.74026, validation RMSE = 6.77589
# Epoch 26, training RMSE = 6.69844, validation RMSE = 6.75031
# Epoch 27, training RMSE = 6.62902, validation RMSE = 6.81005
# Epoch 28, training RMSE = 6.58041, validation RMSE = 6.80079
# Epoch 29, training RMSE = 6.53871, validation RMSE = 6.7375
# Epoch 30, training RMSE = 6.50537, validation RMSE = 6.75501
# Epoch 31, training RMSE = 6.52922, validation RMSE = 6.51323
# Epoch 32, training RMSE = 6.47293, validation RMSE = 6.57549
# Epoch 33, training RMSE = 6.42977, validation RMSE = 6.50892
# Epoch 34, training RMSE = 6.38819, validation RMSE = 6.49176
# Epoch 35, training RMSE = 6.33978, validation RMSE = 6.47603
# Epoch 36, training RMSE = 6.2939, validation RMSE = 6.50113
# Epoch 37, training RMSE = 6.29301, validation RMSE = 6.41374
# Epoch 38, training RMSE = 6.27306, validation RMSE = 6.34651
# Epoch 39, training RMSE = 6.24315, validation RMSE = 6.36243
# Epoch 40, training RMSE = 6.21808, validation RMSE = 6.33062
# Epoch 41, training RMSE = 6.19916, validation RMSE = 6.2525
# Epoch 42, training RMSE = 6.15485, validation RMSE = 6.32014
# Epoch 43, training RMSE = 6.1464, validation RMSE = 6.19768
# Epoch 44, training RMSE = 6.14106, validation RMSE = 6.12865
# Epoch 45, training RMSE = 6.00591, validation RMSE = 6.35809
# Epoch 46, training RMSE = 6.02423, validation RMSE = 6.24325
# Epoch 47, training RMSE = 6.02981, validation RMSE = 6.16049
# Epoch 48, training RMSE = 5.98929, validation RMSE = 6.16245
# Epoch 49, training RMSE = 5.91906, validation RMSE = 6.22429
# Epoch 50, training RMSE = 5.96186, validation RMSE = 6.08373
# Epoch 51, training RMSE = 5.87805, validation RMSE = 6.20676
# Epoch 52, training RMSE = 5.87501, validation RMSE = 6.11509
# Epoch 53, training RMSE = 5.86299, validation RMSE = 6.05455
# Epoch 54, training RMSE = 5.86731, validation RMSE = 6.00925
# Epoch 55, training RMSE = 5.84619, validation RMSE = 6.00945
# Epoch 56, training RMSE = 5.80957, validation RMSE = 6.02818
# Epoch 57, training RMSE = 5.80996, validation RMSE = 5.95962
# Epoch 58, training RMSE = 5.82909, validation RMSE = 5.81904
# Epoch 59, training RMSE = 5.78681, validation RMSE = 5.92502
# Epoch 60, training RMSE = 5.72974, validation RMSE = 5.98247
# Epoch 61, training RMSE = 5.75542, validation RMSE = 5.85534
# Epoch 62, training RMSE = 5.72328, validation RMSE = 5.87115
# Epoch 63, training RMSE = 5.73699, validation RMSE = 5.81916
# Epoch 64, training RMSE = 5.6995, validation RMSE = 5.81357
# Epoch 65, training RMSE = 5.63984, validation RMSE = 5.91601
# Epoch 66, training RMSE = 5.65426, validation RMSE = 5.84041
# Epoch 67, training RMSE = 5.6374, validation RMSE = 5.77674
# Epoch 68, training RMSE = 5.65212, validation RMSE = 5.76708
# Epoch 69, training RMSE = 5.67671, validation RMSE = 5.63491
# Epoch 70, training RMSE = 5.55579, validation RMSE = 5.87584
# Epoch 71, training RMSE = 5.61172, validation RMSE = 5.69479
# Epoch 72, training RMSE = 5.61459, validation RMSE = 5.65923
# Epoch 73, training RMSE = 5.54903, validation RMSE = 5.72418
# Epoch 74, training RMSE = 5.58388, validation RMSE = 5.61573
# Epoch 75, training RMSE = 5.58257, validation RMSE = 5.62974
# Epoch 76, training RMSE = 5.53647, validation RMSE = 5.6325
# Epoch 77, training RMSE = 5.48037, validation RMSE = 5.7233
# Epoch 78, training RMSE = 5.4953, validation RMSE = 5.65824
# Epoch 79, training RMSE = 5.46809, validation RMSE = 5.68885
# Epoch 80, training RMSE = 5.46335, validation RMSE = 5.60312
# Epoch 81, training RMSE = 5.48981, validation RMSE = 5.55953
# Epoch 82, training RMSE = 5.43985, validation RMSE = 5.61885
# Epoch 83, training RMSE = 5.42993, validation RMSE = 5.70047
# Epoch 84, training RMSE = 5.39438, validation RMSE = 5.67316
# Epoch 85, training RMSE = 5.42501, validation RMSE = 5.60053
# Epoch 86, training RMSE = 5.39879, validation RMSE = 5.51686
# Epoch 87, training RMSE = 5.4284, validation RMSE = 5.48058
# Epoch 88, training RMSE = 5.38187, validation RMSE = 5.50358
# Epoch 89, training RMSE = 5.37049, validation RMSE = 5.57558
# Epoch 90, training RMSE = 5.36773, validation RMSE = 5.52478
# Epoch 91, training RMSE = 5.3102, validation RMSE = 5.60262
# Epoch 92, training RMSE = 5.36022, validation RMSE = 5.4884
# Epoch 93, training RMSE = 5.32106, validation RMSE = 5.53357
# Epoch 94, training RMSE = 5.37417, validation RMSE = 5.35631
# Epoch 95, training RMSE = 5.35228, validation RMSE = 5.37618
# Epoch 96, training RMSE = 5.29176, validation RMSE = 5.5109
# Epoch 97, training RMSE = 5.2926, validation RMSE = 5.46645
# Epoch 98, training RMSE = 5.34189, validation RMSE = 5.36345
# Epoch 99, training RMSE = 5.2554, validation RMSE = 5.49478
# Epoch 100, training RMSE = 5.32744, validation RMSE = 5.3376
# ==========Model result==========
# Best epoch is 100 with minimum validation error = 5.3376

# %%
print("=" * 10, " Best Model result ", "=" * 10)
print(f"Batch Size = {best_batch_size}, Epoch Size = {best_epoch_size} (Actually running {best_stop_epoch_size} epoch), Learning rate = {best_learning_rate}")
print(f"Best lambda = {best_lambda}")
print(f"Validation RMSE = {global_best_RMSE}")
# Out:
# ==========  Best Model result  ==========
# Batch Size = 64, Epoch Size = 50 (Actually running 28 epoch), Learning rate = 0.05
# Best lambda = 0.001
# Validation RMSE = 4.657250971350151

# %%
train_all_model = LinearRegression()
train_all_model.train_with_full_data(X_train, y_train, best_batch_size, best_stop_epoch_size, best_learning_rate, best_lambda,verbose = False)
final_w = train_all_model.best_w
final_bias = train_all_model.best_bias

# %%
#Training with all data finally
predict_model = LinearRegression()
y_pred = predict_model.predict(X_test, final_w, final_bias)

# %%
file_name = 'prediction.csv'
write_to_csv(y_pred, file_name)
