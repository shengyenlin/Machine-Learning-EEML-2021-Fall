# %% [markdown]
# # **2021ML FALL HW1: PM2.5 Prediction (Regression)**

# %% [markdown]
# # **Import Some Packages**

# %%
# For data preprocess
import numpy as np
import csv
import math
import pandas as pd
import math

# %%
data_train = pd.read_csv('../train.csv')
data_test = pd.read_csv('../test.csv')

# %% [markdown]
# # Data preprocessing

# %%
class DataPreprocessor():
    def __init__(self):
        self.keep_col = None
        self.top_corr_number = 15
        self.train_mean = None
        self.train_std = None
    
    def remove_outlier_y_with_IQR(self, data_train: pd.DataFrame):
        mean_y = data_train['PM2.5'].mean()
        q75, q25 = np.percentile(data_train['PM2.5'], [75 ,25])
        IQR = q75 - q25
        upper_bound = mean_y + 1.5 * IQR
        lower_bound = mean_y - 1.5 * IQR
        keep_cond = (data_train['PM2.5'] < upper_bound) & (data_train['PM2.5'] > lower_bound)
        data_train = data_train[keep_cond]
        return data_train

    def remove_larger_than_1000(self, data_train: pd.DataFrame):
        data_train = data_train[data_train['PM2.5'] < 1000]
        return data_train

    def slice_top_n_correlation_with_y(self, data: pd.DataFrame, isTraining = False):
        if isTraining:
            index_corr_descending = abs(data.corrwith(data['PM2.5'])).sort_values(ascending=False).index
            #first column will always be `PM2.5`
            self.keep_col = index_corr_descending[:self.top_corr_number]
        data = data[self.keep_col]
        return data

    def normalize_data(self, X_data: np.array, isTraining = False):
        if isTraining:
            self.train_mean = X_data.mean(axis = 0)
            self.train_std = X_data.std(axis = 0)
        normalized_data = (X_data - self.train_mean) / self.train_std
        return normalized_data

    def min_max_scaling(self, X_data: np.array, isTraining = False):
        if isTraining:
            self.train_max = X_data.max(axis = 0)
            self.train_min = X_data.min(axis = 0)
        normalized_data = (X_data - self.train_min) / (self.train_max - self.train_min)
        return normalized_data


    def parse2train(self, data):
        data = data.values
        x = []
        y = []
        # 用前面9筆資料預測下一筆PM2.5 所以需要-9
        total_length = data.shape[0] - 9
        for i in range(total_length):
            x_tmp = data[i:i+9, :]
            y_tmp = data[i+9, 0] #PM2.5 is the first column
            x.append(x_tmp.reshape(-1,))
            y.append(y_tmp)
        x = np.array(x) #shape = (# of observations, # of features * # of time lag)
        y = np.array(y)
        return x, y


    def parse2test(self, data):
        x = []
        y = []
        data = data.values
        # 用前面9筆資料預測下一筆PM2.5 所以需要-9
        total_length = data.shape[0] - 9
        for i in range(857):
            x_tmp = data[9 * i: 9 * i + 9, :]
            x.append(x_tmp.reshape(-1,))
        # x 會是一個(n, 18, 9)的陣列， y 則是(n, 1) 
        x = np.array(x)
        return x

    def preprocess_train_data(self, data_train: pd.DataFrame):
        data_train = self.remove_outlier_y_with_IQR(data_train)
        #data_train = self.remove_larger_than_1000(data_train)
        data_train = self.slice_top_n_correlation_with_y(data_train, isTraining=True)
        X_train, y_train = self.parse2train(data_train)
        #X_train = self.normalize_data(X_train, isTraining = True)
        X_train = self.min_max_scaling(X_train, isTraining = True)
        return X_train, y_train

    def preprocess_test_data(self, data_test: pd.DataFrame):
        data_test = self.slice_top_n_correlation_with_y(data_test, isTraining=False)
        X_test = self.parse2test(data_test)
        #X_test = self.normalize_data(X_test, isTraining = False)
        X_test = self.min_max_scaling(X_test, isTraining = False)
        return X_test

# %%
class LinearRegression():
    def __init__(self):
        self.train_valid_ratio = 0.70
        self.train_loss = list()
        self.valid_loss = list()
        #record best information
        self.best_w = None
        self.best_bias = None
        self.best_valid_RMSE = None
        self.best_epoch = None
        self.stop_epoch = None

    def initialize_params(self, x):
        #initalize as a ~ unif(1, n-1) / sqrt(n)
        w = np.random.rand(x.shape[1]).reshape(-1, 1)
        bias = np.random.rand()
        return w, bias

    def train(self, x, y,batch_size, epoch_size, learning_rate, lam_train, verbose = True):
        #Initialize parameter
        batch_size = batch_size 
        epoch_size = epoch_size 
        lr = learning_rate
        w, bias = self.initialize_params(x)
        best_valid_RMSE = 99999
        best_epoch = 0
        patience = 10 #for early stopping

        #Adam optimizer
        lam = lam_train #L2 regularization
        beta_1 = np.full(x[0].shape, 0.9).reshape(-1, 1) #exponential decay rates for the moment estimates
        beta_2 = np.full(x[0].shape, 0.999).reshape(-1,1) #exponential decay rates for the moment estimates
        #m_t: first momentum vector, for momentum
        m_t = np.full(x[0].shape, 0).reshape(-1, 1)
        #v_t: second momemtum vector, for RMSprop
        v_t = np.full(x[0].shape, 0).reshape(-1, 1)
        m_t_b = 0.0
        v_t_b = 0.0
        t = 0
        epsilon = 1e-8

        for num_epoch in range(1, epoch_size + 1):
            #Shuffle when each epoch begin
            index = np.arange(x.shape[0])
            np.random.shuffle(index)
            x = x[index]
            y = y[index]
            split_point_x = math.floor(x.shape[0] * self.train_valid_ratio)
            split_point_y = math.floor(y.shape[0] * self.train_valid_ratio)
            X_train = x[:split_point_x, :]
            y_train = y[:split_point_y] 
            X_valid = x[split_point_x:, :] 
            y_valid = y[split_point_y:]
            SSE = 0
            for num_batch in range(int(X_train.shape[0]/batch_size)):
                t+=1
                x_batch = X_train[num_batch * batch_size:(num_batch + 1) * batch_size]
                y_batch = y_train[num_batch * batch_size:(num_batch + 1) * batch_size].reshape(-1,1)
                
                y_hat = np.dot(x_batch, w) + bias
                train_loss = y_batch - y_hat
                # 計算gradient
                g_t = np.dot(x_batch.transpose(), train_loss) * (-2) +  2 * lam * np.sum(w)
                #助教原本寫的是*2
                g_t_b = train_loss.sum(axis=0) * (-2)
                m_t = beta_1*m_t + (1-beta_1)*g_t 
                v_t = beta_2*v_t + (1-beta_2)*np.multiply(g_t, g_t)
                m_cap = m_t/(1-(beta_1**t))
                v_cap = v_t/(1-(beta_2**t))
                m_t_b = 0.9*m_t_b + (1-0.9)*g_t_b
                v_t_b = 0.999*v_t_b + (1-0.999) * (g_t_b*g_t_b) 
                m_cap_b = m_t_b/(1-(0.9**t))
                v_cap_b = v_t_b/(1-(0.999**t))

                # 更新weight, bias
                w -= ((lr*m_cap)/(np.sqrt(v_cap)+epsilon)).reshape(-1, 1)
                bias -= (lr*m_cap_b)/(math.sqrt(v_cap_b)+epsilon)
                SSE += np.sum(np.square(train_loss))

            # print(SSE)
            train_RMSE = np.sqrt(SSE / X_train.shape[0])
            valid_RMSE = self.compute_valid_RMSE(X_valid, y_valid, w, bias)
            self.train_loss.append(train_RMSE)
            self.valid_loss.append(valid_RMSE)
            if verbose:
                print(f"Epoch {num_epoch}, training RMSE = {round(train_RMSE, 5)}, validation RMSE = {round(valid_RMSE, 5)}")
            
            #save best result
            if valid_RMSE < best_valid_RMSE:
                self.best_w = w
                self.best_bias = bias
                self.best_epoch = num_epoch
                best_valid_RMSE = valid_RMSE
                self.best_valid_RMSE = best_valid_RMSE

            #early stopping
            if valid_RMSE > best_valid_RMSE and num_epoch >= self.best_epoch + patience:
                self.stop_epoch = self.best_epoch + patience
                if verbose:
                    print("Early Stopping!")
                    print("="*10 + "validation result" + "="*10)
                    print(f"Best epoch is {self.best_epoch} with minimum validation error = {round(best_valid_RMSE, 5)}")
                return

        self.stop_epoch = num_epoch
        if verbose:
            print("="*10 + "Model result" + "="*10)
            print(f"Best epoch is {self.best_epoch} with minimum validation error = {round(best_valid_RMSE, 5)}")
                      
    def compute_valid_RMSE(self, X_valid, y_valid, w, bias):
        valid_loss = 0
        y_hat = np.dot(X_valid, w) + bias
        valid_loss = y_valid.reshape(-1, 1) - y_hat.reshape(-1, 1)
        valid_SSE = np.sum(np.square(valid_loss))
        valid_RMSE = np.sqrt(valid_SSE / X_valid.shape[0])
        return valid_RMSE

    def train_with_full_data(self, x, y, batch_size, epoch_size, learning_rate, lam_train, verbose = True):
        #Initialize parameter
        batch_size = batch_size 
        epoch_size = epoch_size 
        lr = learning_rate
        w, bias = self.initialize_params(x)

        #Adam optimizer
        lam = lam_train #L2 regularization
        beta_1 = np.full(x[0].shape, 0.9).reshape(-1, 1) #exponential decay rates for the moment estimates
        beta_2 = np.full(x[0].shape, 0.999).reshape(-1,1) #exponential decay rates for the moment estimates
        #m_t: first momentum vector, for momentum
        m_t = np.full(x[0].shape, 0).reshape(-1, 1)
        #v_t: second momemtum vector, for RMSprop
        v_t = np.full(x[0].shape, 0).reshape(-1, 1)
        m_t_b = 0.0
        v_t_b = 0.0
        t = 0
        epsilon = 1e-8

        for num_epoch in range(1, epoch_size + 1):
            #Shuffle when each epoch begin
            index = np.arange(x.shape[0])
            np.random.shuffle(index)
            x = x[index]
            y = y[index]

            SSE = 0
            for num_batch in range(int(x.shape[0]/batch_size)):
                t+=1
                x_batch = x[num_batch * batch_size:(num_batch + 1) * batch_size]
                y_batch = y[num_batch * batch_size:(num_batch + 1) * batch_size].reshape(-1,1)
                
                y_hat = np.dot(x_batch, w) + bias
                train_loss = y_batch - y_hat
                # 計算gradient
                g_t = np.dot(x_batch.transpose(), train_loss) * (-2) +  2 * lam * np.sum(w)
                g_t_b = train_loss.sum(axis=0) * (-2)
                m_t = beta_1*m_t + (1-beta_1)*g_t 
                v_t = beta_2*v_t + (1-beta_2)*np.multiply(g_t, g_t)
                m_cap = m_t/(1-(beta_1**t))
                v_cap = v_t/(1-(beta_2**t))
                m_t_b = 0.9*m_t_b + (1-0.9)*g_t_b
                v_t_b = 0.999*v_t_b + (1-0.999) * (g_t_b*g_t_b) 
                m_cap_b = m_t_b/(1-(0.9**t))
                v_cap_b = v_t_b/(1-(0.999**t))

                # 更新weight, bias
                w -= ((lr*m_cap)/(np.sqrt(v_cap)+epsilon)).reshape(-1, 1)
                bias -= (lr*m_cap_b)/(math.sqrt(v_cap_b)+epsilon)
                SSE += np.sum(np.square(train_loss))

            # print(SSE)
            train_RMSE = np.sqrt(SSE / x.shape[0])
            self.train_loss.append(train_RMSE)
            if verbose:
                print(f"Epoch {num_epoch}, training RMSE = {round(train_RMSE, 5)}")

        self.best_w = w
        self.best_bias = bias

    def predict(self, X_test, w, bias):
        predict_value = np.dot(X_test, w) + bias
        return predict_value

# %%
def write_to_csv(y_pred, file_name):
    with open(file_name, 'w', newline='') as csvf:
        # 建立 CSV 檔寫入器
        writer = csv.writer(csvf)
        writer.writerow(['Id','Predicted'])
        for i in range(int(y_pred.shape[0])):
            writer.writerow([i + 1, y_pred[i][0]])

# %% [markdown]
# # Preprocessing and model tuning

# %%
DP = DataPreprocessor()
X_train, y_train = DP.preprocess_train_data(data_train)
X_test = DP.preprocess_test_data(data_test)

# %%
#train_valid_ratio_list = [0.6, 0.7, 0.8, 0.9]
batch_size_list = [64, 128, 256, 512, 1024]
epoch_size_list = [20, 30, 50, 100]
learning_rate_list = [0.002, 0.005, 0.01, 0.025, 0.05]
lambda_list = [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5]
np.random.seed(2021)

#Model saving
global_best_w = 0
global_best_bias = 0
global_best_RMSE = 1000000

#Hyperparameter saving
best_train_valid_ratio = 0
best_batch_size = 0
best_epoch_size = 0
best_learning_rate = 0
best_lambda = 0

# for train_valid_ratio in train_valid_ratio_list:
for batch_size in batch_size_list:
    for epoch_size in epoch_size_list:
        for learning_rate in learning_rate_list:
            for lam in lambda_list:
                print("=" * 10,"Start training model", "="*10)
                print(f"batch size = {batch_size}, epoch_size = {epoch_size}, learning rate = {learning_rate}, lambda = {lam}")
                model = LinearRegression()
                model.train(X_train, y_train, batch_size, epoch_size, learning_rate, lam, verbose = True)
                if model.best_valid_RMSE < global_best_RMSE:
                    global_best_RMSE = model.best_valid_RMSE
                    global_best_w = model.best_w
                    global_best_bias = model.best_bias
                    best_batch_size = batch_size
                    best_epoch_size = epoch_size
                    best_stop_epoch_size = model.best_epoch
                    best_learning_rate = learning_rate
                    best_lambda = lam
# Out:
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.001
# Epoch 1, training RMSE = 28.45004, validation RMSE = 26.97757
# Epoch 2, training RMSE = 26.14901, validation RMSE = 25.24989
# Epoch 3, training RMSE = 24.95117, validation RMSE = 24.35827
# Epoch 4, training RMSE = 24.14988, validation RMSE = 23.81528
# Epoch 5, training RMSE = 23.58159, validation RMSE = 23.34367
# Epoch 6, training RMSE = 23.13333, validation RMSE = 22.86589
# Epoch 7, training RMSE = 22.66811, validation RMSE = 22.54766
# Epoch 8, training RMSE = 22.29012, validation RMSE = 22.13532
# Epoch 9, training RMSE = 21.89954, validation RMSE = 21.78404
# Epoch 10, training RMSE = 21.54923, validation RMSE = 21.37929
# Epoch 11, training RMSE = 21.18159, validation RMSE = 21.02205
# Epoch 12, training RMSE = 20.83371, validation RMSE = 20.63436
# Epoch 13, training RMSE = 20.46816, validation RMSE = 20.30677
# Epoch 14, training RMSE = 20.11563, validation RMSE = 19.9609
# Epoch 15, training RMSE = 19.7545, validation RMSE = 19.64852
# Epoch 16, training RMSE = 19.43519, validation RMSE = 19.22446
# Epoch 17, training RMSE = 19.06966, validation RMSE = 18.92729
# Epoch 18, training RMSE = 18.73432, validation RMSE = 18.56882
# Epoch 19, training RMSE = 18.39855, validation RMSE = 18.21359
# Epoch 20, training RMSE = 18.04107, validation RMSE = 17.90784
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.90784
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.005
# Epoch 1, training RMSE = 28.04129, validation RMSE = 26.52496
# Epoch 2, training RMSE = 25.77431, validation RMSE = 25.20862
# Epoch 3, training RMSE = 24.76672, validation RMSE = 24.45295
# Epoch 4, training RMSE = 24.14952, validation RMSE = 23.87332
# Epoch 5, training RMSE = 23.63949, validation RMSE = 23.42729
# Epoch 6, training RMSE = 23.21416, validation RMSE = 22.99868
# Epoch 7, training RMSE = 22.8096, validation RMSE = 22.61694
# Epoch 8, training RMSE = 22.39422, validation RMSE = 22.29839
# Epoch 9, training RMSE = 22.05579, validation RMSE = 21.84696
# Epoch 10, training RMSE = 21.67212, validation RMSE = 21.52175
# Epoch 11, training RMSE = 21.30137, validation RMSE = 21.18194
# Epoch 12, training RMSE = 20.96022, validation RMSE = 20.79342
# Epoch 13, training RMSE = 20.59582, validation RMSE = 20.46593
# Epoch 14, training RMSE = 20.24637, validation RMSE = 20.11215
# Epoch 15, training RMSE = 19.90905, validation RMSE = 19.73661
# Epoch 16, training RMSE = 19.56563, validation RMSE = 19.39689
# Epoch 17, training RMSE = 19.20847, validation RMSE = 19.07834
# Epoch 18, training RMSE = 18.87573, validation RMSE = 18.71141
# Epoch 19, training RMSE = 18.52506, validation RMSE = 18.38795
# Epoch 20, training RMSE = 18.18581, validation RMSE = 18.04963
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 18.04963
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.01
# Epoch 1, training RMSE = 28.50685, validation RMSE = 26.62122
# Epoch 2, training RMSE = 25.75664, validation RMSE = 25.17432
# Epoch 3, training RMSE = 24.65463, validation RMSE = 24.28108
# Epoch 4, training RMSE = 23.97867, validation RMSE = 23.66881
# Epoch 5, training RMSE = 23.44187, validation RMSE = 23.24837
# Epoch 6, training RMSE = 22.99629, validation RMSE = 22.86637
# Epoch 7, training RMSE = 22.61201, validation RMSE = 22.43691
# Epoch 8, training RMSE = 22.23372, validation RMSE = 22.03706
# Epoch 9, training RMSE = 21.84646, validation RMSE = 21.69764
# Epoch 10, training RMSE = 21.48344, validation RMSE = 21.33503
# Epoch 11, training RMSE = 21.11964, validation RMSE = 20.9845
# Epoch 12, training RMSE = 20.77569, validation RMSE = 20.61572
# Epoch 13, training RMSE = 20.42469, validation RMSE = 20.24979
# Epoch 14, training RMSE = 20.07916, validation RMSE = 19.89112
# Epoch 15, training RMSE = 19.72327, validation RMSE = 19.55838
# Epoch 16, training RMSE = 19.37734, validation RMSE = 19.21376
# Epoch 17, training RMSE = 19.02576, validation RMSE = 18.89386
# Epoch 18, training RMSE = 18.69342, validation RMSE = 18.53468
# Epoch 19, training RMSE = 18.34309, validation RMSE = 18.21786
# Epoch 20, training RMSE = 18.00779, validation RMSE = 17.86503
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.86503
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.05
# Epoch 1, training RMSE = 28.53539, validation RMSE = 26.61157
# Epoch 2, training RMSE = 25.84819, validation RMSE = 24.95548
# Epoch 3, training RMSE = 24.63959, validation RMSE = 24.17906
# Epoch 4, training RMSE = 23.91905, validation RMSE = 23.60169
# Epoch 5, training RMSE = 23.34821, validation RMSE = 23.21299
# Epoch 6, training RMSE = 22.93914, validation RMSE = 22.71376
# Epoch 7, training RMSE = 22.5047, validation RMSE = 22.39427
# Epoch 8, training RMSE = 22.142, validation RMSE = 21.96725
# Epoch 9, training RMSE = 21.76475, validation RMSE = 21.60547
# Epoch 10, training RMSE = 21.39202, validation RMSE = 21.27156
# Epoch 11, training RMSE = 21.02613, validation RMSE = 20.92434
# Epoch 12, training RMSE = 20.68966, validation RMSE = 20.53196
# Epoch 13, training RMSE = 20.34383, validation RMSE = 20.18003
# Epoch 14, training RMSE = 19.98612, validation RMSE = 19.83434
# Epoch 15, training RMSE = 19.64927, validation RMSE = 19.45881
# Epoch 16, training RMSE = 19.3073, validation RMSE = 19.1275
# Epoch 17, training RMSE = 18.93898, validation RMSE = 18.81983
# Epoch 18, training RMSE = 18.60694, validation RMSE = 18.45799
# Epoch 19, training RMSE = 18.27537, validation RMSE = 18.09858
# Epoch 20, training RMSE = 17.92744, validation RMSE = 17.77454
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.77454
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.1
# Epoch 1, training RMSE = 28.25619, validation RMSE = 26.32465
# Epoch 2, training RMSE = 25.53089, validation RMSE = 24.69823
# Epoch 3, training RMSE = 24.37782, validation RMSE = 24.0032
# Epoch 4, training RMSE = 23.75345, validation RMSE = 23.42123
# Epoch 5, training RMSE = 23.22177, validation RMSE = 23.08415
# Epoch 6, training RMSE = 22.82135, validation RMSE = 22.65424
# Epoch 7, training RMSE = 22.4424, validation RMSE = 22.25804
# Epoch 8, training RMSE = 22.05939, validation RMSE = 21.91908
# Epoch 9, training RMSE = 21.70082, validation RMSE = 21.53865
# Epoch 10, training RMSE = 21.33716, validation RMSE = 21.198
# Epoch 11, training RMSE = 20.98389, validation RMSE = 20.82689
# Epoch 12, training RMSE = 20.62985, validation RMSE = 20.46528
# Epoch 13, training RMSE = 20.27681, validation RMSE = 20.131
# Epoch 14, training RMSE = 19.92069, validation RMSE = 19.80426
# Epoch 15, training RMSE = 19.59054, validation RMSE = 19.42506
# Epoch 16, training RMSE = 19.24117, validation RMSE = 19.09687
# Epoch 17, training RMSE = 18.89247, validation RMSE = 18.76121
# Epoch 18, training RMSE = 18.57366, validation RMSE = 18.36214
# Epoch 19, training RMSE = 18.21558, validation RMSE = 18.06678
# Epoch 20, training RMSE = 17.86924, validation RMSE = 17.73701
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.73701
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 0.5
# Epoch 1, training RMSE = 27.39182, validation RMSE = 25.82747
# Epoch 2, training RMSE = 24.95417, validation RMSE = 24.55127
# Epoch 3, training RMSE = 23.96631, validation RMSE = 23.77614
# Epoch 4, training RMSE = 23.40498, validation RMSE = 23.12137
# Epoch 5, training RMSE = 22.89696, validation RMSE = 22.72838
# Epoch 6, training RMSE = 22.47783, validation RMSE = 22.34448
# Epoch 7, training RMSE = 22.10519, validation RMSE = 21.92287
# Epoch 8, training RMSE = 21.70302, validation RMSE = 21.5977
# Epoch 9, training RMSE = 21.34311, validation RMSE = 21.20293
# Epoch 10, training RMSE = 20.98601, validation RMSE = 20.81781
# Epoch 11, training RMSE = 20.60218, validation RMSE = 20.52519
# Epoch 12, training RMSE = 20.27271, validation RMSE = 20.11265
# Epoch 13, training RMSE = 19.91719, validation RMSE = 19.76501
# Epoch 14, training RMSE = 19.55517, validation RMSE = 19.43759
# Epoch 15, training RMSE = 19.23421, validation RMSE = 19.03035
# Epoch 16, training RMSE = 18.86243, validation RMSE = 18.73285
# Epoch 17, training RMSE = 18.5322, validation RMSE = 18.36132
# Epoch 18, training RMSE = 18.18947, validation RMSE = 18.02373
# Epoch 19, training RMSE = 17.8396, validation RMSE = 17.70873
# Epoch 20, training RMSE = 17.50173, validation RMSE = 17.35622
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.35622
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 1
# Epoch 1, training RMSE = 28.60816, validation RMSE = 26.8087
# Epoch 2, training RMSE = 25.86941, validation RMSE = 25.19913
# Epoch 3, training RMSE = 24.77617, validation RMSE = 24.41206
# Epoch 4, training RMSE = 24.12083, validation RMSE = 23.97654
# Epoch 5, training RMSE = 23.68478, validation RMSE = 23.49159
# Epoch 6, training RMSE = 23.24789, validation RMSE = 23.14891
# Epoch 7, training RMSE = 22.8781, validation RMSE = 22.74088
# Epoch 8, training RMSE = 22.51113, validation RMSE = 22.36969
# Epoch 9, training RMSE = 22.13898, validation RMSE = 22.01256
# Epoch 10, training RMSE = 21.78439, validation RMSE = 21.63672
# Epoch 11, training RMSE = 21.40179, validation RMSE = 21.33584
# Epoch 12, training RMSE = 21.07698, validation RMSE = 20.91817
# Epoch 13, training RMSE = 20.72215, validation RMSE = 20.56357
# Epoch 14, training RMSE = 20.37485, validation RMSE = 20.20905
# Epoch 15, training RMSE = 20.01543, validation RMSE = 19.88811
# Epoch 16, training RMSE = 19.66007, validation RMSE = 19.57164
# Epoch 17, training RMSE = 19.34588, validation RMSE = 19.16207
# Epoch 18, training RMSE = 19.00447, validation RMSE = 18.81409
# Epoch 19, training RMSE = 18.65084, validation RMSE = 18.50848
# Epoch 20, training RMSE = 18.30482, validation RMSE = 18.18113
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 18.18113
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.002, lambda = 5
# Epoch 1, training RMSE = 27.03197, validation RMSE = 25.30816
# Epoch 2, training RMSE = 24.51836, validation RMSE = 24.02965
# Epoch 3, training RMSE = 23.76843, validation RMSE = 23.53553
# Epoch 4, training RMSE = 23.34114, validation RMSE = 23.12021
# Epoch 5, training RMSE = 22.96796, validation RMSE = 22.68906
# Epoch 6, training RMSE = 22.56177, validation RMSE = 22.35742
# Epoch 7, training RMSE = 22.1687, validation RMSE = 22.03541
# Epoch 8, training RMSE = 21.80471, validation RMSE = 21.66997
# Epoch 9, training RMSE = 21.4521, validation RMSE = 21.29141
# Epoch 10, training RMSE = 21.09662, validation RMSE = 20.92699
# Epoch 11, training RMSE = 20.73424, validation RMSE = 20.59315
# Epoch 12, training RMSE = 20.39113, validation RMSE = 20.21191
# Epoch 13, training RMSE = 20.01419, validation RMSE = 19.92076
# Epoch 14, training RMSE = 19.6847, validation RMSE = 19.52899
# Epoch 15, training RMSE = 19.33315, validation RMSE = 19.19705
# Epoch 16, training RMSE = 18.98182, validation RMSE = 18.87482
# Epoch 17, training RMSE = 18.64973, validation RMSE = 18.50882
# Epoch 18, training RMSE = 18.30769, validation RMSE = 18.16385
# Epoch 19, training RMSE = 17.96346, validation RMSE = 17.84557
# Epoch 20, training RMSE = 17.6423, validation RMSE = 17.47178
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 17.47178
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.001
# Epoch 1, training RMSE = 25.89286, validation RMSE = 24.20087
# Epoch 2, training RMSE = 23.3111, validation RMSE = 22.7684
# Epoch 3, training RMSE = 22.2019, validation RMSE = 21.74066
# Epoch 4, training RMSE = 21.27486, validation RMSE = 20.82487
# Epoch 5, training RMSE = 20.40272, validation RMSE = 19.9248
# Epoch 6, training RMSE = 19.50803, validation RMSE = 19.1553
# Epoch 7, training RMSE = 18.68122, validation RMSE = 18.32136
# Epoch 8, training RMSE = 17.86213, validation RMSE = 17.49801
# Epoch 9, training RMSE = 17.05728, validation RMSE = 16.68607
# Epoch 10, training RMSE = 16.26867, validation RMSE = 15.89432
# Epoch 11, training RMSE = 15.49787, validation RMSE = 15.09064
# Epoch 12, training RMSE = 14.72213, validation RMSE = 14.35663
# Epoch 13, training RMSE = 13.96548, validation RMSE = 13.62894
# Epoch 14, training RMSE = 13.23127, validation RMSE = 12.869
# Epoch 15, training RMSE = 12.50765, validation RMSE = 12.14402
# Epoch 16, training RMSE = 11.79944, validation RMSE = 11.4339
# Epoch 17, training RMSE = 11.09129, validation RMSE = 10.7528
# Epoch 18, training RMSE = 10.41059, validation RMSE = 10.06425
# Epoch 19, training RMSE = 9.73357, validation RMSE = 9.41883
# Epoch 20, training RMSE = 9.07069, validation RMSE = 8.806
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 8.806
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.005
# Epoch 1, training RMSE = 26.01943, validation RMSE = 24.35134
# Epoch 2, training RMSE = 23.66382, validation RMSE = 23.15064
# Epoch 3, training RMSE = 22.60107, validation RMSE = 22.17207
# Epoch 4, training RMSE = 21.67588, validation RMSE = 21.26053
# Epoch 5, training RMSE = 20.7898, validation RMSE = 20.36692
# Epoch 6, training RMSE = 19.92208, validation RMSE = 19.54717
# Epoch 7, training RMSE = 19.07515, validation RMSE = 18.68945
# Epoch 8, training RMSE = 18.25924, validation RMSE = 17.87249
# Epoch 9, training RMSE = 17.45103, validation RMSE = 17.04853
# Epoch 10, training RMSE = 16.64352, validation RMSE = 16.28035
# Epoch 11, training RMSE = 15.85253, validation RMSE = 15.51534
# Epoch 12, training RMSE = 15.08345, validation RMSE = 14.75019
# Epoch 13, training RMSE = 14.33999, validation RMSE = 13.97738
# Epoch 14, training RMSE = 13.60004, validation RMSE = 13.22604
# Epoch 15, training RMSE = 12.87443, validation RMSE = 12.47671
# Epoch 16, training RMSE = 12.13981, validation RMSE = 11.81163
# Epoch 17, training RMSE = 11.43989, validation RMSE = 11.10464
# Epoch 18, training RMSE = 10.75519, validation RMSE = 10.417
# Epoch 19, training RMSE = 10.07634, validation RMSE = 9.74826
# Epoch 20, training RMSE = 9.40733, validation RMSE = 9.1098
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.1098
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.01
# Epoch 1, training RMSE = 26.20869, validation RMSE = 24.9008
# Epoch 2, training RMSE = 24.12144, validation RMSE = 23.60825
# Epoch 3, training RMSE = 23.05698, validation RMSE = 22.61216
# Epoch 4, training RMSE = 22.1287, validation RMSE = 21.7147
# Epoch 5, training RMSE = 21.2422, validation RMSE = 20.86543
# Epoch 6, training RMSE = 20.38824, validation RMSE = 20.00041
# Epoch 7, training RMSE = 19.5379, validation RMSE = 19.19561
# Epoch 8, training RMSE = 18.7333, validation RMSE = 18.32596
# Epoch 9, training RMSE = 17.91881, validation RMSE = 17.50246
# Epoch 10, training RMSE = 17.1095, validation RMSE = 16.7184
# Epoch 11, training RMSE = 16.32335, validation RMSE = 15.93751
# Epoch 12, training RMSE = 15.55246, validation RMSE = 15.17787
# Epoch 13, training RMSE = 14.78554, validation RMSE = 14.43444
# Epoch 14, training RMSE = 14.04092, validation RMSE = 13.69422
# Epoch 15, training RMSE = 13.30118, validation RMSE = 12.95337
# Epoch 16, training RMSE = 12.58152, validation RMSE = 12.23497
# Epoch 17, training RMSE = 11.87926, validation RMSE = 11.52618
# Epoch 18, training RMSE = 11.18363, validation RMSE = 10.82401
# Epoch 19, training RMSE = 10.48522, validation RMSE = 10.16989
# Epoch 20, training RMSE = 9.82765, validation RMSE = 9.50056
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.50056
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.05
# Epoch 1, training RMSE = 25.97581, validation RMSE = 24.46223
# Epoch 2, training RMSE = 23.70298, validation RMSE = 23.15738
# Epoch 3, training RMSE = 22.63306, validation RMSE = 22.19931
# Epoch 4, training RMSE = 21.71847, validation RMSE = 21.30691
# Epoch 5, training RMSE = 20.84188, validation RMSE = 20.44393
# Epoch 6, training RMSE = 19.98127, validation RMSE = 19.62147
# Epoch 7, training RMSE = 19.13746, validation RMSE = 18.76941
# Epoch 8, training RMSE = 18.30322, validation RMSE = 17.97093
# Epoch 9, training RMSE = 17.49963, validation RMSE = 17.14385
# Epoch 10, training RMSE = 16.70318, validation RMSE = 16.36657
# Epoch 11, training RMSE = 15.92906, validation RMSE = 15.58163
# Epoch 12, training RMSE = 15.14491, validation RMSE = 14.8153
# Epoch 13, training RMSE = 14.40453, validation RMSE = 14.01822
# Epoch 14, training RMSE = 13.64587, validation RMSE = 13.30715
# Epoch 15, training RMSE = 12.92346, validation RMSE = 12.59381
# Epoch 16, training RMSE = 12.20628, validation RMSE = 11.85459
# Epoch 17, training RMSE = 11.49424, validation RMSE = 11.17238
# Epoch 18, training RMSE = 10.81201, validation RMSE = 10.47434
# Epoch 19, training RMSE = 10.1323, validation RMSE = 9.82051
# Epoch 20, training RMSE = 9.46941, validation RMSE = 9.14826
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.14826
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.1
# Epoch 1, training RMSE = 26.36442, validation RMSE = 24.59024
# Epoch 2, training RMSE = 23.97147, validation RMSE = 23.39519
# Epoch 3, training RMSE = 22.91111, validation RMSE = 22.43432
# Epoch 4, training RMSE = 21.98036, validation RMSE = 21.58439
# Epoch 5, training RMSE = 21.11741, validation RMSE = 20.68203
# Epoch 6, training RMSE = 20.2542, validation RMSE = 19.82247
# Epoch 7, training RMSE = 19.39769, validation RMSE = 19.06036
# Epoch 8, training RMSE = 18.57798, validation RMSE = 18.20328
# Epoch 9, training RMSE = 17.78256, validation RMSE = 17.38253
# Epoch 10, training RMSE = 16.9722, validation RMSE = 16.59548
# Epoch 11, training RMSE = 16.18348, validation RMSE = 15.8268
# Epoch 12, training RMSE = 15.41814, validation RMSE = 15.05533
# Epoch 13, training RMSE = 14.66593, validation RMSE = 14.28266
# Epoch 14, training RMSE = 13.91989, validation RMSE = 13.52647
# Epoch 15, training RMSE = 13.17067, validation RMSE = 12.86145
# Epoch 16, training RMSE = 12.46027, validation RMSE = 12.1127
# Epoch 17, training RMSE = 11.74541, validation RMSE = 11.4455
# Epoch 18, training RMSE = 11.05462, validation RMSE = 10.73617
# Epoch 19, training RMSE = 10.38489, validation RMSE = 10.05619
# Epoch 20, training RMSE = 9.71646, validation RMSE = 9.39951
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.39951
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 0.5
# Epoch 1, training RMSE = 26.21843, validation RMSE = 24.55468
# Epoch 2, training RMSE = 23.80747, validation RMSE = 23.1986
# Epoch 3, training RMSE = 22.73394, validation RMSE = 22.33241
# Epoch 4, training RMSE = 21.83851, validation RMSE = 21.39879
# Epoch 5, training RMSE = 20.92778, validation RMSE = 20.59965
# Epoch 6, training RMSE = 20.08989, validation RMSE = 19.70731
# Epoch 7, training RMSE = 19.22739, validation RMSE = 18.91987
# Epoch 8, training RMSE = 18.43156, validation RMSE = 18.03247
# Epoch 9, training RMSE = 17.6087, validation RMSE = 17.24781
# Epoch 10, training RMSE = 16.80616, validation RMSE = 16.45872
# Epoch 11, training RMSE = 16.03122, validation RMSE = 15.68122
# Epoch 12, training RMSE = 15.25233, validation RMSE = 14.92551
# Epoch 13, training RMSE = 14.51683, validation RMSE = 14.12155
# Epoch 14, training RMSE = 13.75453, validation RMSE = 13.42449
# Epoch 15, training RMSE = 13.0316, validation RMSE = 12.68003
# Epoch 16, training RMSE = 12.30616, validation RMSE = 11.97971
# Epoch 17, training RMSE = 11.60322, validation RMSE = 11.27707
# Epoch 18, training RMSE = 10.90404, validation RMSE = 10.60383
# Epoch 19, training RMSE = 10.23193, validation RMSE = 9.90723
# Epoch 20, training RMSE = 9.57416, validation RMSE = 9.22482
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.22482
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 1
# Epoch 1, training RMSE = 25.86093, validation RMSE = 24.39368
# Epoch 2, training RMSE = 23.81749, validation RMSE = 23.32865
# Epoch 3, training RMSE = 22.83428, validation RMSE = 22.42287
# Epoch 4, training RMSE = 21.94432, validation RMSE = 21.54866
# Epoch 5, training RMSE = 21.05676, validation RMSE = 20.68105
# Epoch 6, training RMSE = 20.19905, validation RMSE = 19.83857
# Epoch 7, training RMSE = 19.37365, validation RMSE = 18.96218
# Epoch 8, training RMSE = 18.54558, validation RMSE = 18.16544
# Epoch 9, training RMSE = 17.73725, validation RMSE = 17.32131
# Epoch 10, training RMSE = 16.93209, validation RMSE = 16.56331
# Epoch 11, training RMSE = 16.15445, validation RMSE = 15.77335
# Epoch 12, training RMSE = 15.37377, validation RMSE = 15.02697
# Epoch 13, training RMSE = 14.62328, validation RMSE = 14.26912
# Epoch 14, training RMSE = 13.88083, validation RMSE = 13.53602
# Epoch 15, training RMSE = 13.14913, validation RMSE = 12.79152
# Epoch 16, training RMSE = 12.41137, validation RMSE = 12.11482
# Epoch 17, training RMSE = 11.72072, validation RMSE = 11.38806
# Epoch 18, training RMSE = 11.02423, validation RMSE = 10.6803
# Epoch 19, training RMSE = 10.35045, validation RMSE = 10.01448
# Epoch 20, training RMSE = 9.67148, validation RMSE = 9.37608
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.37608
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.005, lambda = 5
# Epoch 1, training RMSE = 26.50488, validation RMSE = 24.61715
# Epoch 2, training RMSE = 24.0376, validation RMSE = 23.63841
# Epoch 3, training RMSE = 23.11363, validation RMSE = 22.70692
# Epoch 4, training RMSE = 22.19072, validation RMSE = 21.86215
# Epoch 5, training RMSE = 21.31634, validation RMSE = 20.99783
# Epoch 6, training RMSE = 20.48002, validation RMSE = 20.08112
# Epoch 7, training RMSE = 19.63238, validation RMSE = 19.28199
# Epoch 8, training RMSE = 18.81222, validation RMSE = 18.47077
# Epoch 9, training RMSE = 18.01611, validation RMSE = 17.58475
# Epoch 10, training RMSE = 17.19881, validation RMSE = 16.83808
# Epoch 11, training RMSE = 16.40646, validation RMSE = 16.08624
# Epoch 12, training RMSE = 15.64182, validation RMSE = 15.2829
# Epoch 13, training RMSE = 14.87283, validation RMSE = 14.5447
# Epoch 14, training RMSE = 14.11425, validation RMSE = 13.82898
# Epoch 15, training RMSE = 13.4028, validation RMSE = 13.05074
# Epoch 16, training RMSE = 12.67176, validation RMSE = 12.33251
# Epoch 17, training RMSE = 11.95915, validation RMSE = 11.63897
# Epoch 18, training RMSE = 11.26315, validation RMSE = 10.95238
# Epoch 19, training RMSE = 10.59265, validation RMSE = 10.257
# Epoch 20, training RMSE = 9.91916, validation RMSE = 9.58053
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 9.58053
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.001
# Epoch 1, training RMSE = 25.09228, validation RMSE = 22.94608
# Epoch 2, training RMSE = 22.03726, validation RMSE = 21.12011
# Epoch 3, training RMSE = 20.24884, validation RMSE = 19.46549
# Epoch 4, training RMSE = 18.59293, validation RMSE = 17.77928
# Epoch 5, training RMSE = 16.95987, validation RMSE = 16.29418
# Epoch 6, training RMSE = 15.48133, validation RMSE = 14.75666
# Epoch 7, training RMSE = 14.01117, validation RMSE = 13.34631
# Epoch 8, training RMSE = 12.62898, validation RMSE = 11.94839
# Epoch 9, training RMSE = 11.30031, validation RMSE = 10.67076
# Epoch 10, training RMSE = 10.05332, validation RMSE = 9.43765
# Epoch 11, training RMSE = 8.86986, validation RMSE = 8.32498
# Epoch 12, training RMSE = 7.7653, validation RMSE = 7.26972
# Epoch 13, training RMSE = 6.74353, validation RMSE = 6.24686
# Epoch 14, training RMSE = 5.78678, validation RMSE = 5.33445
# Epoch 15, training RMSE = 4.92019, validation RMSE = 4.49724
# Epoch 16, training RMSE = 4.12977, validation RMSE = 3.75225
# Epoch 17, training RMSE = 3.42601, validation RMSE = 3.12796
# Epoch 18, training RMSE = 2.80082, validation RMSE = 2.56254
# Epoch 19, training RMSE = 2.31042, validation RMSE = 2.04835
# Epoch 20, training RMSE = 1.87579, validation RMSE = 1.67062
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.67062
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.005
# Epoch 1, training RMSE = 25.25536, validation RMSE = 23.64579
# Epoch 2, training RMSE = 22.65213, validation RMSE = 21.75592
# Epoch 3, training RMSE = 20.85414, validation RMSE = 20.03404
# Epoch 4, training RMSE = 19.18691, validation RMSE = 18.36963
# Epoch 5, training RMSE = 17.59969, validation RMSE = 16.78429
# Epoch 6, training RMSE = 16.03963, validation RMSE = 15.31843
# Epoch 7, training RMSE = 14.57681, validation RMSE = 13.90467
# Epoch 8, training RMSE = 13.17191, validation RMSE = 12.54458
# Epoch 9, training RMSE = 11.84452, validation RMSE = 11.21539
# Epoch 10, training RMSE = 10.5837, validation RMSE = 9.97678
# Epoch 11, training RMSE = 9.3848, validation RMSE = 8.79314
# Epoch 12, training RMSE = 8.24043, validation RMSE = 7.75357
# Epoch 13, training RMSE = 7.20228, validation RMSE = 6.68273
# Epoch 14, training RMSE = 6.21599, validation RMSE = 5.74253
# Epoch 15, training RMSE = 5.30946, validation RMSE = 4.90515
# Epoch 16, training RMSE = 4.51147, validation RMSE = 4.08941
# Epoch 17, training RMSE = 3.75507, validation RMSE = 3.43839
# Epoch 18, training RMSE = 3.10377, validation RMSE = 2.79623
# Epoch 19, training RMSE = 2.53542, validation RMSE = 2.282
# Epoch 20, training RMSE = 2.03149, validation RMSE = 1.92075
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.92075
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.01
# Epoch 1, training RMSE = 25.38552, validation RMSE = 23.60246
# Epoch 2, training RMSE = 22.59153, validation RMSE = 21.67915
# Epoch 3, training RMSE = 20.79467, validation RMSE = 19.96434
# Epoch 4, training RMSE = 19.11836, validation RMSE = 18.34683
# Epoch 5, training RMSE = 17.51509, validation RMSE = 16.80204
# Epoch 6, training RMSE = 15.98594, validation RMSE = 15.25884
# Epoch 7, training RMSE = 14.52308, validation RMSE = 13.86331
# Epoch 8, training RMSE = 13.12981, validation RMSE = 12.47535
# Epoch 9, training RMSE = 11.7945, validation RMSE = 11.15858
# Epoch 10, training RMSE = 10.5161, validation RMSE = 9.93739
# Epoch 11, training RMSE = 9.3152, validation RMSE = 8.81066
# Epoch 12, training RMSE = 8.20322, validation RMSE = 7.68879
# Epoch 13, training RMSE = 7.14536, validation RMSE = 6.68064
# Epoch 14, training RMSE = 6.16028, validation RMSE = 5.75027
# Epoch 15, training RMSE = 5.28087, validation RMSE = 4.83664
# Epoch 16, training RMSE = 4.4638, validation RMSE = 4.05165
# Epoch 17, training RMSE = 3.72422, validation RMSE = 3.37191
# Epoch 18, training RMSE = 3.08688, validation RMSE = 2.77342
# Epoch 19, training RMSE = 2.51434, validation RMSE = 2.2773
# Epoch 20, training RMSE = 2.05848, validation RMSE = 1.8131
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.8131
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.05
# Epoch 1, training RMSE = 24.50451, validation RMSE = 22.77583
# Epoch 2, training RMSE = 21.77574, validation RMSE = 20.93066
# Epoch 3, training RMSE = 19.98763, validation RMSE = 19.23671
# Epoch 4, training RMSE = 18.32831, validation RMSE = 17.63614
# Epoch 5, training RMSE = 16.7549, validation RMSE = 16.05431
# Epoch 6, training RMSE = 15.23384, validation RMSE = 14.53356
# Epoch 7, training RMSE = 13.77894, validation RMSE = 13.08061
# Epoch 8, training RMSE = 12.38041, validation RMSE = 11.76365
# Epoch 9, training RMSE = 11.08985, validation RMSE = 10.45213
# Epoch 10, training RMSE = 9.83582, validation RMSE = 9.25492
# Epoch 11, training RMSE = 8.66, validation RMSE = 8.14322
# Epoch 12, training RMSE = 7.57467, validation RMSE = 7.04495
# Epoch 13, training RMSE = 6.54849, validation RMSE = 6.07635
# Epoch 14, training RMSE = 5.60928, validation RMSE = 5.17563
# Epoch 15, training RMSE = 4.75075, validation RMSE = 4.37192
# Epoch 16, training RMSE = 3.97131, validation RMSE = 3.66468
# Epoch 17, training RMSE = 3.29859, validation RMSE = 3.05892
# Epoch 18, training RMSE = 2.70929, validation RMSE = 2.4257
# Epoch 19, training RMSE = 2.18396, validation RMSE = 2.02115
# Epoch 20, training RMSE = 1.78762, validation RMSE = 1.59803
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.59803
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.1
# Epoch 1, training RMSE = 24.81959, validation RMSE = 23.26557
# Epoch 2, training RMSE = 22.271, validation RMSE = 21.41061
# Epoch 3, training RMSE = 20.51714, validation RMSE = 19.69155
# Epoch 4, training RMSE = 18.83436, validation RMSE = 18.09565
# Epoch 5, training RMSE = 17.23065, validation RMSE = 16.59974
# Epoch 6, training RMSE = 15.7301, validation RMSE = 15.00364
# Epoch 7, training RMSE = 14.24391, validation RMSE = 13.62531
# Epoch 8, training RMSE = 12.88121, validation RMSE = 12.2156
# Epoch 9, training RMSE = 11.53496, validation RMSE = 10.92734
# Epoch 10, training RMSE = 10.28125, validation RMSE = 9.692
# Epoch 11, training RMSE = 9.09191, validation RMSE = 8.50615
# Epoch 12, training RMSE = 7.97662, validation RMSE = 7.44186
# Epoch 13, training RMSE = 6.92978, validation RMSE = 6.437
# Epoch 14, training RMSE = 5.97063, validation RMSE = 5.49613
# Epoch 15, training RMSE = 5.09153, validation RMSE = 4.64493
# Epoch 16, training RMSE = 4.26329, validation RMSE = 3.94229
# Epoch 17, training RMSE = 3.57278, validation RMSE = 3.23007
# Epoch 18, training RMSE = 2.94301, validation RMSE = 2.65199
# Epoch 19, training RMSE = 2.39405, validation RMSE = 2.17138
# Epoch 20, training RMSE = 1.94848, validation RMSE = 1.76352
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.76352
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 0.5
# Epoch 1, training RMSE = 24.35688, validation RMSE = 22.72202
# Epoch 2, training RMSE = 21.76994, validation RMSE = 20.95125
# Epoch 3, training RMSE = 20.04791, validation RMSE = 19.20507
# Epoch 4, training RMSE = 18.36246, validation RMSE = 17.61832
# Epoch 5, training RMSE = 16.76498, validation RMSE = 16.0612
# Epoch 6, training RMSE = 15.25452, validation RMSE = 14.56761
# Epoch 7, training RMSE = 13.80722, validation RMSE = 13.10064
# Epoch 8, training RMSE = 12.42129, validation RMSE = 11.74517
# Epoch 9, training RMSE = 11.1109, validation RMSE = 10.47717
# Epoch 10, training RMSE = 9.86072, validation RMSE = 9.28558
# Epoch 11, training RMSE = 8.6974, validation RMSE = 8.12194
# Epoch 12, training RMSE = 7.58402, validation RMSE = 7.09043
# Epoch 13, training RMSE = 6.57705, validation RMSE = 6.09245
# Epoch 14, training RMSE = 5.64044, validation RMSE = 5.17998
# Epoch 15, training RMSE = 4.77341, validation RMSE = 4.36371
# Epoch 16, training RMSE = 3.99468, validation RMSE = 3.67672
# Epoch 17, training RMSE = 3.32623, validation RMSE = 3.01065
# Epoch 18, training RMSE = 2.70818, validation RMSE = 2.50192
# Epoch 19, training RMSE = 2.20612, validation RMSE = 1.99245
# Epoch 20, training RMSE = 1.78231, validation RMSE = 1.66585
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.66585
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 1
# Epoch 1, training RMSE = 25.02466, validation RMSE = 23.39427
# Epoch 2, training RMSE = 22.37768, validation RMSE = 21.62037
# Epoch 3, training RMSE = 20.68645, validation RMSE = 19.7581
# Epoch 4, training RMSE = 18.97474, validation RMSE = 18.16833
# Epoch 5, training RMSE = 17.38265, validation RMSE = 16.63212
# Epoch 6, training RMSE = 15.8529, validation RMSE = 15.10912
# Epoch 7, training RMSE = 14.367, validation RMSE = 13.72655
# Epoch 8, training RMSE = 12.97821, validation RMSE = 12.33865
# Epoch 9, training RMSE = 11.6777, validation RMSE = 11.01188
# Epoch 10, training RMSE = 10.38264, validation RMSE = 9.8002
# Epoch 11, training RMSE = 9.19235, validation RMSE = 8.65731
# Epoch 12, training RMSE = 8.07697, validation RMSE = 7.58952
# Epoch 13, training RMSE = 7.03388, validation RMSE = 6.5597
# Epoch 14, training RMSE = 6.0771, validation RMSE = 5.61912
# Epoch 15, training RMSE = 5.18294, validation RMSE = 4.74256
# Epoch 16, training RMSE = 4.36162, validation RMSE = 4.02505
# Epoch 17, training RMSE = 3.64178, validation RMSE = 3.3209
# Epoch 18, training RMSE = 3.0029, validation RMSE = 2.7286
# Epoch 19, training RMSE = 2.4714, validation RMSE = 2.20458
# Epoch 20, training RMSE = 2.00928, validation RMSE = 1.80341
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.80341
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.01, lambda = 5
# Epoch 1, training RMSE = 25.36973, validation RMSE = 23.62082
# Epoch 2, training RMSE = 22.72044, validation RMSE = 21.80576
# Epoch 3, training RMSE = 20.94815, validation RMSE = 20.17195
# Epoch 4, training RMSE = 19.29024, validation RMSE = 18.50048
# Epoch 5, training RMSE = 17.68787, validation RMSE = 16.89929
# Epoch 6, training RMSE = 16.13187, validation RMSE = 15.50744
# Epoch 7, training RMSE = 14.67506, validation RMSE = 14.00748
# Epoch 8, training RMSE = 13.29886, validation RMSE = 12.579
# Epoch 9, training RMSE = 11.94239, validation RMSE = 11.31134
# Epoch 10, training RMSE = 10.66933, validation RMSE = 10.10157
# Epoch 11, training RMSE = 9.46538, validation RMSE = 8.92814
# Epoch 12, training RMSE = 8.34544, validation RMSE = 7.859
# Epoch 13, training RMSE = 7.28718, validation RMSE = 6.81734
# Epoch 14, training RMSE = 6.33107, validation RMSE = 5.83306
# Epoch 15, training RMSE = 5.39389, validation RMSE = 5.0073
# Epoch 16, training RMSE = 4.59847, validation RMSE = 4.22511
# Epoch 17, training RMSE = 3.85474, validation RMSE = 3.54464
# Epoch 18, training RMSE = 3.20196, validation RMSE = 2.94207
# Epoch 19, training RMSE = 2.65399, validation RMSE = 2.45638
# Epoch 20, training RMSE = 2.16571, validation RMSE = 1.98459
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.98459
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.001
# Epoch 1, training RMSE = 23.32603, validation RMSE = 20.36614
# Epoch 2, training RMSE = 18.40355, validation RMSE = 16.53271
# Epoch 3, training RMSE = 14.67819, validation RMSE = 12.90991
# Epoch 4, training RMSE = 11.35614, validation RMSE = 9.82099
# Epoch 5, training RMSE = 8.51592, validation RMSE = 7.31337
# Epoch 6, training RMSE = 6.23521, validation RMSE = 5.26001
# Epoch 7, training RMSE = 4.40928, validation RMSE = 3.60701
# Epoch 8, training RMSE = 3.0341, validation RMSE = 2.48095
# Epoch 9, training RMSE = 2.0831, validation RMSE = 1.69504
# Epoch 10, training RMSE = 1.44044, validation RMSE = 1.40775
# Epoch 11, training RMSE = 1.29507, validation RMSE = 1.19935
# Epoch 12, training RMSE = 1.20019, validation RMSE = 1.41929
# Epoch 13, training RMSE = 1.06354, validation RMSE = 1.59016
# Epoch 14, training RMSE = 1.61826, validation RMSE = 1.56525
# Epoch 15, training RMSE = 1.39572, validation RMSE = 1.51585
# Epoch 16, training RMSE = 1.58588, validation RMSE = 1.80875
# Epoch 17, training RMSE = 1.36406, validation RMSE = 1.43776
# Epoch 18, training RMSE = 1.6058, validation RMSE = 1.65362
# Epoch 19, training RMSE = 1.70654, validation RMSE = 1.31209
# Epoch 20, training RMSE = 1.47939, validation RMSE = 0.90263
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 0.90263
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.005
# Epoch 1, training RMSE = 23.07014, validation RMSE = 20.51136
# Epoch 2, training RMSE = 18.44281, validation RMSE = 16.4423
# Epoch 3, training RMSE = 14.65169, validation RMSE = 12.97392
# Epoch 4, training RMSE = 11.37214, validation RMSE = 9.90899
# Epoch 5, training RMSE = 8.57662, validation RMSE = 7.3194
# Epoch 6, training RMSE = 6.28579, validation RMSE = 5.2553
# Epoch 7, training RMSE = 4.41998, validation RMSE = 3.63612
# Epoch 8, training RMSE = 3.09992, validation RMSE = 2.53121
# Epoch 9, training RMSE = 2.0781, validation RMSE = 1.73161
# Epoch 10, training RMSE = 1.48814, validation RMSE = 1.26175
# Epoch 11, training RMSE = 1.08628, validation RMSE = 1.25886
# Epoch 12, training RMSE = 1.05839, validation RMSE = 1.11073
# Epoch 13, training RMSE = 1.19638, validation RMSE = 1.11502
# Epoch 14, training RMSE = 1.43479, validation RMSE = 1.92398
# Epoch 15, training RMSE = 2.35608, validation RMSE = 1.76826
# Epoch 16, training RMSE = 1.99578, validation RMSE = 1.54988
# Epoch 17, training RMSE = 1.54728, validation RMSE = 1.06613
# Epoch 18, training RMSE = 1.05989, validation RMSE = 0.96724
# Epoch 19, training RMSE = 1.06562, validation RMSE = 1.04428
# Epoch 20, training RMSE = 1.05414, validation RMSE = 1.23855
# ==========Model result==========
# Best epoch is 18 with minimum validation error = 0.96724
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.01
# Epoch 1, training RMSE = 23.34528, validation RMSE = 20.7265
# Epoch 2, training RMSE = 18.70514, validation RMSE = 16.64395
# Epoch 3, training RMSE = 14.88435, validation RMSE = 13.10207
# Epoch 4, training RMSE = 11.5563, validation RMSE = 10.1026
# Epoch 5, training RMSE = 8.7387, validation RMSE = 7.44733
# Epoch 6, training RMSE = 6.42286, validation RMSE = 5.3527
# Epoch 7, training RMSE = 4.56074, validation RMSE = 3.7803
# Epoch 8, training RMSE = 3.144, validation RMSE = 2.59409
# Epoch 9, training RMSE = 2.16297, validation RMSE = 1.68929
# Epoch 10, training RMSE = 1.4949, validation RMSE = 1.2589
# Epoch 11, training RMSE = 1.2094, validation RMSE = 1.18291
# Epoch 12, training RMSE = 1.17482, validation RMSE = 1.22659
# Epoch 13, training RMSE = 1.29831, validation RMSE = 1.13842
# Epoch 14, training RMSE = 1.3668, validation RMSE = 1.29441
# Epoch 15, training RMSE = 1.54839, validation RMSE = 1.41395
# Epoch 16, training RMSE = 1.61282, validation RMSE = 1.21455
# Epoch 17, training RMSE = 1.24665, validation RMSE = 1.26044
# Epoch 18, training RMSE = 1.48796, validation RMSE = 1.49124
# Epoch 19, training RMSE = 1.39643, validation RMSE = 1.41326
# Epoch 20, training RMSE = 1.55459, validation RMSE = 1.63177
# ==========Model result==========
# Best epoch is 13 with minimum validation error = 1.13842
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.05
# Epoch 1, training RMSE = 23.60871, validation RMSE = 20.9681
# Epoch 2, training RMSE = 18.94441, validation RMSE = 16.96264
# Epoch 3, training RMSE = 15.11124, validation RMSE = 13.4371
# Epoch 4, training RMSE = 11.79944, validation RMSE = 10.29479
# Epoch 5, training RMSE = 8.99007, validation RMSE = 7.67489
# Epoch 6, training RMSE = 6.61134, validation RMSE = 5.61552
# Epoch 7, training RMSE = 4.7073, validation RMSE = 3.88514
# Epoch 8, training RMSE = 3.27331, validation RMSE = 2.69581
# Epoch 9, training RMSE = 2.20881, validation RMSE = 1.9721
# Epoch 10, training RMSE = 1.6215, validation RMSE = 1.36662
# Epoch 11, training RMSE = 1.25912, validation RMSE = 1.22154
# Epoch 12, training RMSE = 1.3834, validation RMSE = 1.0724
# Epoch 13, training RMSE = 1.36453, validation RMSE = 1.24291
# Epoch 14, training RMSE = 1.43705, validation RMSE = 1.90424
# Epoch 15, training RMSE = 1.31389, validation RMSE = 1.26807
# Epoch 16, training RMSE = 1.44056, validation RMSE = 1.57477
# Epoch 17, training RMSE = 1.93661, validation RMSE = 1.98685
# Epoch 18, training RMSE = 2.16356, validation RMSE = 1.24417
# Epoch 19, training RMSE = 1.25906, validation RMSE = 1.60281
# Epoch 20, training RMSE = 1.33949, validation RMSE = 1.34109
# ==========Model result==========
# Best epoch is 12 with minimum validation error = 1.0724
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.1
# Epoch 1, training RMSE = 22.74232, validation RMSE = 20.091
# Epoch 2, training RMSE = 18.07479, validation RMSE = 16.04454
# Epoch 3, training RMSE = 14.27861, validation RMSE = 12.62195
# Epoch 4, training RMSE = 11.03858, validation RMSE = 9.63476
# Epoch 5, training RMSE = 8.24758, validation RMSE = 7.03525
# Epoch 6, training RMSE = 5.98054, validation RMSE = 5.01417
# Epoch 7, training RMSE = 4.20838, validation RMSE = 3.50422
# Epoch 8, training RMSE = 2.87106, validation RMSE = 2.46428
# Epoch 9, training RMSE = 2.01959, validation RMSE = 1.62834
# Epoch 10, training RMSE = 1.54614, validation RMSE = 1.30141
# Epoch 11, training RMSE = 1.15867, validation RMSE = 1.35294
# Epoch 12, training RMSE = 1.32641, validation RMSE = 1.33493
# Epoch 13, training RMSE = 1.52579, validation RMSE = 1.41939
# Epoch 14, training RMSE = 1.55151, validation RMSE = 1.53745
# Epoch 15, training RMSE = 1.58334, validation RMSE = 1.28674
# Epoch 16, training RMSE = 1.43411, validation RMSE = 1.31575
# Epoch 17, training RMSE = 1.55766, validation RMSE = 1.3565
# Epoch 18, training RMSE = 1.55605, validation RMSE = 1.20737
# Epoch 19, training RMSE = 1.44661, validation RMSE = 1.59422
# Epoch 20, training RMSE = 1.43381, validation RMSE = 1.13485
# ==========Model result==========
# Best epoch is 20 with minimum validation error = 1.13485
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 0.5
# Epoch 1, training RMSE = 23.15922, validation RMSE = 20.90745
# Epoch 2, training RMSE = 18.6105, validation RMSE = 16.56347
# Epoch 3, training RMSE = 14.73459, validation RMSE = 12.9893
# Epoch 4, training RMSE = 11.42303, validation RMSE = 9.94059
# Epoch 5, training RMSE = 8.64174, validation RMSE = 7.31718
# Epoch 6, training RMSE = 6.26792, validation RMSE = 5.38626
# Epoch 7, training RMSE = 4.44255, validation RMSE = 3.76151
# Epoch 8, training RMSE = 3.08043, validation RMSE = 2.5583
# Epoch 9, training RMSE = 2.12877, validation RMSE = 1.93083
# Epoch 10, training RMSE = 1.52425, validation RMSE = 1.48485
# Epoch 11, training RMSE = 1.34928, validation RMSE = 1.45211
# Epoch 12, training RMSE = 1.08599, validation RMSE = 1.29241
# Epoch 13, training RMSE = 1.16035, validation RMSE = 1.50335
# Epoch 14, training RMSE = 1.63791, validation RMSE = 1.17332
# Epoch 15, training RMSE = 1.32126, validation RMSE = 1.10068
# Epoch 16, training RMSE = 1.3347, validation RMSE = 1.31913
# Epoch 17, training RMSE = 1.39058, validation RMSE = 1.26021
# Epoch 18, training RMSE = 1.42569, validation RMSE = 1.27152
# Epoch 19, training RMSE = 1.45213, validation RMSE = 1.89468
# Epoch 20, training RMSE = 1.87781, validation RMSE = 1.45654
# ==========Model result==========
# Best epoch is 15 with minimum validation error = 1.10068
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 1
# Epoch 1, training RMSE = 23.50118, validation RMSE = 20.81992
# Epoch 2, training RMSE = 18.74426, validation RMSE = 16.83479
# Epoch 3, training RMSE = 14.94256, validation RMSE = 13.18454
# Epoch 4, training RMSE = 11.6039, validation RMSE = 10.07907
# Epoch 5, training RMSE = 8.78345, validation RMSE = 7.51971
# Epoch 6, training RMSE = 6.43712, validation RMSE = 5.40084
# Epoch 7, training RMSE = 4.56003, validation RMSE = 3.80057
# Epoch 8, training RMSE = 3.18143, validation RMSE = 2.56554
# Epoch 9, training RMSE = 2.14987, validation RMSE = 1.92925
# Epoch 10, training RMSE = 1.60351, validation RMSE = 1.57569
# Epoch 11, training RMSE = 1.58638, validation RMSE = 1.50628
# Epoch 12, training RMSE = 1.38594, validation RMSE = 1.28213
# Epoch 13, training RMSE = 1.1812, validation RMSE = 1.06881
# Epoch 14, training RMSE = 1.1574, validation RMSE = 1.10668
# Epoch 15, training RMSE = 1.3367, validation RMSE = 1.61321
# Epoch 16, training RMSE = 1.48345, validation RMSE = 1.08948
# Epoch 17, training RMSE = 1.17041, validation RMSE = 1.30539
# Epoch 18, training RMSE = 1.22532, validation RMSE = 1.1766
# Epoch 19, training RMSE = 1.24936, validation RMSE = 1.44166
# Epoch 20, training RMSE = 1.29757, validation RMSE = 1.37121
# ==========Model result==========
# Best epoch is 13 with minimum validation error = 1.06881
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.025, lambda = 5
# Epoch 1, training RMSE = 23.66643, validation RMSE = 21.00058
# Epoch 2, training RMSE = 18.9394, validation RMSE = 17.11745
# Epoch 3, training RMSE = 15.1893, validation RMSE = 13.5003
# Epoch 4, training RMSE = 11.85669, validation RMSE = 10.37379
# Epoch 5, training RMSE = 9.01096, validation RMSE = 7.76722
# Epoch 6, training RMSE = 6.62539, validation RMSE = 5.60582
# Epoch 7, training RMSE = 4.76915, validation RMSE = 4.03401
# Epoch 8, training RMSE = 3.38717, validation RMSE = 2.65701
# Epoch 9, training RMSE = 2.33754, validation RMSE = 1.87514
# Epoch 10, training RMSE = 1.74425, validation RMSE = 1.58735
# Epoch 11, training RMSE = 1.43638, validation RMSE = 1.58943
# Epoch 12, training RMSE = 1.52771, validation RMSE = 1.34035
# Epoch 13, training RMSE = 1.39919, validation RMSE = 1.53329
# Epoch 14, training RMSE = 1.8179, validation RMSE = 1.69663
# Epoch 15, training RMSE = 1.54851, validation RMSE = 1.12309
# Epoch 16, training RMSE = 1.25576, validation RMSE = 1.6955
# Epoch 17, training RMSE = 1.36182, validation RMSE = 1.73974
# Epoch 18, training RMSE = 1.71282, validation RMSE = 1.23875
# Epoch 19, training RMSE = 1.95619, validation RMSE = 1.47575
# Epoch 20, training RMSE = 1.62854, validation RMSE = 1.49888
# ==========Model result==========
# Best epoch is 15 with minimum validation error = 1.12309
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.05, lambda = 0.001
# Epoch 1, training RMSE = 20.95661, validation RMSE = 16.78242
# Epoch 2, training RMSE = 13.25037, validation RMSE = 10.39627
# Epoch 3, training RMSE = 7.86941, validation RMSE = 5.97378
# Epoch 4, training RMSE = 4.32587, validation RMSE = 3.03386
# Epoch 5, training RMSE = 2.65238, validation RMSE = 3.0414
# Epoch 6, training RMSE = 2.52155, validation RMSE = 2.08798
# Epoch 7, training RMSE = 2.48524, validation RMSE = 1.46149
# Epoch 8, training RMSE = 1.8473, validation RMSE = 2.22473
# Epoch 9, training RMSE = 2.71289, validation RMSE = 3.15306
# Epoch 10, training RMSE = 2.50388, validation RMSE = 2.1975
# Epoch 11, training RMSE = 1.94063, validation RMSE = 2.00534
# Epoch 12, training RMSE = 1.95811, validation RMSE = 2.02106
# Epoch 13, training RMSE = 1.76338, validation RMSE = 1.98981
# Epoch 14, training RMSE = 2.39485, validation RMSE = 3.10683
# Epoch 15, training RMSE = 3.86451, validation RMSE = 2.80471
# Epoch 16, training RMSE = 3.47686, validation RMSE = 2.44457
# Epoch 17, training RMSE = 3.44053, validation RMSE = 1.87382
# Early Stopping!
# ==========validation result==========
# Best epoch is 7 with minimum validation error = 1.46149
# ========== Start training model ==========
# batch size = 64, epoch_size = 20, learning rate = 0.05, lambda = 0.005
# Epoch 1, training RMSE = 21.39485, validation RMSE = 17.24904
# Epoch 2, training RMSE = 13.48482, validation RMSE = 10.37667
# Epoch 3, training RMSE = 7.80942, validation RMSE = 5.51669
# Epoch 4, training RMSE = 4.18297, validation RMSE = 3.73176
# Epoch 5, training RMSE = 3.62172, validation RMSE = 2.14236
# Epoch 6, training RMSE = 2.46963, validation RMSE = 2.15476
# Epoch 7, training RMSE = 1.74039, validation RMSE = 1.57758
# Epoch 8, training RMSE = 1.88247, validation RMSE = 2.12544
# Epoch 9, training RMSE = 2.36149, validation RMSE = 2.02366
# Epoch 10, training RMSE = 2.17462, validation RMSE = 1.35803
# Epoch 11, training RMSE = 1.72249, validation RMSE = 2.04275
# ...
# Epoch 48, training RMSE = 6.01519, validation RMSE = 6.08566
# Epoch 49, training RMSE = 5.80845, validation RMSE = 5.82885
# Epoch 50, training RMSE = 5.59019, validation RMSE = 5.58721
# Epoch 51, training RMSE = 5.36606, validation RMSE = 5.39744
# Epoch 52, training RMSE = 5.15673, validation RMSE = 5.17554
# Epoch 53, training RMSE = 4.95297, validation RMSE = 4.99799
# Epoch 54, training RMSE = 4.75578, validation RMSE = 4.81607
# Epoch 55, training RMSE = 4.5701, validation RMSE = 4.60382
# Epoch 56, training RMSE = 4.39115, validation RMSE = 4.386
# Epoch 57, training RMSE = 4.21462, validation RMSE = 4.21417
# Epoch 58, training RMSE = 4.03532, validation RMSE = 4.05588
# Epoch 59, training RMSE = 3.87438, validation RMSE = 3.88501
# Epoch 60, training RMSE = 3.70092, validation RMSE = 3.75353
# Epoch 61, training RMSE = 3.55399, validation RMSE = 3.60176
# Epoch 62, training RMSE = 3.40151, validation RMSE = 3.44839
# Epoch 63, training RMSE = 3.26436, validation RMSE = 3.28216
# Epoch 64, training RMSE = 3.10722, validation RMSE = 3.14029
# Epoch 65, training RMSE = 2.98832, validation RMSE = 3.00144
# Epoch 66, training RMSE = 2.85207, validation RMSE = 2.88922
# Epoch 67, training RMSE = 2.73405, validation RMSE = 2.76619
# Epoch 68, training RMSE = 2.62983, validation RMSE = 2.61658
# Epoch 69, training RMSE = 2.51469, validation RMSE = 2.48918
# Epoch 70, training RMSE = 2.39869, validation RMSE = 2.41073
# Epoch 71, training RMSE = 2.27122, validation RMSE = 2.34523
# Epoch 72, training RMSE = 2.17399, validation RMSE = 2.24425
# Epoch 73, training RMSE = 2.07256, validation RMSE = 2.15105
# Epoch 74, training RMSE = 2.0117, validation RMSE = 2.01744
# Epoch 75, training RMSE = 1.92996, validation RMSE = 1.91972
# Epoch 76, training RMSE = 1.8299, validation RMSE = 1.87277
# Epoch 77, training RMSE = 1.79922, validation RMSE = 1.69713
# Epoch 78, training RMSE = 1.69377, validation RMSE = 1.69342
# Epoch 79, training RMSE = 1.61699, validation RMSE = 1.6465
# Epoch 80, training RMSE = 1.51742, validation RMSE = 1.66599
# Epoch 81, training RMSE = 1.46228, validation RMSE = 1.58539
# Epoch 82, training RMSE = 1.4465, validation RMSE = 1.42529
# Epoch 83, training RMSE = 1.39804, validation RMSE = 1.31628
# Epoch 84, training RMSE = 1.30716, validation RMSE = 1.36927
# Epoch 85, training RMSE = 1.27442, validation RMSE = 1.29156
# Epoch 86, training RMSE = 1.2115, validation RMSE = 1.2918
# Epoch 87, training RMSE = 1.1947, validation RMSE = 1.18315
# Epoch 88, training RMSE = 1.14874, validation RMSE = 1.14648
# Epoch 89, training RMSE = 1.13642, validation RMSE = 1.04811
# Epoch 90, training RMSE = 1.04611, validation RMSE = 1.17732
# Epoch 91, training RMSE = 1.06248, validation RMSE = 1.04226
# Epoch 92, training RMSE = 1.06699, validation RMSE = 0.94125
# Epoch 93, training RMSE = 1.01223, validation RMSE = 0.98817
# Epoch 94, training RMSE = 1.01017, validation RMSE = 0.8678
# Epoch 95, training RMSE = 0.94914, validation RMSE = 0.97737
# Epoch 96, training RMSE = 0.92354, validation RMSE = 0.97516
# Epoch 97, training RMSE = 0.86435, validation RMSE = 1.04458
# Epoch 98, training RMSE = 0.87817, validation RMSE = 0.97137
# Epoch 99, training RMSE = 0.85056, validation RMSE = 0.88916
# Epoch 100, training RMSE = 0.88699, validation RMSE = 0.79431
# ==========Model result==========
# Best epoch is 100 with minimum validation error = 0.79431
# ========== Start training model ==========
# batch size = 1024, epoch_size = 100, learning rate = 0.05, lambda = 1
# Epoch 1, training RMSE = 26.15646, validation RMSE = 24.60171
# Epoch 2, training RMSE = 23.45705, validation RMSE = 23.65253
# Epoch 3, training RMSE = 22.73636, validation RMSE = 22.96612
# Epoch 4, training RMSE = 22.02952, validation RMSE = 22.25844
# Epoch 5, training RMSE = 21.44324, validation RMSE = 21.73055
# Epoch 6, training RMSE = 20.92897, validation RMSE = 21.16204
# Epoch 7, training RMSE = 20.39159, validation RMSE = 20.70294
# Epoch 8, training RMSE = 19.89868, validation RMSE = 20.17416
# Epoch 9, training RMSE = 19.40549, validation RMSE = 19.65049
# Epoch 10, training RMSE = 18.92479, validation RMSE = 19.15218
# Epoch 11, training RMSE = 18.44604, validation RMSE = 18.6599
# Epoch 12, training RMSE = 17.94612, validation RMSE = 18.18503
# Epoch 13, training RMSE = 17.4874, validation RMSE = 17.70898
# Epoch 14, training RMSE = 17.01788, validation RMSE = 17.24578
# Epoch 15, training RMSE = 16.56008, validation RMSE = 16.75858
# Epoch 16, training RMSE = 16.11631, validation RMSE = 16.32149
# Epoch 17, training RMSE = 15.67797, validation RMSE = 15.84946
# Epoch 18, training RMSE = 15.24129, validation RMSE = 15.39727
# Epoch 19, training RMSE = 14.81606, validation RMSE = 14.9721
# Epoch 20, training RMSE = 14.37747, validation RMSE = 14.55451
# Epoch 21, training RMSE = 13.97929, validation RMSE = 14.07955
# Epoch 22, training RMSE = 13.56603, validation RMSE = 13.71117
# Epoch 23, training RMSE = 13.17555, validation RMSE = 13.34862
# Epoch 24, training RMSE = 12.77457, validation RMSE = 12.92641
# Epoch 25, training RMSE = 12.40446, validation RMSE = 12.51115
# Epoch 26, training RMSE = 12.00691, validation RMSE = 12.12683
# Epoch 27, training RMSE = 11.64547, validation RMSE = 11.71895
# Epoch 28, training RMSE = 11.26231, validation RMSE = 11.38716
# Epoch 29, training RMSE = 10.91048, validation RMSE = 11.01793
# Epoch 30, training RMSE = 10.57036, validation RMSE = 10.63981
# Epoch 31, training RMSE = 10.22391, validation RMSE = 10.30141
# Epoch 32, training RMSE = 9.89156, validation RMSE = 9.95502
# Epoch 33, training RMSE = 9.56506, validation RMSE = 9.61843
# Epoch 34, training RMSE = 9.23523, validation RMSE = 9.31833
# Epoch 35, training RMSE = 8.92255, validation RMSE = 9.01116
# Epoch 36, training RMSE = 8.62665, validation RMSE = 8.66312
# Epoch 37, training RMSE = 8.31876, validation RMSE = 8.37551
# Epoch 38, training RMSE = 8.03636, validation RMSE = 8.08107
# Epoch 39, training RMSE = 7.73758, validation RMSE = 7.82263
# Epoch 40, training RMSE = 7.46328, validation RMSE = 7.49979
# Epoch 41, training RMSE = 7.19217, validation RMSE = 7.24172
# Epoch 42, training RMSE = 6.93291, validation RMSE = 6.96844
# Epoch 43, training RMSE = 6.66917, validation RMSE = 6.72785
# Epoch 44, training RMSE = 6.40504, validation RMSE = 6.4764
# Epoch 45, training RMSE = 6.17055, validation RMSE = 6.21372
# Epoch 46, training RMSE = 5.93657, validation RMSE = 5.97786
# Epoch 47, training RMSE = 5.70915, validation RMSE = 5.75533
# Epoch 48, training RMSE = 5.48299, validation RMSE = 5.52522
# Epoch 49, training RMSE = 5.24994, validation RMSE = 5.31606
# Epoch 50, training RMSE = 5.05987, validation RMSE = 5.08197
# Epoch 51, training RMSE = 4.85524, validation RMSE = 4.90298
# Epoch 52, training RMSE = 4.6594, validation RMSE = 4.66648
# Epoch 53, training RMSE = 4.4745, validation RMSE = 4.45252
# Epoch 54, training RMSE = 4.27145, validation RMSE = 4.31283
# Epoch 55, training RMSE = 4.11148, validation RMSE = 4.10074
# Epoch 56, training RMSE = 3.9152, validation RMSE = 3.95696
# Epoch 57, training RMSE = 3.75865, validation RMSE = 3.78113
# Epoch 58, training RMSE = 3.59758, validation RMSE = 3.61025
# Epoch 59, training RMSE = 3.45143, validation RMSE = 3.45256
# Epoch 60, training RMSE = 3.29467, validation RMSE = 3.29359
# Epoch 61, training RMSE = 3.14171, validation RMSE = 3.18315
# Epoch 62, training RMSE = 3.01316, validation RMSE = 3.00932
# Epoch 63, training RMSE = 2.85972, validation RMSE = 2.92488
# Epoch 64, training RMSE = 2.76602, validation RMSE = 2.73258
# Epoch 65, training RMSE = 2.6342, validation RMSE = 2.63924
# Epoch 66, training RMSE = 2.52823, validation RMSE = 2.47899
# Epoch 67, training RMSE = 2.41074, validation RMSE = 2.39137
# Epoch 68, training RMSE = 2.29803, validation RMSE = 2.30309
# Epoch 69, training RMSE = 2.19611, validation RMSE = 2.18486
# Epoch 70, training RMSE = 2.12376, validation RMSE = 2.03748
# Epoch 71, training RMSE = 2.00479, validation RMSE = 2.01646
# Epoch 72, training RMSE = 1.91256, validation RMSE = 1.95203
# Epoch 73, training RMSE = 1.83226, validation RMSE = 1.8684
# Epoch 74, training RMSE = 1.7697, validation RMSE = 1.72155
# Epoch 75, training RMSE = 1.70275, validation RMSE = 1.6301
# Epoch 76, training RMSE = 1.61266, validation RMSE = 1.60351
# Epoch 77, training RMSE = 1.497, validation RMSE = 1.63927
# Epoch 78, training RMSE = 1.49418, validation RMSE = 1.45145
# Epoch 79, training RMSE = 1.40695, validation RMSE = 1.44909
# Epoch 80, training RMSE = 1.34568, validation RMSE = 1.41222
# Epoch 81, training RMSE = 1.24332, validation RMSE = 1.46182
# Epoch 82, training RMSE = 1.281, validation RMSE = 1.21344
# Epoch 83, training RMSE = 1.21444, validation RMSE = 1.22422
# Epoch 84, training RMSE = 1.17463, validation RMSE = 1.19104
# Epoch 85, training RMSE = 1.13224, validation RMSE = 1.15115
# Epoch 86, training RMSE = 1.09128, validation RMSE = 1.08198
# Epoch 87, training RMSE = 1.0352, validation RMSE = 1.15174
# Epoch 88, training RMSE = 1.03089, validation RMSE = 1.05227
# Epoch 89, training RMSE = 0.9937, validation RMSE = 1.03366
# Epoch 90, training RMSE = 0.96802, validation RMSE = 0.9732
# Epoch 91, training RMSE = 0.94367, validation RMSE = 1.00148
# Epoch 92, training RMSE = 0.93429, validation RMSE = 0.948
# Epoch 93, training RMSE = 0.95846, validation RMSE = 0.80598
# Epoch 94, training RMSE = 0.90015, validation RMSE = 0.85853
# Epoch 95, training RMSE = 0.88505, validation RMSE = 0.8935
# Epoch 96, training RMSE = 0.81911, validation RMSE = 0.88331
# Epoch 97, training RMSE = 0.86684, validation RMSE = 0.83149
# Epoch 98, training RMSE = 0.78523, validation RMSE = 0.98639
# Epoch 99, training RMSE = 0.86168, validation RMSE = 0.78489
# Epoch 100, training RMSE = 0.786, validation RMSE = 0.9279
# ==========Model result==========
# Best epoch is 99 with minimum validation error = 0.78489
# ========== Start training model ==========
# batch size = 1024, epoch_size = 100, learning rate = 0.05, lambda = 5
# Epoch 1, training RMSE = 25.55069, validation RMSE = 24.67615
# Epoch 2, training RMSE = 23.60163, validation RMSE = 23.72115
# Epoch 3, training RMSE = 22.83106, validation RMSE = 23.12491
# Epoch 4, training RMSE = 22.18454, validation RMSE = 22.44033
# Epoch 5, training RMSE = 21.64075, validation RMSE = 21.89696
# Epoch 6, training RMSE = 21.09317, validation RMSE = 21.39922
# Epoch 7, training RMSE = 20.58143, validation RMSE = 20.9074
# Epoch 8, training RMSE = 20.09619, validation RMSE = 20.34938
# Epoch 9, training RMSE = 19.57734, validation RMSE = 19.83425
# Epoch 10, training RMSE = 19.10371, validation RMSE = 19.31913
# Epoch 11, training RMSE = 18.60308, validation RMSE = 18.87867
# Epoch 12, training RMSE = 18.12967, validation RMSE = 18.40459
# Epoch 13, training RMSE = 17.67722, validation RMSE = 17.87552
# Epoch 14, training RMSE = 17.21267, validation RMSE = 17.42978
# Epoch 15, training RMSE = 16.74143, validation RMSE = 16.97155
# Epoch 16, training RMSE = 16.31177, validation RMSE = 16.46783
# Epoch 17, training RMSE = 15.85622, validation RMSE = 16.0613
# Epoch 18, training RMSE = 15.41303, validation RMSE = 15.59469
# Epoch 19, training RMSE = 14.98461, validation RMSE = 15.14656
# Epoch 20, training RMSE = 14.57133, validation RMSE = 14.72008
# Epoch 21, training RMSE = 14.15413, validation RMSE = 14.29667
# Epoch 22, training RMSE = 13.74249, validation RMSE = 13.91588
# Epoch 23, training RMSE = 13.33804, validation RMSE = 13.46913
# Epoch 24, training RMSE = 12.94748, validation RMSE = 13.06401
# Epoch 25, training RMSE = 12.56031, validation RMSE = 12.68394
# Epoch 26, training RMSE = 12.16915, validation RMSE = 12.33899
# Epoch 27, training RMSE = 11.8008, validation RMSE = 11.92271
# Epoch 28, training RMSE = 11.44085, validation RMSE = 11.55116
# Epoch 29, training RMSE = 11.08411, validation RMSE = 11.17082
# Epoch 30, training RMSE = 10.73245, validation RMSE = 10.82727
# Epoch 31, training RMSE = 10.38199, validation RMSE = 10.48376
# Epoch 32, training RMSE = 10.05629, validation RMSE = 10.152
# Epoch 33, training RMSE = 9.73036, validation RMSE = 9.79079
# Epoch 34, training RMSE = 9.39764, validation RMSE = 9.49095
# Epoch 35, training RMSE = 9.08021, validation RMSE = 9.14671
# Epoch 36, training RMSE = 8.75688, validation RMSE = 8.86171
# Epoch 37, training RMSE = 8.46599, validation RMSE = 8.54852
# Epoch 38, training RMSE = 8.16717, validation RMSE = 8.2566
# Epoch 39, training RMSE = 7.89694, validation RMSE = 7.92608
# Epoch 40, training RMSE = 7.60474, validation RMSE = 7.69415
# Epoch 41, training RMSE = 7.32054, validation RMSE = 7.4116
# Epoch 42, training RMSE = 7.06627, validation RMSE = 7.13121
# Epoch 43, training RMSE = 6.81319, validation RMSE = 6.87254
# Epoch 44, training RMSE = 6.56165, validation RMSE = 6.63722
# Epoch 45, training RMSE = 6.30795, validation RMSE = 6.38621
# Epoch 46, training RMSE = 6.08835, validation RMSE = 6.12299
# Epoch 47, training RMSE = 5.8351, validation RMSE = 5.87437
# Epoch 48, training RMSE = 5.60798, validation RMSE = 5.67555
# Epoch 49, training RMSE = 5.39618, validation RMSE = 5.41872
# Epoch 50, training RMSE = 5.1788, validation RMSE = 5.22241
# Epoch 51, training RMSE = 4.95655, validation RMSE = 5.04529
# Epoch 52, training RMSE = 4.77018, validation RMSE = 4.80405
# Epoch 53, training RMSE = 4.586, validation RMSE = 4.57711
# Epoch 54, training RMSE = 4.37652, validation RMSE = 4.43325
# Epoch 55, training RMSE = 4.23682, validation RMSE = 4.20322
# Epoch 56, training RMSE = 4.02998, validation RMSE = 4.07114
# Epoch 57, training RMSE = 3.86625, validation RMSE = 3.88181
# Epoch 58, training RMSE = 3.69258, validation RMSE = 3.73706
# Epoch 59, training RMSE = 3.54822, validation RMSE = 3.55409
# Epoch 60, training RMSE = 3.3864, validation RMSE = 3.41266
# Epoch 61, training RMSE = 3.25236, validation RMSE = 3.24212
# Epoch 62, training RMSE = 3.09593, validation RMSE = 3.13236
# Epoch 63, training RMSE = 2.96586, validation RMSE = 3.0307
# Epoch 64, training RMSE = 2.82024, validation RMSE = 2.88721
# Epoch 65, training RMSE = 2.73134, validation RMSE = 2.68305
# Epoch 66, training RMSE = 2.60014, validation RMSE = 2.57357
# Epoch 67, training RMSE = 2.4874, validation RMSE = 2.46514
# Epoch 68, training RMSE = 2.35889, validation RMSE = 2.4085
# Epoch 69, training RMSE = 2.27493, validation RMSE = 2.27055
# Epoch 70, training RMSE = 2.1806, validation RMSE = 2.17473
# Epoch 71, training RMSE = 2.04676, validation RMSE = 2.13176
# Epoch 72, training RMSE = 2.00925, validation RMSE = 1.94587
# Epoch 73, training RMSE = 1.90368, validation RMSE = 1.8697
# Epoch 74, training RMSE = 1.82273, validation RMSE = 1.78571
# Epoch 75, training RMSE = 1.70773, validation RMSE = 1.8154
# Epoch 76, training RMSE = 1.64578, validation RMSE = 1.67038
# Epoch 77, training RMSE = 1.5677, validation RMSE = 1.66788
# Epoch 78, training RMSE = 1.54291, validation RMSE = 1.50493
# Epoch 79, training RMSE = 1.4557, validation RMSE = 1.50935
# Epoch 80, training RMSE = 1.41244, validation RMSE = 1.41857
# Epoch 81, training RMSE = 1.34921, validation RMSE = 1.36792
# Epoch 82, training RMSE = 1.29506, validation RMSE = 1.31144
# Epoch 83, training RMSE = 1.26865, validation RMSE = 1.19976
# Epoch 84, training RMSE = 1.21363, validation RMSE = 1.23157
# Epoch 85, training RMSE = 1.17718, validation RMSE = 1.17937
# Epoch 86, training RMSE = 1.15759, validation RMSE = 1.10498
# Epoch 87, training RMSE = 1.14378, validation RMSE = 1.01232
# Epoch 88, training RMSE = 1.0705, validation RMSE = 1.07024
# Epoch 89, training RMSE = 1.00151, validation RMSE = 1.1287
# Epoch 90, training RMSE = 1.05977, validation RMSE = 0.91237
# Epoch 91, training RMSE = 0.9654, validation RMSE = 1.0554
# Epoch 92, training RMSE = 0.90521, validation RMSE = 1.03755
# Epoch 93, training RMSE = 0.86986, validation RMSE = 1.10146
# Epoch 94, training RMSE = 0.89576, validation RMSE = 0.99837
# Epoch 95, training RMSE = 0.90616, validation RMSE = 0.86577
# Epoch 96, training RMSE = 0.87546, validation RMSE = 0.89457
# Epoch 97, training RMSE = 0.84352, validation RMSE = 0.96066
# Epoch 98, training RMSE = 0.854, validation RMSE = 0.91026
# Epoch 99, training RMSE = 0.84126, validation RMSE = 0.90549
# Epoch 100, training RMSE = 0.82407, validation RMSE = 0.90091
# ==========Model result==========
# Best epoch is 95 with minimum validation error = 0.86577

# %%
print("=" * 10, " Best Model result ", "=" * 10)
print(f"Batch Size = {best_batch_size}, Epoch Size = {best_epoch_size} (Actually running {best_stop_epoch_size} epoch), Learning rate = {best_learning_rate}")
print(f"Best lambda = {best_lambda}")
print(f"Validation RMSE = {global_best_RMSE}")
# Out:
# ==========  Best Model result  ==========
# Batch Size = 128, Epoch Size = 100 (Actually running 93 epoch), Learning rate = 0.005
# Best lambda = 0.001
# Validation RMSE = 0.6552837787040128

# %%
train_all_model = LinearRegression()
train_all_model.train_with_full_data(X_train, y_train, best_batch_size, best_stop_epoch_size, best_learning_rate, best_lambda,verbose = False)
final_w = train_all_model.best_w
final_bias = train_all_model.best_bias

# %%
#Training with all data finally
predict_model = LinearRegression()
y_pred = predict_model.predict(X_test, final_w, final_bias)

# %%
file_name = 'prediction.csv'
write_to_csv(y_pred, file_name)
