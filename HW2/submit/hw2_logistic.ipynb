# %% [markdown]
# # B06702064 會計五 林聖硯
# # Logistic regression

# %%
import numpy as np
import pandas as pd
import math
import os
import csv

# %%
data_path = "./data/"
path_train = os.path.join(data_path, "train.csv")
#path_x_test = os.path.join(data_path, "X_test")
path_test = os.path.join(data_path, "test.csv")

# %%
def load_data(path_train, path_test):
    data_train = pd.read_csv(path_train, skipinitialspace = True)
    data_test = pd.read_csv(path_test, skipinitialspace = True)
    return data_train, data_test

# %% [markdown]
# # Data Preprocessing

# %%
class DataPreprocessor:
    def __init__(self):
        self.train_mean = None
        self.train_std = None
        self.num_cols = ["age", "fnlwgt", "education_num", "capital_gain", "capital_loss", "hours_per_week"]
        self.cat_cols = ["workclass", "education", "marital_status", "occupation", "relationship", "race", "sex", "native_country"]
        self.all_native_countries = None

    def transform_label(self, data_train):
        label_dict = {'<=50K': 0, '>50K': 1}
        data_train["income"] = data_train["income"].apply(lambda x: label_dict[x])
        return data_train 
        
    def do_one_hot_encoding(self, data_cat: pd.DataFrame, isTraining = False):
        if isTraining:
            self.all_native_countries = data_cat["native_country"].value_counts().index.sort_values().to_list()
            data_one_hot = pd.get_dummies(data_cat)
        else:
            #fix missing columns in testing dataset
            data_cat["native_country"] = data_cat["native_country"].astype(pd.CategoricalDtype(categories=self.all_native_countries))
            data_one_hot = pd.get_dummies(data_cat)
        return data_one_hot
        
    def normalize_data(self, X_data: pd.DataFrame, isTraining = False):
        if isTraining:
            self.train_mean = X_data.mean(axis = 0)
            self.train_std = X_data.std(axis = 0)
        normalized_data = (X_data - self.train_mean) / self.train_std
        return normalized_data

    def standardize_data(self, X_data: pd.DataFrame, isTraining = False):
        if isTraining:
            self.train_min = X_data.min(axis = 0)
            self.train_range = X_data.max(axis = 0) - X_data.min(axis = 0)
        standardized_data = (X_data - self.train_min) / self.train_range
        return standardized_data

    def preprocess_train_data(self, data_train: pd.DataFrame):
        data_train = self.transform_label(data_train)
        #split data into numerical columns and categorical columns
        data_train_num = data_train[self.num_cols]
        data_train_cat = data_train[self.cat_cols]
        y_train = np.array(data_train["income"])

        #preprocessing - numerical
        #data_train_num = self.normalize_data(data_train_num, isTraining=True)
        data_train_num = self.standardize_data(data_train_num, isTraining=True)
        
        #preprocessing - categorical
        data_train_cat = self.do_one_hot_encoding(data_train_cat, isTraining=True)

        #combine
        data_train = pd.concat([data_train_num, data_train_cat], axis = 1)
        X_train = np.array(data_train)
        
        return X_train, y_train

    def preprocess_test_data(self, data_test: pd.DataFrame):
        #split data into numerical columns and categorical columns
        data_test_num = data_test[self.num_cols]
        data_test_cat = data_test[self.cat_cols]

        #preprocessing - numerical
        #data_test_num = self.normalize_data(data_test_num, isTraining=False)
        data_test_num = self.standardize_data(data_test_num, isTraining=False)

        #preprocessing - categorical
        data_test_cat = self.do_one_hot_encoding(data_test_cat, isTraining=False)

        #combine
        data_test = pd.concat([data_test_num, data_test_cat], axis = 1)
        X_test = np.array(data_test)
        return X_test

# %%
data_train, data_test = load_data(path_train, path_test)
DP = DataPreprocessor()
X_train, y_train= DP.preprocess_train_data(data_train)
X_test= DP.preprocess_test_data(data_test)
# Out:
# C:\Users\martin\.conda\envs\EEML\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ratio_greater_than_50K = round(sum(y_train) / y_train.shape[0], 4)
ratio_less_than_50K = 1 - round(sum(y_train) / y_train.shape[0], 4)
print(f"The ratio of income greater than 50K = {ratio_greater_than_50K * 100}%")
print(f"The ratio of income less than 50K = {ratio_less_than_50K * 100}%")
# Out:
# The ratio of income greater than 50K = 24.08%
# The ratio of income less than 50K = 75.92%

# %% [markdown]
# # Modeling

# %%
class LogisticRegression:
    def __init__(self):
        self.train_valid_ratio = 0.7
        self.train_acc_list = list()
        self.train_loss_list = list()
        self.valid_acc_list = list()
        self.valid_loss_list = list()
        #Best weights
        self.best_w = None
        self.best_b = None
        #Best results
        self.best_epoch = None
        self.best_valid_loss = None
        self.best_valid_acc = None

    def initialize_params(self, x):
        w = np.random.rand(X_train.shape[1])
        bias = np.random.rand()
        return w, bias

    def train(self, X, y, batch_size, epoch_size, learning_rate, verbose = True):
        w, b = self.initialize_params(X)
        #adagrad params
        eps = 1e-12
        g_b = 0
        g_w = np.ones(X.shape[1])

        #other hyperparams
        best_valid_loss = 99999
        patience = 10 #for early stopping
        
        for num_epoch in range(1, epoch_size+1):
            #Shuffle when each epoch begin
            index = np.arange(X.shape[0])
            np.random.shuffle(index)
            X = X[index]
            y = y[index]
            split_point_x = math.floor(X.shape[0] * self.train_valid_ratio)
            split_point_y = math.floor(y.shape[0] * self.train_valid_ratio)
            X_train = X[:split_point_x, :]
            y_train = y[:split_point_y]
            X_valid = X[split_point_x:, :] 
            y_valid = y[split_point_y:]

            for num_batch in range(int(X_train.shape[0] / batch_size)):
                #print("start")
                x_batch = X_train[num_batch * batch_size:(num_batch + 1) * batch_size]
                y_batch = y_train[num_batch * batch_size:(num_batch + 1) * batch_size]

                #implement adagrad
                w_grad, b_grad = self.compute_gradient(x_batch, y_batch, w, b)
                g_w += w_grad ** 2
                g_b += b_grad ** 2

                w = w - learning_rate * w_grad / np.sqrt(g_w + eps)
                b = b - learning_rate * b_grad / np.sqrt(g_b + eps)
                
            #compute loss 
            y_train_pred = np.round(self.compute_logistic_value(X_train, w, b))
            train_acc = self.compute_accuracy(y_train_pred, y_train)
            train_loss = self.compute_cross_entropy_loss(y_train_pred, y_train) / X_train.shape[0]
            self.train_acc_list.append(train_acc)
            self.train_loss_list.append(train_loss)

            y_valid_pred = np.round(self.compute_logistic_value(X_valid, w, b))
            valid_acc = self.compute_accuracy(y_valid_pred, y_valid)
            valid_loss = self.compute_cross_entropy_loss(y_valid_pred, y_valid) / X_valid.shape[0]
            self.valid_acc_list.append(valid_acc)
            self.valid_loss_list.append(valid_loss)

            if verbose:
                print(f"Epoch {num_epoch}, train loss = {round(train_loss, 4)} (Accuracy: {round(train_acc*100, 3)}%), valid loss = {round(valid_loss, 4)} (Accuracy: {round(valid_acc*100, 3)}%)")
        
            #save best result
            if valid_loss < best_valid_loss:
                self.best_w = w
                self.best_b = b
                self.best_epoch = num_epoch
                best_valid_loss = valid_loss
                best_valid_acc = valid_acc
                self.best_valid_loss = best_valid_loss
                self.best_valid_acc = best_valid_acc

            #early stopping
            if valid_loss > best_valid_loss and num_epoch >= self.best_epoch + patience:
                self.stop_epoch = self.best_epoch + patience
                if verbose:
                    print("Early Stopping!")
                    print("="*10 + "validation result" + "="*10)
                    print(f"Best epoch is {self.best_epoch} with minimum valid loss = {round(best_valid_loss, 4)} (Accuracy: {round(best_valid_acc*100, 3)}%)")
                return

        self.stop_epoch = num_epoch
        if verbose:
            print("Finish model tuning")
            print("="*10 + "Model result" + "="*10)
            print(f"Best epoch is {self.best_epoch} with minimum valid loss = {round(best_valid_loss, 4)} (Accuracy: {round(best_valid_acc*100, 3)}%)")

    def predict(self, X_test):
        y_pred = self.compute_logistic_value(X_test, self.best_w, self.best_b)
        y_pred = np.round(y_pred)
        return y_pred

    def compute_gradient(self, X, y_true, w, b):
        #print(w.shape)
        y_pred = self.compute_logistic_value(X, w, b).flatten() #dim = (batch_size, )
        pred_error = y_true - y_pred
        w_grad = -np.dot(X.T, pred_error) #dim = (feature_size, )
        b_grad = -pred_error.sum(axis = 0)
        return w_grad, b_grad

    def compute_logistic_value(self, X, w, b):
        return self.sigmoid(np.matmul(X, w) + b)

    def compute_cross_entropy_loss(self, y_pred, y_true):
        eps = 1e-12
        y_pred = np.clip(y_pred, eps, 1-eps)
        cross_entropy = -np.dot(y_true, np.log(y_pred )) - np.dot((1-y_true), np.log(1 - y_pred))
        return cross_entropy

    def compute_accuracy(self, y_pred, y_true):
        accuracy = 1 - np.mean(np.abs(y_pred - y_true))
        return accuracy

    def sigmoid(self, z):
        res = 1 / (1.0 + np.exp(-z))
        return np.clip(res, 1e-6, 1 - (1e-6))

# %%
batch_size_list = [128, 256, 512, 1024, 2048]
epoch_size_list = [20, 30, 50, 100]
learning_rate_list = [0.01, 0.05, 0.1, 0.5, 1]
loss_list = []
acc_list = []

#Model saving
best_model = None
global_best_loss = 99999
global_best_acc = 0

#Hyperparameter saving
best_batch_size = 0
best_epoch_size = 0
best_learning_rate = 0

for batch_size in batch_size_list:
    for epoch_size in epoch_size_list:
        for learning_rate in learning_rate_list:
            print("=" * 10,"Start training model", "="*10)
            print(f"batch size = {batch_size}, epoch_size = {epoch_size}, learningrate = {learning_rate}")
            LR = LogisticRegression()
            LR.train(X_train, y_train, batch_size, epoch_size, learning_rate)
            loss_list.append(LR.best_valid_loss)
            acc_list.append(LR.best_valid_acc)
            if LR.best_valid_loss < global_best_loss:
                best_model = LR
                best_batch_size = batch_size
                best_stop_epoch_size = LR.best_epoch
                best_epoch_size = epoch_size
                best_learning_rate = learning_rate
                global_best_loss = LR.best_valid_loss
                global_best_acc = LR.best_valid_acc
# Out:
# ========== Start training model ==========
# batch size = 128, epoch_size = 20, learningrate = 0.01
# Epoch 1, train loss = 20.9706 (Accuracy: 24.105%), valid loss = 20.9927 (Accuracy: 24.025%)
# Epoch 2, train loss = 20.7463 (Accuracy: 24.917%), valid loss = 20.7834 (Accuracy: 24.782%)
# Epoch 3, train loss = 19.2346 (Accuracy: 30.388%), valid loss = 19.3324 (Accuracy: 30.034%)
# Epoch 4, train loss = 15.9953 (Accuracy: 42.111%), valid loss = 15.9043 (Accuracy: 42.44%)
# Epoch 5, train loss = 12.6056 (Accuracy: 54.379%), valid loss = 12.5215 (Accuracy: 54.683%)
# Epoch 6, train loss = 9.7434 (Accuracy: 64.738%), valid loss = 9.6506 (Accuracy: 65.073%)
# Epoch 7, train loss = 7.9904 (Accuracy: 71.082%), valid loss = 7.8631 (Accuracy: 71.543%)
# Epoch 8, train loss = 6.6859 (Accuracy: 75.803%), valid loss = 6.7628 (Accuracy: 75.525%)
# Epoch 9, train loss = 6.1949 (Accuracy: 77.58%), valid loss = 5.9765 (Accuracy: 78.37%)
# Epoch 10, train loss = 5.8094 (Accuracy: 78.975%), valid loss = 5.9765 (Accuracy: 78.37%)
# Epoch 11, train loss = 5.6373 (Accuracy: 79.598%), valid loss = 5.8945 (Accuracy: 78.667%)
# Epoch 12, train loss = 5.6348 (Accuracy: 79.607%), valid loss = 5.4843 (Accuracy: 80.151%)
# Epoch 13, train loss = 5.5512 (Accuracy: 79.91%), valid loss = 5.5494 (Accuracy: 79.916%)
# Epoch 14, train loss = 5.5451 (Accuracy: 79.932%), valid loss = 5.4476 (Accuracy: 80.285%)
# Epoch 15, train loss = 5.5124 (Accuracy: 80.05%), valid loss = 5.5296 (Accuracy: 79.988%)
# Epoch 16, train loss = 5.5488 (Accuracy: 79.918%), valid loss = 5.3175 (Accuracy: 80.755%)
# Epoch 17, train loss = 5.4396 (Accuracy: 80.313%), valid loss = 5.4872 (Accuracy: 80.141%)
# Epoch 18, train loss = 5.4845 (Accuracy: 80.151%), valid loss = 5.2779 (Accuracy: 80.899%)
# Epoch 19, train loss = 5.4445 (Accuracy: 80.296%), valid loss = 5.2666 (Accuracy: 80.94%)
# Epoch 20, train loss = 5.4057 (Accuracy: 80.436%), valid loss = 5.2835 (Accuracy: 80.878%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 19 with minimum valid loss = 5.2666 (Accuracy: 80.94%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 20, learningrate = 0.05
# Epoch 1, train loss = 5.5439 (Accuracy: 79.936%), valid loss = 5.408 (Accuracy: 80.428%)
# Epoch 2, train loss = 4.9002 (Accuracy: 82.266%), valid loss = 4.9271 (Accuracy: 82.168%)
# Epoch 3, train loss = 4.6953 (Accuracy: 83.007%), valid loss = 4.7405 (Accuracy: 82.844%)
# Epoch 4, train loss = 4.6844 (Accuracy: 83.047%), valid loss = 4.6132 (Accuracy: 83.304%)
# Epoch 5, train loss = 4.5801 (Accuracy: 83.424%), valid loss = 4.6952 (Accuracy: 83.007%)
# Epoch 6, train loss = 4.5134 (Accuracy: 83.665%), valid loss = 4.749 (Accuracy: 82.813%)
# Epoch 7, train loss = 4.5389 (Accuracy: 83.573%), valid loss = 4.6217 (Accuracy: 83.274%)
# Epoch 8, train loss = 4.5171 (Accuracy: 83.652%), valid loss = 4.5849 (Accuracy: 83.407%)
# Epoch 9, train loss = 4.4977 (Accuracy: 83.722%), valid loss = 4.5425 (Accuracy: 83.56%)
# Epoch 10, train loss = 4.5813 (Accuracy: 83.42%), valid loss = 4.3247 (Accuracy: 84.348%)
# Epoch 11, train loss = 4.4868 (Accuracy: 83.762%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 12, train loss = 4.4565 (Accuracy: 83.872%), valid loss = 4.5283 (Accuracy: 83.611%)
# Epoch 13, train loss = 4.4807 (Accuracy: 83.784%), valid loss = 4.4661 (Accuracy: 83.837%)
# Epoch 14, train loss = 4.4856 (Accuracy: 83.766%), valid loss = 4.4011 (Accuracy: 84.072%)
# Epoch 15, train loss = 4.4068 (Accuracy: 84.051%), valid loss = 4.5255 (Accuracy: 83.622%)
# Epoch 16, train loss = 4.4698 (Accuracy: 83.823%), valid loss = 4.353 (Accuracy: 84.246%)
# Epoch 17, train loss = 4.3546 (Accuracy: 84.24%), valid loss = 4.5934 (Accuracy: 83.376%)
# Epoch 18, train loss = 4.4965 (Accuracy: 83.727%), valid loss = 4.2738 (Accuracy: 84.533%)
# Epoch 19, train loss = 4.4686 (Accuracy: 83.828%), valid loss = 4.2907 (Accuracy: 84.471%)
# Epoch 20, train loss = 4.4504 (Accuracy: 83.893%), valid loss = 4.3275 (Accuracy: 84.338%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 18 with minimum valid loss = 4.2738 (Accuracy: 84.533%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 20, learningrate = 0.1
# Epoch 1, train loss = 4.7147 (Accuracy: 82.937%), valid loss = 4.6613 (Accuracy: 83.13%)
# Epoch 2, train loss = 4.4625 (Accuracy: 83.85%), valid loss = 4.4831 (Accuracy: 83.775%)
# Epoch 3, train loss = 4.4431 (Accuracy: 83.92%), valid loss = 4.4011 (Accuracy: 84.072%)
# Epoch 4, train loss = 4.3801 (Accuracy: 84.148%), valid loss = 4.4548 (Accuracy: 83.878%)
# Epoch 5, train loss = 4.3971 (Accuracy: 84.087%), valid loss = 4.353 (Accuracy: 84.246%)
# Epoch 6, train loss = 4.3316 (Accuracy: 84.323%), valid loss = 4.4633 (Accuracy: 83.847%)
# Epoch 7, train loss = 4.3861 (Accuracy: 84.126%), valid loss = 4.3303 (Accuracy: 84.328%)
# Epoch 8, train loss = 4.3389 (Accuracy: 84.297%), valid loss = 4.3954 (Accuracy: 84.093%)
# Epoch 9, train loss = 4.3995 (Accuracy: 84.078%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 10, train loss = 4.2407 (Accuracy: 84.653%), valid loss = 4.534 (Accuracy: 83.591%)
# Epoch 11, train loss = 4.3049 (Accuracy: 84.42%), valid loss = 4.3105 (Accuracy: 84.4%)
# Epoch 12, train loss = 4.311 (Accuracy: 84.398%), valid loss = 4.2964 (Accuracy: 84.451%)
# Epoch 13, train loss = 4.277 (Accuracy: 84.521%), valid loss = 4.3473 (Accuracy: 84.267%)
# Epoch 14, train loss = 4.3219 (Accuracy: 84.359%), valid loss = 4.1946 (Accuracy: 84.819%)
# Epoch 15, train loss = 4.3122 (Accuracy: 84.394%), valid loss = 4.1974 (Accuracy: 84.809%)
# Epoch 16, train loss = 4.3728 (Accuracy: 84.174%), valid loss = 4.1182 (Accuracy: 85.096%)
# Epoch 17, train loss = 4.2419 (Accuracy: 84.648%), valid loss = 4.3699 (Accuracy: 84.185%)
# Epoch 18, train loss = 4.2152 (Accuracy: 84.745%), valid loss = 4.3954 (Accuracy: 84.093%)
# Epoch 19, train loss = 4.3049 (Accuracy: 84.42%), valid loss = 4.2087 (Accuracy: 84.768%)
# Epoch 20, train loss = 4.277 (Accuracy: 84.521%), valid loss = 4.237 (Accuracy: 84.666%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 16 with minimum valid loss = 4.1182 (Accuracy: 85.096%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 20, learningrate = 0.5
# Epoch 1, train loss = 4.3231 (Accuracy: 84.354%), valid loss = 4.3615 (Accuracy: 84.215%)
# Epoch 2, train loss = 4.2831 (Accuracy: 84.499%), valid loss = 4.2427 (Accuracy: 84.645%)
# Epoch 3, train loss = 4.1146 (Accuracy: 85.109%), valid loss = 4.4095 (Accuracy: 84.041%)
# Epoch 4, train loss = 4.1534 (Accuracy: 84.968%), valid loss = 4.2229 (Accuracy: 84.717%)
# Epoch 5, train loss = 4.2091 (Accuracy: 84.767%), valid loss = 4.0107 (Accuracy: 85.485%)
# Epoch 6, train loss = 4.1097 (Accuracy: 85.126%), valid loss = 4.1154 (Accuracy: 85.106%)
# Epoch 7, train loss = 4.0976 (Accuracy: 85.17%), valid loss = 4.022 (Accuracy: 85.444%)
# Epoch 8, train loss = 4.1413 (Accuracy: 85.012%), valid loss = 4.0871 (Accuracy: 85.208%)
# Epoch 9, train loss = 4.0891 (Accuracy: 85.201%), valid loss = 4.0956 (Accuracy: 85.178%)
# Epoch 10, train loss = 4.0661 (Accuracy: 85.284%), valid loss = 4.1352 (Accuracy: 85.034%)
# Epoch 11, train loss = 4.0649 (Accuracy: 85.289%), valid loss = 4.1069 (Accuracy: 85.137%)
# Epoch 12, train loss = 4.1037 (Accuracy: 85.148%), valid loss = 4.0758 (Accuracy: 85.249%)
# Epoch 13, train loss = 4.0758 (Accuracy: 85.249%), valid loss = 4.039 (Accuracy: 85.382%)
# Epoch 14, train loss = 4.1073 (Accuracy: 85.135%), valid loss = 4.1295 (Accuracy: 85.055%)
# Epoch 15, train loss = 4.1995 (Accuracy: 84.802%), valid loss = 3.9796 (Accuracy: 85.597%)
# Epoch 16, train loss = 4.094 (Accuracy: 85.183%), valid loss = 4.022 (Accuracy: 85.444%)
# Epoch 17, train loss = 4.1267 (Accuracy: 85.065%), valid loss = 4.1889 (Accuracy: 84.84%)
# Epoch 18, train loss = 4.0819 (Accuracy: 85.227%), valid loss = 4.0362 (Accuracy: 85.393%)
# Epoch 19, train loss = 4.0249 (Accuracy: 85.433%), valid loss = 4.1804 (Accuracy: 84.871%)
# Epoch 20, train loss = 4.0855 (Accuracy: 85.214%), valid loss = 4.022 (Accuracy: 85.444%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 15 with minimum valid loss = 3.9796 (Accuracy: 85.597%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 20, learningrate = 1
# Epoch 1, train loss = 4.1861 (Accuracy: 84.85%), valid loss = 4.4039 (Accuracy: 84.062%)
# Epoch 2, train loss = 4.2225 (Accuracy: 84.718%), valid loss = 4.2596 (Accuracy: 84.584%)
# Epoch 3, train loss = 4.1485 (Accuracy: 84.986%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 4, train loss = 4.077 (Accuracy: 85.245%), valid loss = 4.2427 (Accuracy: 84.645%)
# Epoch 5, train loss = 4.1279 (Accuracy: 85.061%), valid loss = 4.0645 (Accuracy: 85.29%)
# Epoch 6, train loss = 4.1231 (Accuracy: 85.078%), valid loss = 4.0277 (Accuracy: 85.423%)
# Epoch 7, train loss = 4.0588 (Accuracy: 85.311%), valid loss = 4.1069 (Accuracy: 85.137%)
# Epoch 8, train loss = 4.0503 (Accuracy: 85.341%), valid loss = 4.1041 (Accuracy: 85.147%)
# Epoch 9, train loss = 4.0734 (Accuracy: 85.258%), valid loss = 4.0786 (Accuracy: 85.239%)
# Epoch 10, train loss = 4.0867 (Accuracy: 85.21%), valid loss = 4.0164 (Accuracy: 85.464%)
# Epoch 11, train loss = 4.14 (Accuracy: 85.017%), valid loss = 4.0871 (Accuracy: 85.208%)
# Epoch 12, train loss = 4.1013 (Accuracy: 85.157%), valid loss = 4.0305 (Accuracy: 85.413%)
# Epoch 13, train loss = 4.1449 (Accuracy: 84.999%), valid loss = 3.9089 (Accuracy: 85.853%)
# Epoch 14, train loss = 4.0916 (Accuracy: 85.192%), valid loss = 4.121 (Accuracy: 85.085%)
# Epoch 15, train loss = 4.1231 (Accuracy: 85.078%), valid loss = 4.0899 (Accuracy: 85.198%)
# Epoch 16, train loss = 4.1352 (Accuracy: 85.034%), valid loss = 3.9372 (Accuracy: 85.751%)
# Epoch 17, train loss = 4.0746 (Accuracy: 85.254%), valid loss = 4.0899 (Accuracy: 85.198%)
# Epoch 18, train loss = 4.0855 (Accuracy: 85.214%), valid loss = 4.1182 (Accuracy: 85.096%)
# Epoch 19, train loss = 4.037 (Accuracy: 85.39%), valid loss = 4.2398 (Accuracy: 84.656%)
# Epoch 20, train loss = 4.0528 (Accuracy: 85.333%), valid loss = 4.1776 (Accuracy: 84.881%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 13 with minimum valid loss = 3.9089 (Accuracy: 85.853%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 30, learningrate = 0.01
# Epoch 1, train loss = 20.9209 (Accuracy: 24.285%), valid loss = 21.1087 (Accuracy: 23.605%)
# Epoch 2, train loss = 20.9609 (Accuracy: 24.14%), valid loss = 20.9672 (Accuracy: 24.117%)
# Epoch 3, train loss = 20.5305 (Accuracy: 25.698%), valid loss = 20.3846 (Accuracy: 26.226%)
# Epoch 4, train loss = 18.1895 (Accuracy: 34.17%), valid loss = 17.9267 (Accuracy: 35.121%)
# Epoch 5, train loss = 14.2629 (Accuracy: 48.381%), valid loss = 14.6032 (Accuracy: 47.149%)
# Epoch 6, train loss = 11.6855 (Accuracy: 57.709%), valid loss = 11.4863 (Accuracy: 58.43%)
# Epoch 7, train loss = 9.6997 (Accuracy: 64.896%), valid loss = 9.71 (Accuracy: 64.858%)
# Epoch 8, train loss = 8.5977 (Accuracy: 68.884%), valid loss = 8.4881 (Accuracy: 69.28%)
# Epoch 9, train loss = 7.5721 (Accuracy: 72.596%), valid loss = 7.7612 (Accuracy: 71.911%)
# Epoch 10, train loss = 7.3733 (Accuracy: 73.315%), valid loss = 7.156 (Accuracy: 74.102%)
# Epoch 11, train loss = 6.949 (Accuracy: 74.851%), valid loss = 7.1758 (Accuracy: 74.03%)
# Epoch 12, train loss = 6.7623 (Accuracy: 75.527%), valid loss = 6.9155 (Accuracy: 74.972%)
# Epoch 13, train loss = 6.7186 (Accuracy: 75.684%), valid loss = 6.6157 (Accuracy: 76.057%)
# Epoch 14, train loss = 6.6023 (Accuracy: 76.106%), valid loss = 6.5082 (Accuracy: 76.446%)
# Epoch 15, train loss = 6.5671 (Accuracy: 76.233%), valid loss = 6.2933 (Accuracy: 77.224%)
# Epoch 16, train loss = 6.378 (Accuracy: 76.917%), valid loss = 6.3583 (Accuracy: 76.988%)
# Epoch 17, train loss = 6.2677 (Accuracy: 77.317%), valid loss = 6.2791 (Accuracy: 77.275%)
# Epoch 18, train loss = 6.1779 (Accuracy: 77.641%), valid loss = 6.2509 (Accuracy: 77.377%)
# Epoch 19, train loss = 6.1101 (Accuracy: 77.887%), valid loss = 6.0953 (Accuracy: 77.94%)
# Epoch 20, train loss = 6.0228 (Accuracy: 78.203%), valid loss = 6.067 (Accuracy: 78.043%)
# Epoch 21, train loss = 5.944 (Accuracy: 78.488%), valid loss = 6.0415 (Accuracy: 78.135%)
# Epoch 22, train loss = 5.8809 (Accuracy: 78.716%), valid loss = 5.9228 (Accuracy: 78.565%)
# Epoch 23, train loss = 5.7379 (Accuracy: 79.234%), valid loss = 6.0217 (Accuracy: 78.207%)
# Epoch 24, train loss = 5.687 (Accuracy: 79.418%), valid loss = 5.8888 (Accuracy: 78.688%)
# Epoch 25, train loss = 5.6688 (Accuracy: 79.484%), valid loss = 5.6625 (Accuracy: 79.507%)
# Epoch 26, train loss = 5.6057 (Accuracy: 79.712%), valid loss = 5.5437 (Accuracy: 79.937%)
# Epoch 27, train loss = 5.5233 (Accuracy: 80.011%), valid loss = 5.4645 (Accuracy: 80.223%)
# Epoch 28, train loss = 5.4542 (Accuracy: 80.261%), valid loss = 5.4645 (Accuracy: 80.223%)
# Epoch 29, train loss = 5.4615 (Accuracy: 80.234%), valid loss = 5.3655 (Accuracy: 80.581%)
# Epoch 30, train loss = 5.3924 (Accuracy: 80.484%), valid loss = 5.4334 (Accuracy: 80.336%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 29 with minimum valid loss = 5.3655 (Accuracy: 80.581%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 30, learningrate = 0.05
# Epoch 1, train loss = 5.8688 (Accuracy: 78.76%), valid loss = 6.0613 (Accuracy: 78.063%)
# Epoch 2, train loss = 4.9171 (Accuracy: 82.204%), valid loss = 4.9752 (Accuracy: 81.994%)
# Epoch 3, train loss = 4.8153 (Accuracy: 82.573%), valid loss = 4.599 (Accuracy: 83.356%)
# Epoch 4, train loss = 4.6941 (Accuracy: 83.012%), valid loss = 4.7716 (Accuracy: 82.731%)
# Epoch 5, train loss = 4.5777 (Accuracy: 83.433%), valid loss = 4.6669 (Accuracy: 83.11%)
# Epoch 6, train loss = 4.5935 (Accuracy: 83.376%), valid loss = 4.5594 (Accuracy: 83.499%)
# Epoch 7, train loss = 4.6359 (Accuracy: 83.222%), valid loss = 4.4095 (Accuracy: 84.041%)
# Epoch 8, train loss = 4.5316 (Accuracy: 83.6%), valid loss = 4.599 (Accuracy: 83.356%)
# Epoch 9, train loss = 4.4904 (Accuracy: 83.749%), valid loss = 4.6075 (Accuracy: 83.325%)
# Epoch 10, train loss = 4.5534 (Accuracy: 83.521%), valid loss = 4.4322 (Accuracy: 83.959%)
# Epoch 11, train loss = 4.5304 (Accuracy: 83.604%), valid loss = 4.4604 (Accuracy: 83.857%)
# Epoch 12, train loss = 4.4395 (Accuracy: 83.933%), valid loss = 4.6613 (Accuracy: 83.13%)
# Epoch 13, train loss = 4.4953 (Accuracy: 83.731%), valid loss = 4.4887 (Accuracy: 83.755%)
# Epoch 14, train loss = 4.4746 (Accuracy: 83.806%), valid loss = 4.4972 (Accuracy: 83.724%)
# Epoch 15, train loss = 4.534 (Accuracy: 83.591%), valid loss = 4.3303 (Accuracy: 84.328%)
# Epoch 16, train loss = 4.5086 (Accuracy: 83.683%), valid loss = 4.3388 (Accuracy: 84.297%)
# Epoch 17, train loss = 4.4055 (Accuracy: 84.056%), valid loss = 4.5425 (Accuracy: 83.56%)
# Epoch 18, train loss = 4.4698 (Accuracy: 83.823%), valid loss = 4.3615 (Accuracy: 84.215%)
# Epoch 19, train loss = 4.4419 (Accuracy: 83.924%), valid loss = 4.4152 (Accuracy: 84.021%)
# Epoch 20, train loss = 4.4637 (Accuracy: 83.845%), valid loss = 4.3134 (Accuracy: 84.389%)
# Epoch 21, train loss = 4.4346 (Accuracy: 83.951%), valid loss = 4.4209 (Accuracy: 84.0%)
# Epoch 22, train loss = 4.3837 (Accuracy: 84.135%), valid loss = 4.4718 (Accuracy: 83.816%)
# Epoch 23, train loss = 4.3304 (Accuracy: 84.328%), valid loss = 4.6047 (Accuracy: 83.335%)
# Epoch 24, train loss = 4.4128 (Accuracy: 84.029%), valid loss = 4.3699 (Accuracy: 84.185%)
# Epoch 25, train loss = 4.374 (Accuracy: 84.17%), valid loss = 4.4435 (Accuracy: 83.919%)
# Epoch 26, train loss = 4.3607 (Accuracy: 84.218%), valid loss = 4.5227 (Accuracy: 83.632%)
# Epoch 27, train loss = 4.431 (Accuracy: 83.964%), valid loss = 4.319 (Accuracy: 84.369%)
# Epoch 28, train loss = 4.3898 (Accuracy: 84.113%), valid loss = 4.4152 (Accuracy: 84.021%)
# Epoch 29, train loss = 4.3195 (Accuracy: 84.367%), valid loss = 4.5623 (Accuracy: 83.489%)
# Epoch 30, train loss = 4.4201 (Accuracy: 84.003%), valid loss = 4.319 (Accuracy: 84.369%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 20 with minimum valid loss = 4.3134 (Accuracy: 84.389%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 30, learningrate = 0.1
# Epoch 1, train loss = 4.7486 (Accuracy: 82.814%), valid loss = 4.6896 (Accuracy: 83.028%)
# Epoch 2, train loss = 4.5838 (Accuracy: 83.411%), valid loss = 4.4746 (Accuracy: 83.806%)
# Epoch 3, train loss = 4.5122 (Accuracy: 83.67%), valid loss = 4.4718 (Accuracy: 83.816%)
# Epoch 4, train loss = 4.4346 (Accuracy: 83.951%), valid loss = 4.5396 (Accuracy: 83.57%)
# Epoch 5, train loss = 4.3958 (Accuracy: 84.091%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 6, train loss = 4.3934 (Accuracy: 84.1%), valid loss = 4.4887 (Accuracy: 83.755%)
# Epoch 7, train loss = 4.3704 (Accuracy: 84.183%), valid loss = 4.4859 (Accuracy: 83.765%)
# Epoch 8, train loss = 4.3886 (Accuracy: 84.117%), valid loss = 4.4237 (Accuracy: 83.99%)
# Epoch 9, train loss = 4.3183 (Accuracy: 84.372%), valid loss = 4.5255 (Accuracy: 83.622%)
# Epoch 10, train loss = 4.3449 (Accuracy: 84.275%), valid loss = 4.3954 (Accuracy: 84.093%)
# Epoch 11, train loss = 4.3571 (Accuracy: 84.231%), valid loss = 4.3077 (Accuracy: 84.41%)
# Epoch 12, train loss = 4.3243 (Accuracy: 84.35%), valid loss = 4.3303 (Accuracy: 84.328%)
# Epoch 13, train loss = 4.2746 (Accuracy: 84.53%), valid loss = 4.4435 (Accuracy: 83.919%)
# Epoch 14, train loss = 4.2649 (Accuracy: 84.565%), valid loss = 4.4152 (Accuracy: 84.021%)
# Epoch 15, train loss = 4.3292 (Accuracy: 84.332%), valid loss = 4.2879 (Accuracy: 84.482%)
# Epoch 16, train loss = 4.3267 (Accuracy: 84.341%), valid loss = 4.2285 (Accuracy: 84.696%)
# Epoch 17, train loss = 4.2673 (Accuracy: 84.556%), valid loss = 4.3275 (Accuracy: 84.338%)
# Epoch 18, train loss = 4.2964 (Accuracy: 84.451%), valid loss = 4.2427 (Accuracy: 84.645%)
# Epoch 19, train loss = 4.2758 (Accuracy: 84.525%), valid loss = 4.3473 (Accuracy: 84.267%)
# Epoch 20, train loss = 4.2904 (Accuracy: 84.473%), valid loss = 4.2681 (Accuracy: 84.553%)
# Epoch 21, train loss = 4.191 (Accuracy: 84.832%), valid loss = 4.4407 (Accuracy: 83.929%)
# Epoch 22, train loss = 4.2213 (Accuracy: 84.723%), valid loss = 4.3586 (Accuracy: 84.226%)
# Epoch 23, train loss = 4.2613 (Accuracy: 84.578%), valid loss = 4.336 (Accuracy: 84.308%)
# Epoch 24, train loss = 4.191 (Accuracy: 84.832%), valid loss = 4.4237 (Accuracy: 83.99%)
# Epoch 25, train loss = 4.2419 (Accuracy: 84.648%), valid loss = 4.3445 (Accuracy: 84.277%)
# Epoch 26, train loss = 4.2067 (Accuracy: 84.775%), valid loss = 4.3134 (Accuracy: 84.389%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 16 with minimum valid loss = 4.2285 (Accuracy: 84.696%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 30, learningrate = 0.5
# Epoch 1, train loss = 4.3764 (Accuracy: 84.161%), valid loss = 4.3162 (Accuracy: 84.379%)
# Epoch 2, train loss = 4.2273 (Accuracy: 84.701%), valid loss = 4.3501 (Accuracy: 84.256%)
# Epoch 3, train loss = 4.2467 (Accuracy: 84.631%), valid loss = 4.2483 (Accuracy: 84.625%)
# Epoch 4, train loss = 4.1279 (Accuracy: 85.061%), valid loss = 4.2087 (Accuracy: 84.768%)
# Epoch 5, train loss = 4.1291 (Accuracy: 85.056%), valid loss = 4.1578 (Accuracy: 84.952%)
# Epoch 6, train loss = 4.1061 (Accuracy: 85.14%), valid loss = 4.1635 (Accuracy: 84.932%)
# Epoch 7, train loss = 4.1255 (Accuracy: 85.069%), valid loss = 4.0814 (Accuracy: 85.229%)
# Epoch 8, train loss = 4.1097 (Accuracy: 85.126%), valid loss = 4.1465 (Accuracy: 84.993%)
# Epoch 9, train loss = 4.0309 (Accuracy: 85.412%), valid loss = 4.2738 (Accuracy: 84.533%)
# Epoch 10, train loss = 4.0746 (Accuracy: 85.254%), valid loss = 4.0814 (Accuracy: 85.229%)
# Epoch 11, train loss = 4.0103 (Accuracy: 85.486%), valid loss = 4.2087 (Accuracy: 84.768%)
# Epoch 12, train loss = 4.0928 (Accuracy: 85.188%), valid loss = 4.0645 (Accuracy: 85.29%)
# Epoch 13, train loss = 4.077 (Accuracy: 85.245%), valid loss = 4.1606 (Accuracy: 84.942%)
# Epoch 14, train loss = 4.0806 (Accuracy: 85.232%), valid loss = 4.1352 (Accuracy: 85.034%)
# Epoch 15, train loss = 4.0588 (Accuracy: 85.311%), valid loss = 4.0871 (Accuracy: 85.208%)
# Epoch 16, train loss = 4.0503 (Accuracy: 85.341%), valid loss = 4.0843 (Accuracy: 85.219%)
# Epoch 17, train loss = 4.1219 (Accuracy: 85.082%), valid loss = 3.9655 (Accuracy: 85.648%)
# Epoch 18, train loss = 4.0431 (Accuracy: 85.368%), valid loss = 4.1239 (Accuracy: 85.075%)
# Epoch 19, train loss = 4.0164 (Accuracy: 85.464%), valid loss = 4.1267 (Accuracy: 85.065%)
# Epoch 20, train loss = 4.0431 (Accuracy: 85.368%), valid loss = 4.1719 (Accuracy: 84.901%)
# Epoch 21, train loss = 4.174 (Accuracy: 84.894%), valid loss = 3.8552 (Accuracy: 86.048%)
# Epoch 22, train loss = 4.0552 (Accuracy: 85.324%), valid loss = 4.0503 (Accuracy: 85.341%)
# Epoch 23, train loss = 3.9885 (Accuracy: 85.565%), valid loss = 4.2002 (Accuracy: 84.799%)
# Epoch 24, train loss = 4.0552 (Accuracy: 85.324%), valid loss = 4.0532 (Accuracy: 85.331%)
# Epoch 25, train loss = 4.0697 (Accuracy: 85.271%), valid loss = 4.073 (Accuracy: 85.259%)
# Epoch 26, train loss = 4.0564 (Accuracy: 85.319%), valid loss = 4.1917 (Accuracy: 84.83%)
# Epoch 27, train loss = 4.077 (Accuracy: 85.245%), valid loss = 4.0447 (Accuracy: 85.362%)
# Epoch 28, train loss = 4.1097 (Accuracy: 85.126%), valid loss = 3.9061 (Accuracy: 85.863%)
# Epoch 29, train loss = 4.0976 (Accuracy: 85.17%), valid loss = 4.0588 (Accuracy: 85.311%)
# Epoch 30, train loss = 4.1049 (Accuracy: 85.144%), valid loss = 3.974 (Accuracy: 85.618%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 21 with minimum valid loss = 3.8552 (Accuracy: 86.048%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 30, learningrate = 1
# Epoch 1, train loss = 4.2443 (Accuracy: 84.639%), valid loss = 4.2851 (Accuracy: 84.492%)
# Epoch 2, train loss = 4.254 (Accuracy: 84.604%), valid loss = 4.1889 (Accuracy: 84.84%)
# Epoch 3, train loss = 4.1837 (Accuracy: 84.859%), valid loss = 4.2483 (Accuracy: 84.625%)
# Epoch 4, train loss = 4.1316 (Accuracy: 85.047%), valid loss = 4.1861 (Accuracy: 84.85%)
# Epoch 5, train loss = 4.1 (Accuracy: 85.161%), valid loss = 4.1239 (Accuracy: 85.075%)
# Epoch 6, train loss = 4.0831 (Accuracy: 85.223%), valid loss = 4.0956 (Accuracy: 85.178%)
# Epoch 7, train loss = 4.0382 (Accuracy: 85.385%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 8, train loss = 4.0225 (Accuracy: 85.442%), valid loss = 4.1521 (Accuracy: 84.973%)
# Epoch 9, train loss = 4.1061 (Accuracy: 85.14%), valid loss = 4.022 (Accuracy: 85.444%)
# Epoch 10, train loss = 4.0382 (Accuracy: 85.385%), valid loss = 4.1635 (Accuracy: 84.932%)
# Epoch 11, train loss = 3.9873 (Accuracy: 85.569%), valid loss = 4.319 (Accuracy: 84.369%)
# Epoch 12, train loss = 4.0685 (Accuracy: 85.276%), valid loss = 4.0418 (Accuracy: 85.372%)
# Epoch 13, train loss = 4.0309 (Accuracy: 85.412%), valid loss = 4.2342 (Accuracy: 84.676%)
# Epoch 14, train loss = 4.1437 (Accuracy: 85.004%), valid loss = 3.8806 (Accuracy: 85.956%)
# Epoch 15, train loss = 4.0819 (Accuracy: 85.227%), valid loss = 4.0814 (Accuracy: 85.229%)
# Epoch 16, train loss = 4.1449 (Accuracy: 84.999%), valid loss = 3.9909 (Accuracy: 85.556%)
# Epoch 17, train loss = 4.0843 (Accuracy: 85.218%), valid loss = 4.2144 (Accuracy: 84.748%)
# Epoch 18, train loss = 4.077 (Accuracy: 85.245%), valid loss = 4.1239 (Accuracy: 85.075%)
# Epoch 19, train loss = 4.1134 (Accuracy: 85.113%), valid loss = 4.0277 (Accuracy: 85.423%)
# Epoch 20, train loss = 4.0697 (Accuracy: 85.271%), valid loss = 4.1663 (Accuracy: 84.922%)
# Epoch 21, train loss = 4.0322 (Accuracy: 85.407%), valid loss = 4.1154 (Accuracy: 85.106%)
# Epoch 22, train loss = 4.0467 (Accuracy: 85.355%), valid loss = 4.1776 (Accuracy: 84.881%)
# Epoch 23, train loss = 4.1097 (Accuracy: 85.126%), valid loss = 4.0503 (Accuracy: 85.341%)
# Epoch 24, train loss = 4.054 (Accuracy: 85.328%), valid loss = 4.1041 (Accuracy: 85.147%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 14 with minimum valid loss = 3.8806 (Accuracy: 85.956%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 50, learningrate = 0.01
# Epoch 1, train loss = 20.99 (Accuracy: 24.035%), valid loss = 20.9474 (Accuracy: 24.189%)
# Epoch 2, train loss = 20.9015 (Accuracy: 24.355%), valid loss = 20.724 (Accuracy: 24.997%)
# Epoch 3, train loss = 17.4803 (Accuracy: 36.737%), valid loss = 17.5052 (Accuracy: 36.647%)
# Epoch 4, train loss = 11.2066 (Accuracy: 59.442%), valid loss = 11.1469 (Accuracy: 59.658%)
# Epoch 5, train loss = 7.8909 (Accuracy: 71.442%), valid loss = 7.9649 (Accuracy: 71.174%)
# Epoch 6, train loss = 7.0072 (Accuracy: 74.64%), valid loss = 6.9693 (Accuracy: 74.777%)
# Epoch 7, train loss = 6.3598 (Accuracy: 76.983%), valid loss = 6.3329 (Accuracy: 77.081%)
# Epoch 8, train loss = 6.1331 (Accuracy: 77.804%), valid loss = 6.0302 (Accuracy: 78.176%)
# Epoch 9, train loss = 6.0531 (Accuracy: 78.093%), valid loss = 5.8775 (Accuracy: 78.729%)
# Epoch 10, train loss = 5.8518 (Accuracy: 78.822%), valid loss = 5.9963 (Accuracy: 78.299%)
# Epoch 11, train loss = 5.8894 (Accuracy: 78.686%), valid loss = 5.7276 (Accuracy: 79.271%)
# Epoch 12, train loss = 5.8761 (Accuracy: 78.734%), valid loss = 5.6229 (Accuracy: 79.65%)
# Epoch 13, train loss = 5.733 (Accuracy: 79.251%), valid loss = 5.7417 (Accuracy: 79.22%)
# Epoch 14, train loss = 5.6954 (Accuracy: 79.388%), valid loss = 5.7417 (Accuracy: 79.22%)
# Epoch 15, train loss = 5.6882 (Accuracy: 79.414%), valid loss = 5.6625 (Accuracy: 79.507%)
# Epoch 16, train loss = 5.6603 (Accuracy: 79.515%), valid loss = 5.572 (Accuracy: 79.834%)
# Epoch 17, train loss = 5.493 (Accuracy: 80.12%), valid loss = 5.7898 (Accuracy: 79.046%)
# Epoch 18, train loss = 5.3948 (Accuracy: 80.476%), valid loss = 5.606 (Accuracy: 79.711%)
# Epoch 19, train loss = 5.4275 (Accuracy: 80.357%), valid loss = 5.3938 (Accuracy: 80.479%)
# Epoch 20, train loss = 5.3511 (Accuracy: 80.634%), valid loss = 5.4221 (Accuracy: 80.377%)
# Epoch 21, train loss = 5.3463 (Accuracy: 80.651%), valid loss = 5.2694 (Accuracy: 80.929%)
# Epoch 22, train loss = 5.2069 (Accuracy: 81.156%), valid loss = 5.5126 (Accuracy: 80.049%)
# Epoch 23, train loss = 5.242 (Accuracy: 81.028%), valid loss = 5.3146 (Accuracy: 80.766%)
# Epoch 24, train loss = 5.2699 (Accuracy: 80.928%), valid loss = 5.1251 (Accuracy: 81.452%)
# Epoch 25, train loss = 5.196 (Accuracy: 81.195%), valid loss = 5.1478 (Accuracy: 81.37%)
# Epoch 26, train loss = 5.0917 (Accuracy: 81.572%), valid loss = 5.2241 (Accuracy: 81.093%)
# Epoch 27, train loss = 5.0275 (Accuracy: 81.805%), valid loss = 5.1704 (Accuracy: 81.288%)
# Epoch 28, train loss = 4.9947 (Accuracy: 81.923%), valid loss = 5.1478 (Accuracy: 81.37%)
# Epoch 29, train loss = 4.9717 (Accuracy: 82.007%), valid loss = 5.0572 (Accuracy: 81.697%)
# Epoch 30, train loss = 4.9487 (Accuracy: 82.09%), valid loss = 4.9865 (Accuracy: 81.953%)
# Epoch 31, train loss = 4.9281 (Accuracy: 82.165%), valid loss = 5.0205 (Accuracy: 81.83%)
# Epoch 32, train loss = 4.9656 (Accuracy: 82.029%), valid loss = 4.8395 (Accuracy: 82.485%)
# Epoch 33, train loss = 4.9074 (Accuracy: 82.239%), valid loss = 4.9441 (Accuracy: 82.107%)
# Epoch 34, train loss = 4.9123 (Accuracy: 82.222%), valid loss = 4.9102 (Accuracy: 82.23%)
# Epoch 35, train loss = 4.8723 (Accuracy: 82.367%), valid loss = 4.9781 (Accuracy: 81.984%)
# Epoch 36, train loss = 4.9038 (Accuracy: 82.253%), valid loss = 4.8819 (Accuracy: 82.332%)
# Epoch 37, train loss = 4.8941 (Accuracy: 82.288%), valid loss = 4.9073 (Accuracy: 82.24%)
# Epoch 38, train loss = 4.9729 (Accuracy: 82.002%), valid loss = 4.7037 (Accuracy: 82.977%)
# Epoch 39, train loss = 4.8565 (Accuracy: 82.424%), valid loss = 4.9611 (Accuracy: 82.045%)
# Epoch 40, train loss = 4.899 (Accuracy: 82.27%), valid loss = 4.8281 (Accuracy: 82.526%)
# Epoch 41, train loss = 4.8929 (Accuracy: 82.292%), valid loss = 4.7829 (Accuracy: 82.69%)
# Epoch 42, train loss = 4.8444 (Accuracy: 82.468%), valid loss = 4.8197 (Accuracy: 82.557%)
# Epoch 43, train loss = 4.8541 (Accuracy: 82.432%), valid loss = 4.7207 (Accuracy: 82.915%)
# Epoch 44, train loss = 4.7886 (Accuracy: 82.669%), valid loss = 4.8677 (Accuracy: 82.383%)
# Epoch 45, train loss = 4.842 (Accuracy: 82.476%), valid loss = 4.6754 (Accuracy: 83.079%)
# Epoch 46, train loss = 4.8565 (Accuracy: 82.424%), valid loss = 4.6188 (Accuracy: 83.284%)
# Epoch 47, train loss = 4.7729 (Accuracy: 82.726%), valid loss = 4.7829 (Accuracy: 82.69%)
# Epoch 48, train loss = 4.7729 (Accuracy: 82.726%), valid loss = 4.7772 (Accuracy: 82.711%)
# Epoch 49, train loss = 4.7462 (Accuracy: 82.823%), valid loss = 4.8112 (Accuracy: 82.588%)
# Epoch 50, train loss = 4.7583 (Accuracy: 82.779%), valid loss = 4.7603 (Accuracy: 82.772%)
# Finish model tuning
# ==========Model result==========
# Best epoch is 46 with minimum valid loss = 4.6188 (Accuracy: 83.284%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 50, learningrate = 0.05
# Epoch 1, train loss = 5.9064 (Accuracy: 78.624%), valid loss = 5.9482 (Accuracy: 78.473%)
# Epoch 2, train loss = 5.019 (Accuracy: 81.836%), valid loss = 4.9781 (Accuracy: 81.984%)
# Epoch 3, train loss = 4.7244 (Accuracy: 82.902%), valid loss = 4.8281 (Accuracy: 82.526%)
# Epoch 4, train loss = 4.6916 (Accuracy: 83.02%), valid loss = 4.5057 (Accuracy: 83.693%)
# Epoch 5, train loss = 4.6516 (Accuracy: 83.165%), valid loss = 4.5283 (Accuracy: 83.611%)
# Epoch 6, train loss = 4.591 (Accuracy: 83.385%), valid loss = 4.5877 (Accuracy: 83.396%)
# Epoch 7, train loss = 4.5656 (Accuracy: 83.477%), valid loss = 4.5538 (Accuracy: 83.519%)
# Epoch 8, train loss = 4.4977 (Accuracy: 83.722%), valid loss = 4.6754 (Accuracy: 83.079%)
# Epoch 9, train loss = 4.5716 (Accuracy: 83.455%), valid loss = 4.4322 (Accuracy: 83.959%)
# Epoch 10, train loss = 4.5389 (Accuracy: 83.573%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 11, train loss = 4.4807 (Accuracy: 83.784%), valid loss = 4.6188 (Accuracy: 83.284%)
# Epoch 12, train loss = 4.5074 (Accuracy: 83.687%), valid loss = 4.4746 (Accuracy: 83.806%)
# Epoch 13, train loss = 4.4686 (Accuracy: 83.828%), valid loss = 4.534 (Accuracy: 83.591%)
# Epoch 14, train loss = 4.4262 (Accuracy: 83.981%), valid loss = 4.6075 (Accuracy: 83.325%)
# Epoch 15, train loss = 4.4892 (Accuracy: 83.753%), valid loss = 4.4152 (Accuracy: 84.021%)
# Epoch 16, train loss = 4.4286 (Accuracy: 83.972%), valid loss = 4.5594 (Accuracy: 83.499%)
# Epoch 17, train loss = 4.3825 (Accuracy: 84.139%), valid loss = 4.5849 (Accuracy: 83.407%)
# Epoch 18, train loss = 4.4189 (Accuracy: 84.008%), valid loss = 4.4887 (Accuracy: 83.755%)
# Epoch 19, train loss = 4.3898 (Accuracy: 84.113%), valid loss = 4.5538 (Accuracy: 83.519%)
# Epoch 20, train loss = 4.4189 (Accuracy: 84.008%), valid loss = 4.4491 (Accuracy: 83.898%)
# Epoch 21, train loss = 4.4092 (Accuracy: 84.043%), valid loss = 4.4689 (Accuracy: 83.826%)
# Epoch 22, train loss = 4.3922 (Accuracy: 84.104%), valid loss = 4.4435 (Accuracy: 83.919%)
# Epoch 23, train loss = 4.4528 (Accuracy: 83.885%), valid loss = 4.2964 (Accuracy: 84.451%)
# Epoch 24, train loss = 4.4019 (Accuracy: 84.069%), valid loss = 4.4095 (Accuracy: 84.041%)
# Epoch 25, train loss = 4.4456 (Accuracy: 83.911%), valid loss = 4.3445 (Accuracy: 84.277%)
# Epoch 26, train loss = 4.408 (Accuracy: 84.047%), valid loss = 4.4237 (Accuracy: 83.99%)
# Epoch 27, train loss = 4.4019 (Accuracy: 84.069%), valid loss = 4.4265 (Accuracy: 83.98%)
# Epoch 28, train loss = 4.4225 (Accuracy: 83.994%), valid loss = 4.3501 (Accuracy: 84.256%)
# Epoch 29, train loss = 4.3655 (Accuracy: 84.201%), valid loss = 4.4689 (Accuracy: 83.826%)
# Epoch 30, train loss = 4.3861 (Accuracy: 84.126%), valid loss = 4.3982 (Accuracy: 84.082%)
# Epoch 31, train loss = 4.4504 (Accuracy: 83.893%), valid loss = 4.2823 (Accuracy: 84.502%)
# Epoch 32, train loss = 4.4152 (Accuracy: 84.021%), valid loss = 4.3558 (Accuracy: 84.236%)
# Epoch 33, train loss = 4.4516 (Accuracy: 83.889%), valid loss = 4.2568 (Accuracy: 84.594%)
# Epoch 34, train loss = 4.4068 (Accuracy: 84.051%), valid loss = 4.3699 (Accuracy: 84.185%)
# Epoch 35, train loss = 4.3813 (Accuracy: 84.144%), valid loss = 4.3897 (Accuracy: 84.113%)
# Epoch 36, train loss = 4.3595 (Accuracy: 84.223%), valid loss = 4.4265 (Accuracy: 83.98%)
# Epoch 37, train loss = 4.454 (Accuracy: 83.88%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 38, train loss = 4.3898 (Accuracy: 84.113%), valid loss = 4.3473 (Accuracy: 84.267%)
# Epoch 39, train loss = 4.3643 (Accuracy: 84.205%), valid loss = 4.3926 (Accuracy: 84.103%)
# Epoch 40, train loss = 4.3558 (Accuracy: 84.236%), valid loss = 4.4124 (Accuracy: 84.031%)
# Epoch 41, train loss = 4.3619 (Accuracy: 84.214%), valid loss = 4.3982 (Accuracy: 84.082%)
# Epoch 42, train loss = 4.4165 (Accuracy: 84.016%), valid loss = 4.2625 (Accuracy: 84.574%)
# Epoch 43, train loss = 4.4104 (Accuracy: 84.038%), valid loss = 4.2511 (Accuracy: 84.615%)
# Epoch 44, train loss = 4.3607 (Accuracy: 84.218%), valid loss = 4.3643 (Accuracy: 84.205%)
# Epoch 45, train loss = 4.3304 (Accuracy: 84.328%), valid loss = 4.4067 (Accuracy: 84.052%)
# Epoch 46, train loss = 4.4007 (Accuracy: 84.073%), valid loss = 4.2342 (Accuracy: 84.676%)
# Epoch 47, train loss = 4.294 (Accuracy: 84.459%), valid loss = 4.4944 (Accuracy: 83.734%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 37 with minimum valid loss = 4.2031 (Accuracy: 84.789%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 50, learningrate = 0.1
# Epoch 1, train loss = 4.7753 (Accuracy: 82.718%), valid loss = 4.5425 (Accuracy: 83.56%)
# Epoch 2, train loss = 4.5316 (Accuracy: 83.6%), valid loss = 4.6641 (Accuracy: 83.12%)
# Epoch 3, train loss = 4.5159 (Accuracy: 83.657%), valid loss = 4.4633 (Accuracy: 83.847%)
# Epoch 4, train loss = 4.4104 (Accuracy: 84.038%), valid loss = 4.6019 (Accuracy: 83.345%)
# Epoch 5, train loss = 4.4189 (Accuracy: 84.008%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 6, train loss = 4.3728 (Accuracy: 84.174%), valid loss = 4.5453 (Accuracy: 83.55%)
# Epoch 7, train loss = 4.4395 (Accuracy: 83.933%), valid loss = 4.3332 (Accuracy: 84.318%)
# Epoch 8, train loss = 4.4068 (Accuracy: 84.051%), valid loss = 4.3388 (Accuracy: 84.297%)
# Epoch 9, train loss = 4.3437 (Accuracy: 84.28%), valid loss = 4.4548 (Accuracy: 83.878%)
# Epoch 10, train loss = 4.4055 (Accuracy: 84.056%), valid loss = 4.2992 (Accuracy: 84.441%)
# Epoch 11, train loss = 4.3728 (Accuracy: 84.174%), valid loss = 4.2653 (Accuracy: 84.563%)
# Epoch 12, train loss = 4.408 (Accuracy: 84.047%), valid loss = 4.1748 (Accuracy: 84.891%)
# Epoch 13, train loss = 4.3861 (Accuracy: 84.126%), valid loss = 4.2625 (Accuracy: 84.574%)
# Epoch 14, train loss = 4.2249 (Accuracy: 84.71%), valid loss = 4.5877 (Accuracy: 83.396%)
# Epoch 15, train loss = 4.3958 (Accuracy: 84.091%), valid loss = 4.1606 (Accuracy: 84.942%)
# Epoch 16, train loss = 4.3195 (Accuracy: 84.367%), valid loss = 4.3077 (Accuracy: 84.41%)
# Epoch 17, train loss = 4.334 (Accuracy: 84.315%), valid loss = 4.2455 (Accuracy: 84.635%)
# Epoch 18, train loss = 4.2831 (Accuracy: 84.499%), valid loss = 4.3105 (Accuracy: 84.4%)
# Epoch 19, train loss = 4.3486 (Accuracy: 84.262%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 20, train loss = 4.2613 (Accuracy: 84.578%), valid loss = 4.3219 (Accuracy: 84.359%)
# Epoch 21, train loss = 4.2904 (Accuracy: 84.473%), valid loss = 4.2936 (Accuracy: 84.461%)
# Epoch 22, train loss = 4.2407 (Accuracy: 84.653%), valid loss = 4.3077 (Accuracy: 84.41%)
# Epoch 23, train loss = 4.2661 (Accuracy: 84.56%), valid loss = 4.3219 (Accuracy: 84.359%)
# Epoch 24, train loss = 4.3146 (Accuracy: 84.385%), valid loss = 4.2115 (Accuracy: 84.758%)
# Epoch 25, train loss = 4.2589 (Accuracy: 84.587%), valid loss = 4.3473 (Accuracy: 84.267%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 15 with minimum valid loss = 4.1606 (Accuracy: 84.942%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 50, learningrate = 0.5
# Epoch 1, train loss = 4.3389 (Accuracy: 84.297%), valid loss = 4.418 (Accuracy: 84.011%)
# Epoch 2, train loss = 4.2443 (Accuracy: 84.639%), valid loss = 4.2681 (Accuracy: 84.553%)
# Epoch 3, train loss = 4.2152 (Accuracy: 84.745%), valid loss = 4.073 (Accuracy: 85.259%)
# Epoch 4, train loss = 4.1255 (Accuracy: 85.069%), valid loss = 4.2907 (Accuracy: 84.471%)
# Epoch 5, train loss = 4.1413 (Accuracy: 85.012%), valid loss = 4.1352 (Accuracy: 85.034%)
# Epoch 6, train loss = 4.1231 (Accuracy: 85.078%), valid loss = 4.0843 (Accuracy: 85.219%)
# Epoch 7, train loss = 4.0406 (Accuracy: 85.376%), valid loss = 4.1889 (Accuracy: 84.84%)
# Epoch 8, train loss = 3.9946 (Accuracy: 85.543%), valid loss = 4.2851 (Accuracy: 84.492%)
# Epoch 9, train loss = 4.094 (Accuracy: 85.183%), valid loss = 4.0418 (Accuracy: 85.372%)
# Epoch 10, train loss = 4.0746 (Accuracy: 85.254%), valid loss = 4.1097 (Accuracy: 85.126%)
# Epoch 11, train loss = 4.0709 (Accuracy: 85.267%), valid loss = 4.0588 (Accuracy: 85.311%)
# Epoch 12, train loss = 4.0685 (Accuracy: 85.276%), valid loss = 4.0249 (Accuracy: 85.434%)
# Epoch 13, train loss = 4.0588 (Accuracy: 85.311%), valid loss = 4.1352 (Accuracy: 85.034%)
# Epoch 14, train loss = 4.1764 (Accuracy: 84.885%), valid loss = 3.8778 (Accuracy: 85.966%)
# Epoch 15, train loss = 4.0758 (Accuracy: 85.249%), valid loss = 4.0249 (Accuracy: 85.434%)
# Epoch 16, train loss = 4.0843 (Accuracy: 85.218%), valid loss = 4.0928 (Accuracy: 85.188%)
# Epoch 17, train loss = 4.0928 (Accuracy: 85.188%), valid loss = 4.0588 (Accuracy: 85.311%)
# Epoch 18, train loss = 4.077 (Accuracy: 85.245%), valid loss = 3.9626 (Accuracy: 85.659%)
# Epoch 19, train loss = 4.0334 (Accuracy: 85.403%), valid loss = 4.0249 (Accuracy: 85.434%)
# Epoch 20, train loss = 4.0043 (Accuracy: 85.508%), valid loss = 4.1324 (Accuracy: 85.045%)
# Epoch 21, train loss = 4.0673 (Accuracy: 85.28%), valid loss = 4.0079 (Accuracy: 85.495%)
# Epoch 22, train loss = 4.0722 (Accuracy: 85.262%), valid loss = 4.1408 (Accuracy: 85.014%)
# Epoch 23, train loss = 4.0261 (Accuracy: 85.429%), valid loss = 4.155 (Accuracy: 84.963%)
# Epoch 24, train loss = 4.0843 (Accuracy: 85.218%), valid loss = 3.9796 (Accuracy: 85.597%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 14 with minimum valid loss = 3.8778 (Accuracy: 85.966%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 50, learningrate = 1
# Epoch 1, train loss = 4.3922 (Accuracy: 84.104%), valid loss = 4.2851 (Accuracy: 84.492%)
# Epoch 2, train loss = 4.1716 (Accuracy: 84.903%), valid loss = 4.2398 (Accuracy: 84.656%)
# Epoch 3, train loss = 4.0419 (Accuracy: 85.372%), valid loss = 4.2936 (Accuracy: 84.461%)
# Epoch 4, train loss = 4.0515 (Accuracy: 85.337%), valid loss = 4.1917 (Accuracy: 84.83%)
# Epoch 5, train loss = 4.1316 (Accuracy: 85.047%), valid loss = 4.1889 (Accuracy: 84.84%)
# Epoch 6, train loss = 4.0249 (Accuracy: 85.433%), valid loss = 4.1126 (Accuracy: 85.116%)
# Epoch 7, train loss = 4.1219 (Accuracy: 85.082%), valid loss = 3.9768 (Accuracy: 85.608%)
# Epoch 8, train loss = 3.9582 (Accuracy: 85.675%), valid loss = 4.3615 (Accuracy: 84.215%)
# Epoch 9, train loss = 4.117 (Accuracy: 85.1%), valid loss = 4.2285 (Accuracy: 84.696%)
# Epoch 10, train loss = 4.0673 (Accuracy: 85.28%), valid loss = 4.1691 (Accuracy: 84.911%)
# Epoch 11, train loss = 4.1534 (Accuracy: 84.968%), valid loss = 3.94 (Accuracy: 85.741%)
# Epoch 12, train loss = 4.0309 (Accuracy: 85.412%), valid loss = 4.2115 (Accuracy: 84.758%)
# Epoch 13, train loss = 4.1291 (Accuracy: 85.056%), valid loss = 4.1719 (Accuracy: 84.901%)
# Epoch 14, train loss = 4.0091 (Accuracy: 85.491%), valid loss = 4.1748 (Accuracy: 84.891%)
# Epoch 15, train loss = 4.0261 (Accuracy: 85.429%), valid loss = 4.2031 (Accuracy: 84.789%)
# Epoch 16, train loss = 4.1413 (Accuracy: 85.012%), valid loss = 4.0249 (Accuracy: 85.434%)
# Epoch 17, train loss = 4.1013 (Accuracy: 85.157%), valid loss = 4.3021 (Accuracy: 84.43%)
# Epoch 18, train loss = 4.117 (Accuracy: 85.1%), valid loss = 4.0956 (Accuracy: 85.178%)
# Epoch 19, train loss = 4.0806 (Accuracy: 85.232%), valid loss = 4.0588 (Accuracy: 85.311%)
# Epoch 20, train loss = 4.0394 (Accuracy: 85.381%), valid loss = 4.1917 (Accuracy: 84.83%)
# Epoch 21, train loss = 4.0782 (Accuracy: 85.24%), valid loss = 4.1097 (Accuracy: 85.126%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 11 with minimum valid loss = 3.94 (Accuracy: 85.741%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 100, learningrate = 0.01
# Epoch 1, train loss = 20.956 (Accuracy: 24.158%), valid loss = 21.0266 (Accuracy: 23.902%)
# Epoch 2, train loss = 19.911 (Accuracy: 27.94%), valid loss = 20.1017 (Accuracy: 27.249%)
# Epoch 3, train loss = 15.7746 (Accuracy: 42.91%), valid loss = 15.7035 (Accuracy: 43.167%)
# Epoch 4, train loss = 12.231 (Accuracy: 55.734%), valid loss = 12.1114 (Accuracy: 56.167%)
# Epoch 5, train loss = 9.9785 (Accuracy: 63.886%), valid loss = 9.8062 (Accuracy: 64.51%)
# Epoch 6, train loss = 8.5238 (Accuracy: 69.151%), valid loss = 8.409 (Accuracy: 69.567%)
# Epoch 7, train loss = 7.7273 (Accuracy: 72.034%), valid loss = 7.6481 (Accuracy: 72.321%)
# Epoch 8, train loss = 7.1102 (Accuracy: 74.267%), valid loss = 7.0456 (Accuracy: 74.501%)
# Epoch 9, train loss = 6.6823 (Accuracy: 75.816%), valid loss = 6.7741 (Accuracy: 75.484%)
# Epoch 10, train loss = 6.4725 (Accuracy: 76.575%), valid loss = 6.5507 (Accuracy: 76.292%)
# Epoch 11, train loss = 6.3198 (Accuracy: 77.128%), valid loss = 6.282 (Accuracy: 77.265%)
# Epoch 12, train loss = 6.1998 (Accuracy: 77.562%), valid loss = 6.1519 (Accuracy: 77.736%)
# Epoch 13, train loss = 6.127 (Accuracy: 77.826%), valid loss = 5.903 (Accuracy: 78.637%)
# Epoch 14, train loss = 5.9124 (Accuracy: 78.602%), valid loss = 6.0359 (Accuracy: 78.155%)
# Epoch 15, train loss = 5.8288 (Accuracy: 78.905%), valid loss = 5.8945 (Accuracy: 78.667%)
# Epoch 16, train loss = 5.6433 (Accuracy: 79.576%), valid loss = 6.0585 (Accuracy: 78.073%)
# Epoch 17, train loss = 5.6724 (Accuracy: 79.471%), valid loss = 5.7813 (Accuracy: 79.077%)
# Epoch 18, train loss = 5.6773 (Accuracy: 79.453%), valid loss = 5.49 (Accuracy: 80.131%)
# Epoch 19, train loss = 5.5415 (Accuracy: 79.945%), valid loss = 5.4985 (Accuracy: 80.1%)
# Epoch 20, train loss = 5.4493 (Accuracy: 80.278%), valid loss = 5.5013 (Accuracy: 80.09%)
# Epoch 21, train loss = 5.3948 (Accuracy: 80.476%), valid loss = 5.3288 (Accuracy: 80.715%)
# Epoch 22, train loss = 5.3499 (Accuracy: 80.638%), valid loss = 5.1789 (Accuracy: 81.257%)
# Epoch 23, train loss = 5.2105 (Accuracy: 81.143%), valid loss = 5.2694 (Accuracy: 80.929%)
# Epoch 24, train loss = 5.1608 (Accuracy: 81.322%), valid loss = 5.2156 (Accuracy: 81.124%)
# Epoch 25, train loss = 5.1935 (Accuracy: 81.204%), valid loss = 5.0516 (Accuracy: 81.718%)
# Epoch 26, train loss = 5.059 (Accuracy: 81.691%), valid loss = 5.2948 (Accuracy: 80.837%)
# Epoch 27, train loss = 5.0456 (Accuracy: 81.739%), valid loss = 5.1987 (Accuracy: 81.185%)
# Epoch 28, train loss = 5.042 (Accuracy: 81.752%), valid loss = 5.1591 (Accuracy: 81.329%)
# Epoch 29, train loss = 5.1014 (Accuracy: 81.537%), valid loss = 4.9611 (Accuracy: 82.045%)
# Epoch 30, train loss = 4.9668 (Accuracy: 82.024%), valid loss = 5.2156 (Accuracy: 81.124%)
# Epoch 31, train loss = 5.0602 (Accuracy: 81.687%), valid loss = 4.9583 (Accuracy: 82.055%)
# Epoch 32, train loss = 4.9087 (Accuracy: 82.235%), valid loss = 5.2496 (Accuracy: 81.001%)
# Epoch 33, train loss = 4.9571 (Accuracy: 82.059%), valid loss = 5.1138 (Accuracy: 81.492%)
# Epoch 34, train loss = 4.9875 (Accuracy: 81.95%), valid loss = 5.0318 (Accuracy: 81.789%)
# Epoch 35, train loss = 4.9632 (Accuracy: 82.038%), valid loss = 5.0572 (Accuracy: 81.697%)
# Epoch 36, train loss = 5.0493 (Accuracy: 81.726%), valid loss = 4.7885 (Accuracy: 82.67%)
# Epoch 37, train loss = 4.9996 (Accuracy: 81.906%), valid loss = 4.8338 (Accuracy: 82.506%)
# Epoch 38, train loss = 4.9875 (Accuracy: 81.95%), valid loss = 4.8621 (Accuracy: 82.404%)
# Epoch 39, train loss = 4.9438 (Accuracy: 82.108%), valid loss = 4.9356 (Accuracy: 82.137%)
# Epoch 40, train loss = 4.9147 (Accuracy: 82.213%), valid loss = 4.9809 (Accuracy: 81.974%)
# Epoch 41, train loss = 4.8383 (Accuracy: 82.489%), valid loss = 5.1251 (Accuracy: 81.452%)
# Epoch 42, train loss = 4.9281 (Accuracy: 82.165%), valid loss = 4.8593 (Accuracy: 82.414%)
# Epoch 43, train loss = 4.8917 (Accuracy: 82.296%), valid loss = 4.8932 (Accuracy: 82.291%)
# Epoch 44, train loss = 4.9014 (Accuracy: 82.261%), valid loss = 4.7999 (Accuracy: 82.629%)
# Epoch 45, train loss = 4.8589 (Accuracy: 82.415%), valid loss = 4.8677 (Accuracy: 82.383%)
# Epoch 46, train loss = 4.8589 (Accuracy: 82.415%), valid loss = 4.831 (Accuracy: 82.516%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 36 with minimum valid loss = 4.7885 (Accuracy: 82.67%)
# ========== Start training model ==========
# batch size = 128, epoch_size = 100, learningrate = 0.05
# Epoch 1, train loss = 5.5148 (Accuracy: 80.041%), valid loss = 5.4023 (Accuracy: 80.448%)
# Epoch 2, train loss = 4.8517 (Accuracy: 82.441%), valid loss = 4.9809 (Accuracy: 81.974%)
# Epoch 3, train loss = 4.631 (Accuracy: 83.24%), valid loss = 4.8621 (Accuracy: 82.404%)
# Epoch 4, train loss = 4.6189 (Accuracy: 83.284%), valid loss = 4.6924 (Accuracy: 83.018%)
# Epoch 5, train loss = 4.4589 (Accuracy: 83.863%), valid loss = 4.8649 (Accuracy: 82.393%)
# Epoch 6, train loss = 4.6056 (Accuracy: 83.332%), valid loss = 4.4661 (Accuracy: 83.837%)
# Epoch 7, train loss = 4.5862 (Accuracy: 83.402%), valid loss = 4.4944 (Accuracy: 83.734%)
# Epoch 8, train loss = 4.5547 (Accuracy: 83.516%), valid loss = 4.5057 (Accuracy: 83.693%)
# Epoch 9, train loss = 4.5353 (Accuracy: 83.586%), valid loss = 4.4576 (Accuracy: 83.867%)
# Epoch 10, train loss = 4.5425 (Accuracy: 83.56%), valid loss = 4.3813 (Accuracy: 84.144%)
# Epoch 11, train loss = 4.4698 (Accuracy: 83.823%), valid loss = 4.5538 (Accuracy: 83.519%)
# Epoch 12, train loss = 4.4807 (Accuracy: 83.784%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 13, train loss = 4.4928 (Accuracy: 83.74%), valid loss = 4.4322 (Accuracy: 83.959%)
# Epoch 14, train loss = 4.4407 (Accuracy: 83.929%), valid loss = 4.5255 (Accuracy: 83.622%)
# Epoch 15, train loss = 4.5001 (Accuracy: 83.714%), valid loss = 4.3275 (Accuracy: 84.338%)
# Epoch 16, train loss = 4.448 (Accuracy: 83.902%), valid loss = 4.4887 (Accuracy: 83.755%)
# Epoch 17, train loss = 4.4516 (Accuracy: 83.889%), valid loss = 4.452 (Accuracy: 83.888%)
# Epoch 18, train loss = 4.4746 (Accuracy: 83.806%), valid loss = 4.3813 (Accuracy: 84.144%)
# Epoch 19, train loss = 4.3667 (Accuracy: 84.196%), valid loss = 4.599 (Accuracy: 83.356%)
# Epoch 20, train loss = 4.4249 (Accuracy: 83.986%), valid loss = 4.4152 (Accuracy: 84.021%)
# Epoch 21, train loss = 4.4601 (Accuracy: 83.858%), valid loss = 4.2907 (Accuracy: 84.471%)
# Epoch 22, train loss = 4.4007 (Accuracy: 84.073%), valid loss = 4.4802 (Accuracy: 83.785%)
# Epoch 23, train loss = 4.4589 (Accuracy: 83.863%), valid loss = 4.2738 (Accuracy: 84.533%)
# Epoch 24, train loss = 4.4359 (Accuracy: 83.946%), valid loss = 4.3275 (Accuracy: 84.338%)
# Epoch 25, train loss = 4.3898 (Accuracy: 84.113%), valid loss = 4.3954 (Accuracy: 84.093%)
# Epoch 26, train loss = 4.3522 (Accuracy: 84.249%), valid loss = 4.4746 (Accuracy: 83.806%)
# Epoch 27, train loss = 4.368 (Accuracy: 84.192%), valid loss = 4.4463 (Accuracy: 83.908%)
# Epoch 28, train loss = 4.3461 (Accuracy: 84.271%), valid loss = 4.4802 (Accuracy: 83.785%)
# Epoch 29, train loss = 4.4007 (Accuracy: 84.073%), valid loss = 4.3332 (Accuracy: 84.318%)
# Epoch 30, train loss = 4.4286 (Accuracy: 83.972%), valid loss = 4.2455 (Accuracy: 84.635%)
# Epoch 31, train loss = 4.3861 (Accuracy: 84.126%), valid loss = 4.353 (Accuracy: 84.246%)
# Epoch 32, train loss = 4.3255 (Accuracy: 84.345%), valid loss = 4.452 (Accuracy: 83.888%)
# Epoch 33, train loss = 4.4177 (Accuracy: 84.012%), valid loss = 4.2625 (Accuracy: 84.574%)
# Epoch 34, train loss = 4.3692 (Accuracy: 84.187%), valid loss = 4.3643 (Accuracy: 84.205%)
# Epoch 35, train loss = 4.3789 (Accuracy: 84.152%), valid loss = 4.3105 (Accuracy: 84.4%)
# Epoch 36, train loss = 4.3716 (Accuracy: 84.179%), valid loss = 4.319 (Accuracy: 84.369%)
# Epoch 37, train loss = 4.294 (Accuracy: 84.459%), valid loss = 4.5227 (Accuracy: 83.632%)
# Epoch 38, train loss = 4.3558 (Accuracy: 84.236%), valid loss = 4.3473 (Accuracy: 84.267%)
# ...
# Epoch 28, train loss = 4.1788 (Accuracy: 84.876%), valid loss = 4.2964 (Accuracy: 84.451%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 18 with minimum valid loss = 4.1719 (Accuracy: 84.901%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 50, learningrate = 1
# Epoch 1, train loss = 4.5813 (Accuracy: 83.42%), valid loss = 4.5114 (Accuracy: 83.673%)
# Epoch 2, train loss = 4.4031 (Accuracy: 84.065%), valid loss = 4.5594 (Accuracy: 83.499%)
# Epoch 3, train loss = 4.3898 (Accuracy: 84.113%), valid loss = 4.418 (Accuracy: 84.011%)
# Epoch 4, train loss = 4.4819 (Accuracy: 83.779%), valid loss = 4.2313 (Accuracy: 84.686%)
# Epoch 5, train loss = 4.3692 (Accuracy: 84.187%), valid loss = 4.3388 (Accuracy: 84.297%)
# Epoch 6, train loss = 4.3474 (Accuracy: 84.266%), valid loss = 4.2398 (Accuracy: 84.656%)
# Epoch 7, train loss = 4.2892 (Accuracy: 84.477%), valid loss = 4.2427 (Accuracy: 84.645%)
# Epoch 8, train loss = 4.3001 (Accuracy: 84.438%), valid loss = 4.353 (Accuracy: 84.246%)
# Epoch 9, train loss = 4.2589 (Accuracy: 84.587%), valid loss = 4.2823 (Accuracy: 84.502%)
# Epoch 10, train loss = 4.2431 (Accuracy: 84.644%), valid loss = 4.2709 (Accuracy: 84.543%)
# Epoch 11, train loss = 4.1752 (Accuracy: 84.889%), valid loss = 4.319 (Accuracy: 84.369%)
# Epoch 12, train loss = 4.2261 (Accuracy: 84.705%), valid loss = 4.1748 (Accuracy: 84.891%)
# Epoch 13, train loss = 4.2322 (Accuracy: 84.683%), valid loss = 4.1521 (Accuracy: 84.973%)
# Epoch 14, train loss = 4.2043 (Accuracy: 84.784%), valid loss = 4.2342 (Accuracy: 84.676%)
# Epoch 15, train loss = 4.1679 (Accuracy: 84.916%), valid loss = 4.254 (Accuracy: 84.604%)
# Epoch 16, train loss = 4.1413 (Accuracy: 85.012%), valid loss = 4.2653 (Accuracy: 84.563%)
# Epoch 17, train loss = 4.1728 (Accuracy: 84.898%), valid loss = 4.1578 (Accuracy: 84.952%)
# Epoch 18, train loss = 4.1364 (Accuracy: 85.03%), valid loss = 4.2398 (Accuracy: 84.656%)
# Epoch 19, train loss = 4.1776 (Accuracy: 84.881%), valid loss = 4.1295 (Accuracy: 85.055%)
# Epoch 20, train loss = 4.1425 (Accuracy: 85.008%), valid loss = 4.3275 (Accuracy: 84.338%)
# Epoch 21, train loss = 4.0855 (Accuracy: 85.214%), valid loss = 4.2964 (Accuracy: 84.451%)
# Epoch 22, train loss = 4.197 (Accuracy: 84.81%), valid loss = 4.056 (Accuracy: 85.321%)
# Epoch 23, train loss = 4.1207 (Accuracy: 85.087%), valid loss = 4.2172 (Accuracy: 84.737%)
# Epoch 24, train loss = 4.1619 (Accuracy: 84.938%), valid loss = 4.0645 (Accuracy: 85.29%)
# Epoch 25, train loss = 4.1607 (Accuracy: 84.942%), valid loss = 4.0701 (Accuracy: 85.27%)
# Epoch 26, train loss = 4.1013 (Accuracy: 85.157%), valid loss = 4.1521 (Accuracy: 84.973%)
# Epoch 27, train loss = 4.1207 (Accuracy: 85.087%), valid loss = 4.1437 (Accuracy: 85.004%)
# Epoch 28, train loss = 4.0903 (Accuracy: 85.197%), valid loss = 4.1324 (Accuracy: 85.045%)
# Epoch 29, train loss = 4.0843 (Accuracy: 85.218%), valid loss = 4.1578 (Accuracy: 84.952%)
# Epoch 30, train loss = 4.0855 (Accuracy: 85.214%), valid loss = 4.155 (Accuracy: 84.963%)
# Epoch 31, train loss = 4.1061 (Accuracy: 85.14%), valid loss = 4.0843 (Accuracy: 85.219%)
# Epoch 32, train loss = 4.0806 (Accuracy: 85.232%), valid loss = 4.1465 (Accuracy: 84.993%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 22 with minimum valid loss = 4.056 (Accuracy: 85.321%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 100, learningrate = 0.01
# Epoch 1, train loss = 21.0724 (Accuracy: 23.736%), valid loss = 20.7551 (Accuracy: 24.885%)
# Epoch 2, train loss = 20.9718 (Accuracy: 24.101%), valid loss = 20.9899 (Accuracy: 24.035%)
# Epoch 3, train loss = 20.9706 (Accuracy: 24.105%), valid loss = 20.9927 (Accuracy: 24.025%)
# Epoch 4, train loss = 21.0118 (Accuracy: 23.956%), valid loss = 20.8965 (Accuracy: 24.373%)
# Epoch 5, train loss = 21.0045 (Accuracy: 23.982%), valid loss = 20.9135 (Accuracy: 24.312%)
# Epoch 6, train loss = 20.9112 (Accuracy: 24.32%), valid loss = 21.1313 (Accuracy: 23.523%)
# Epoch 7, train loss = 21.0955 (Accuracy: 23.653%), valid loss = 20.7014 (Accuracy: 25.079%)
# Epoch 8, train loss = 20.9573 (Accuracy: 24.153%), valid loss = 21.0238 (Accuracy: 23.912%)
# Epoch 9, train loss = 21.0361 (Accuracy: 23.868%), valid loss = 20.84 (Accuracy: 24.578%)
# Epoch 10, train loss = 20.9815 (Accuracy: 24.065%), valid loss = 20.9672 (Accuracy: 24.117%)
# Epoch 11, train loss = 20.9524 (Accuracy: 24.171%), valid loss = 21.0351 (Accuracy: 23.871%)
# Epoch 12, train loss = 20.9851 (Accuracy: 24.052%), valid loss = 20.9588 (Accuracy: 24.148%)
# Epoch 13, train loss = 20.9803 (Accuracy: 24.07%), valid loss = 20.9701 (Accuracy: 24.107%)
# Epoch 14, train loss = 21.0094 (Accuracy: 23.965%), valid loss = 20.9022 (Accuracy: 24.353%)
# Epoch 15, train loss = 21.0445 (Accuracy: 23.837%), valid loss = 20.8202 (Accuracy: 24.649%)
# Epoch 16, train loss = 20.9488 (Accuracy: 24.184%), valid loss = 21.0436 (Accuracy: 23.841%)
# Epoch 17, train loss = 20.9985 (Accuracy: 24.004%), valid loss = 20.9276 (Accuracy: 24.26%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 7 with minimum valid loss = 20.7014 (Accuracy: 25.079%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 100, learningrate = 0.05
# Epoch 1, train loss = 20.6554 (Accuracy: 25.246%), valid loss = 20.9616 (Accuracy: 24.138%)
# Epoch 2, train loss = 15.9734 (Accuracy: 42.19%), valid loss = 16.009 (Accuracy: 42.062%)
# Epoch 3, train loss = 9.8015 (Accuracy: 64.527%), valid loss = 9.7525 (Accuracy: 64.705%)
# Epoch 4, train loss = 7.8655 (Accuracy: 71.534%), valid loss = 7.699 (Accuracy: 72.136%)
# Epoch 5, train loss = 6.3355 (Accuracy: 77.071%), valid loss = 6.4998 (Accuracy: 76.477%)
# Epoch 6, train loss = 6.0882 (Accuracy: 77.966%), valid loss = 5.9623 (Accuracy: 78.422%)
# Epoch 7, train loss = 5.8252 (Accuracy: 78.918%), valid loss = 5.8634 (Accuracy: 78.78%)
# Epoch 8, train loss = 5.7342 (Accuracy: 79.247%), valid loss = 5.6541 (Accuracy: 79.537%)
# Epoch 9, train loss = 5.5306 (Accuracy: 79.984%), valid loss = 5.6936 (Accuracy: 79.394%)
# Epoch 10, train loss = 5.4639 (Accuracy: 80.226%), valid loss = 5.5409 (Accuracy: 79.947%)
# Epoch 11, train loss = 5.3875 (Accuracy: 80.502%), valid loss = 5.4391 (Accuracy: 80.315%)
# Epoch 12, train loss = 5.2699 (Accuracy: 80.928%), valid loss = 5.2411 (Accuracy: 81.032%)
# Epoch 13, train loss = 5.1087 (Accuracy: 81.511%), valid loss = 5.2185 (Accuracy: 81.114%)
# Epoch 14, train loss = 5.0844 (Accuracy: 81.599%), valid loss = 5.0148 (Accuracy: 81.851%)
# Epoch 15, train loss = 4.9377 (Accuracy: 82.13%), valid loss = 5.0799 (Accuracy: 81.615%)
# Epoch 16, train loss = 4.9499 (Accuracy: 82.086%), valid loss = 4.9385 (Accuracy: 82.127%)
# Epoch 17, train loss = 4.8868 (Accuracy: 82.314%), valid loss = 4.9865 (Accuracy: 81.953%)
# Epoch 18, train loss = 4.9341 (Accuracy: 82.143%), valid loss = 4.7857 (Accuracy: 82.68%)
# Epoch 19, train loss = 4.7608 (Accuracy: 82.77%), valid loss = 5.0997 (Accuracy: 81.544%)
# Epoch 20, train loss = 4.7826 (Accuracy: 82.691%), valid loss = 4.8734 (Accuracy: 82.363%)
# Epoch 21, train loss = 4.7947 (Accuracy: 82.647%), valid loss = 4.7914 (Accuracy: 82.659%)
# Epoch 22, train loss = 4.7983 (Accuracy: 82.634%), valid loss = 4.6924 (Accuracy: 83.018%)
# Epoch 23, train loss = 4.7353 (Accuracy: 82.862%), valid loss = 4.7659 (Accuracy: 82.752%)
# Epoch 24, train loss = 4.7329 (Accuracy: 82.871%), valid loss = 4.7178 (Accuracy: 82.926%)
# Epoch 25, train loss = 4.728 (Accuracy: 82.889%), valid loss = 4.6641 (Accuracy: 83.12%)
# Epoch 26, train loss = 4.6832 (Accuracy: 83.051%), valid loss = 4.7207 (Accuracy: 82.915%)
# Epoch 27, train loss = 4.6965 (Accuracy: 83.003%), valid loss = 4.6386 (Accuracy: 83.212%)
# Epoch 28, train loss = 4.6674 (Accuracy: 83.108%), valid loss = 4.6811 (Accuracy: 83.059%)
# Epoch 29, train loss = 4.7183 (Accuracy: 82.924%), valid loss = 4.5312 (Accuracy: 83.601%)
# Epoch 30, train loss = 4.6213 (Accuracy: 83.275%), valid loss = 4.7292 (Accuracy: 82.885%)
# Epoch 31, train loss = 4.6553 (Accuracy: 83.152%), valid loss = 4.616 (Accuracy: 83.294%)
# Epoch 32, train loss = 4.728 (Accuracy: 82.889%), valid loss = 4.3699 (Accuracy: 84.185%)
# Epoch 33, train loss = 4.6771 (Accuracy: 83.073%), valid loss = 4.4718 (Accuracy: 83.816%)
# Epoch 34, train loss = 4.631 (Accuracy: 83.24%), valid loss = 4.5736 (Accuracy: 83.448%)
# Epoch 35, train loss = 4.6529 (Accuracy: 83.161%), valid loss = 4.4774 (Accuracy: 83.796%)
# Epoch 36, train loss = 4.5607 (Accuracy: 83.494%), valid loss = 4.6669 (Accuracy: 83.11%)
# Epoch 37, train loss = 4.5935 (Accuracy: 83.376%), valid loss = 4.5934 (Accuracy: 83.376%)
# Epoch 38, train loss = 4.6274 (Accuracy: 83.253%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 39, train loss = 4.5534 (Accuracy: 83.521%), valid loss = 4.6528 (Accuracy: 83.161%)
# Epoch 40, train loss = 4.5995 (Accuracy: 83.354%), valid loss = 4.5425 (Accuracy: 83.56%)
# Epoch 41, train loss = 4.5668 (Accuracy: 83.472%), valid loss = 4.616 (Accuracy: 83.294%)
# Epoch 42, train loss = 4.6407 (Accuracy: 83.205%), valid loss = 4.4576 (Accuracy: 83.867%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 32 with minimum valid loss = 4.3699 (Accuracy: 84.185%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 100, learningrate = 0.1
# Epoch 1, train loss = 15.6134 (Accuracy: 43.493%), valid loss = 15.8902 (Accuracy: 42.492%)
# Epoch 2, train loss = 7.1005 (Accuracy: 74.302%), valid loss = 6.958 (Accuracy: 74.818%)
# Epoch 3, train loss = 6.1901 (Accuracy: 77.597%), valid loss = 5.9114 (Accuracy: 78.606%)
# Epoch 4, train loss = 5.7476 (Accuracy: 79.199%), valid loss = 5.6258 (Accuracy: 79.64%)
# Epoch 5, train loss = 5.2663 (Accuracy: 80.941%), valid loss = 5.2439 (Accuracy: 81.022%)
# Epoch 6, train loss = 5.0869 (Accuracy: 81.59%), valid loss = 4.9243 (Accuracy: 82.178%)
# Epoch 7, train loss = 4.9681 (Accuracy: 82.02%), valid loss = 4.8225 (Accuracy: 82.547%)
# Epoch 8, train loss = 4.8129 (Accuracy: 82.582%), valid loss = 4.896 (Accuracy: 82.281%)
# Epoch 9, train loss = 4.7462 (Accuracy: 82.823%), valid loss = 4.9413 (Accuracy: 82.117%)
# Epoch 10, train loss = 4.7171 (Accuracy: 82.928%), valid loss = 4.797 (Accuracy: 82.639%)
# Epoch 11, train loss = 4.7898 (Accuracy: 82.665%), valid loss = 4.4859 (Accuracy: 83.765%)
# Epoch 12, train loss = 4.6565 (Accuracy: 83.148%), valid loss = 4.6641 (Accuracy: 83.12%)
# Epoch 13, train loss = 4.6407 (Accuracy: 83.205%), valid loss = 4.6443 (Accuracy: 83.192%)
# Epoch 14, train loss = 4.6432 (Accuracy: 83.196%), valid loss = 4.5792 (Accuracy: 83.427%)
# Epoch 15, train loss = 4.6128 (Accuracy: 83.306%), valid loss = 4.5736 (Accuracy: 83.448%)
# Epoch 16, train loss = 4.5874 (Accuracy: 83.398%), valid loss = 4.6245 (Accuracy: 83.263%)
# Epoch 17, train loss = 4.5437 (Accuracy: 83.556%), valid loss = 4.7348 (Accuracy: 82.864%)
# Epoch 18, train loss = 4.6007 (Accuracy: 83.349%), valid loss = 4.5736 (Accuracy: 83.448%)
# Epoch 19, train loss = 4.5874 (Accuracy: 83.398%), valid loss = 4.5906 (Accuracy: 83.386%)
# Epoch 20, train loss = 4.5692 (Accuracy: 83.463%), valid loss = 4.6047 (Accuracy: 83.335%)
# Epoch 21, train loss = 4.534 (Accuracy: 83.591%), valid loss = 4.6556 (Accuracy: 83.151%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 11 with minimum valid loss = 4.4859 (Accuracy: 83.765%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 100, learningrate = 0.5
# Epoch 1, train loss = 4.6383 (Accuracy: 83.213%), valid loss = 4.5906 (Accuracy: 83.386%)
# Epoch 2, train loss = 4.6056 (Accuracy: 83.332%), valid loss = 4.4293 (Accuracy: 83.97%)
# Epoch 3, train loss = 4.4916 (Accuracy: 83.744%), valid loss = 4.452 (Accuracy: 83.888%)
# Epoch 4, train loss = 4.5098 (Accuracy: 83.678%), valid loss = 4.2087 (Accuracy: 84.768%)
# Epoch 5, train loss = 4.3728 (Accuracy: 84.174%), valid loss = 4.5566 (Accuracy: 83.509%)
# Epoch 6, train loss = 4.4346 (Accuracy: 83.951%), valid loss = 4.2879 (Accuracy: 84.482%)
# Epoch 7, train loss = 4.3752 (Accuracy: 84.165%), valid loss = 4.5029 (Accuracy: 83.704%)
# Epoch 8, train loss = 4.334 (Accuracy: 84.315%), valid loss = 4.4548 (Accuracy: 83.878%)
# Epoch 9, train loss = 4.3231 (Accuracy: 84.354%), valid loss = 4.4067 (Accuracy: 84.052%)
# Epoch 10, train loss = 4.3461 (Accuracy: 84.271%), valid loss = 4.3162 (Accuracy: 84.379%)
# Epoch 11, train loss = 4.2964 (Accuracy: 84.451%), valid loss = 4.4378 (Accuracy: 83.939%)
# Epoch 12, train loss = 4.2746 (Accuracy: 84.53%), valid loss = 4.3671 (Accuracy: 84.195%)
# Epoch 13, train loss = 4.2879 (Accuracy: 84.481%), valid loss = 4.3275 (Accuracy: 84.338%)
# Epoch 14, train loss = 4.2746 (Accuracy: 84.53%), valid loss = 4.3332 (Accuracy: 84.318%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 4 with minimum valid loss = 4.2087 (Accuracy: 84.768%)
# ========== Start training model ==========
# batch size = 2048, epoch_size = 100, learningrate = 1
# Epoch 1, train loss = 4.5874 (Accuracy: 83.398%), valid loss = 4.7009 (Accuracy: 82.987%)
# Epoch 2, train loss = 4.431 (Accuracy: 83.964%), valid loss = 4.3813 (Accuracy: 84.144%)
# Epoch 3, train loss = 4.3704 (Accuracy: 84.183%), valid loss = 4.4011 (Accuracy: 84.072%)
# Epoch 4, train loss = 4.3474 (Accuracy: 84.266%), valid loss = 4.4633 (Accuracy: 83.847%)
# Epoch 5, train loss = 4.3195 (Accuracy: 84.367%), valid loss = 4.3049 (Accuracy: 84.42%)
# Epoch 6, train loss = 4.294 (Accuracy: 84.459%), valid loss = 4.3219 (Accuracy: 84.359%)
# Epoch 7, train loss = 4.2601 (Accuracy: 84.582%), valid loss = 4.2964 (Accuracy: 84.451%)
# Epoch 8, train loss = 4.2698 (Accuracy: 84.547%), valid loss = 4.2229 (Accuracy: 84.717%)
# Epoch 9, train loss = 4.1982 (Accuracy: 84.806%), valid loss = 4.319 (Accuracy: 84.369%)
# Epoch 10, train loss = 4.2213 (Accuracy: 84.723%), valid loss = 4.2229 (Accuracy: 84.717%)
# Epoch 11, train loss = 4.1303 (Accuracy: 85.052%), valid loss = 4.4633 (Accuracy: 83.847%)
# Epoch 12, train loss = 4.2649 (Accuracy: 84.565%), valid loss = 4.1493 (Accuracy: 84.983%)
# Epoch 13, train loss = 4.1631 (Accuracy: 84.933%), valid loss = 4.2625 (Accuracy: 84.574%)
# Epoch 14, train loss = 4.2443 (Accuracy: 84.639%), valid loss = 4.0418 (Accuracy: 85.372%)
# Epoch 15, train loss = 4.174 (Accuracy: 84.894%), valid loss = 4.1408 (Accuracy: 85.014%)
# Epoch 16, train loss = 4.1061 (Accuracy: 85.14%), valid loss = 4.3417 (Accuracy: 84.287%)
# Epoch 17, train loss = 4.1073 (Accuracy: 85.135%), valid loss = 4.2229 (Accuracy: 84.717%)
# Epoch 18, train loss = 4.1813 (Accuracy: 84.867%), valid loss = 4.1069 (Accuracy: 85.137%)
# Epoch 19, train loss = 4.1376 (Accuracy: 85.025%), valid loss = 4.0588 (Accuracy: 85.311%)
# Epoch 20, train loss = 4.1631 (Accuracy: 84.933%), valid loss = 4.1493 (Accuracy: 84.983%)
# Epoch 21, train loss = 4.1582 (Accuracy: 84.951%), valid loss = 4.1069 (Accuracy: 85.137%)
# Epoch 22, train loss = 4.0867 (Accuracy: 85.21%), valid loss = 4.22 (Accuracy: 84.727%)
# Epoch 23, train loss = 4.1534 (Accuracy: 84.968%), valid loss = 4.0192 (Accuracy: 85.454%)
# Epoch 24, train loss = 4.0394 (Accuracy: 85.381%), valid loss = 4.2766 (Accuracy: 84.522%)
# Epoch 25, train loss = 4.0576 (Accuracy: 85.315%), valid loss = 4.2144 (Accuracy: 84.748%)
# Epoch 26, train loss = 4.1376 (Accuracy: 85.025%), valid loss = 4.0277 (Accuracy: 85.423%)
# Epoch 27, train loss = 4.1437 (Accuracy: 85.004%), valid loss = 4.0616 (Accuracy: 85.3%)
# Epoch 28, train loss = 4.06 (Accuracy: 85.306%), valid loss = 4.1691 (Accuracy: 84.911%)
# Epoch 29, train loss = 4.0225 (Accuracy: 85.442%), valid loss = 4.2709 (Accuracy: 84.543%)
# Epoch 30, train loss = 4.0843 (Accuracy: 85.218%), valid loss = 4.1267 (Accuracy: 85.065%)
# Epoch 31, train loss = 4.0758 (Accuracy: 85.249%), valid loss = 4.1069 (Accuracy: 85.137%)
# Epoch 32, train loss = 4.1 (Accuracy: 85.161%), valid loss = 4.0871 (Accuracy: 85.208%)
# Epoch 33, train loss = 4.0709 (Accuracy: 85.267%), valid loss = 4.1324 (Accuracy: 85.045%)
# Early Stopping!
# ==========validation result==========
# Best epoch is 23 with minimum valid loss = 4.0192 (Accuracy: 85.454%)

# %%
print("=" * 10, " Best Model result ", "=" * 10)
print(f"Batch Size = {best_batch_size}, Epoch Size = {best_epoch_size} (Actually running {best_stop_epoch_size} epoch), Learning rate = {best_learning_rate}")
print(f"Validation loss = {round(global_best_loss, 3)} (Accuracy: {round(global_best_acc*100, 3)}%)")
# Out:
# ==========  Best Model result  ==========
# Batch Size = 512, Epoch Size = 50 (Actually running 37 epoch), Learning rate = 0.5
# Validation loss = 3.847 (Accuracy: 86.078%)

# %%
y_pred = best_model.predict(X_test)
y_train_pred = best_model.predict(X_train)

# %%
result_true_index = (y_train_pred == y_train).nonzero()[0][:5]
print("="*10, "Classify correctly", "="*10)
data_train.iloc[result_true_index, :]
# Out:
# ========== Classify correctly ==========
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 6   49           Private  160187        9th              5
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 6  Married-spouse-absent      Other-service  Not-in-family  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country  income
# 0          2174             0              40  United-States       0
# 1             0             0              13  United-States       0
# 2             0             0              40  United-States       0
# 3             0             0              40  United-States       0
# 6             0             0              16        Jamaica       0

# %%
result_false_index = (y_train_pred != y_train).nonzero()[0][:5]
print("="*10, "Classify wrong", "="*10)
data_train.iloc[result_false_index, :]
# Out:
# ========== Classify wrong ==========
#     age         workclass  fnlwgt  education  education_num  \
# 4    28           Private  338409  Bachelors             13
# 5    37           Private  284582    Masters             14
# 7    52  Self-emp-not-inc  209642    HS-grad              9
# 11   30         State-gov  141297  Bachelors             13
# 14   40           Private  121772  Assoc-voc             11
#
#         marital_status       occupation relationship                race  \
# 4   Married-civ-spouse   Prof-specialty         Wife               Black
# 5   Married-civ-spouse  Exec-managerial         Wife               White
# 7   Married-civ-spouse  Exec-managerial      Husband               White
# 11  Married-civ-spouse   Prof-specialty      Husband  Asian-Pac-Islander
# 14  Married-civ-spouse     Craft-repair      Husband  Asian-Pac-Islander
#
#        sex  capital_gain  capital_loss  hours_per_week native_country  income
# 4   Female             0             0              40           Cuba       0
# 5   Female             0             0              40  United-States       0
# 7     Male             0             0              45  United-States       1
# 11    Male             0             0              40          India       1
# 14    Male             0             0              40              ?       1

# %% [markdown]
# # Write to csv

# %%
def write_to_csv(y_pred, file_name):
    path = os.path.join("./submission/", file_name)
    with open(path, 'w', newline='') as csvf:
        # 建立 CSV 檔寫入器
        writer = csv.writer(csvf)
        writer.writerow(['id','label'])
        for i in range(int(y_pred.shape[0])):
            writer.writerow([i + 1, int(y_pred[i])])

# %%
#記得改名字
file_name = 'submission_1029_2.csv'
write_to_csv(y_pred, file_name)
